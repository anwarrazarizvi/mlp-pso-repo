# %% [markdown]
# ## Function Approximation
# ### Using the PSO algorithm to optimise the ANN's parameters

# %% [markdown]
# **Import Resources**

# %%
# import resources

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **1. Create Neural Network Class**

# %%
class NeuralNetwork:    
    def __init__(self, func, hiddenLayerNeurons, activation, inputList, outputList):
        self.func = func # name of the function to be optimized
        self.layerArch = list.copy(hiddenLayerNeurons) #list of neurons in the hidden layers
        self.activation = activation # name of the activation fuction
          
        self.inputArray = inputList # array of given input dataset
        self.outputArray = outputList # array of the desired output dataset
        #print(self.inputArray,self.outputArray)
        
        # adding input and output layers to the hidden neurons list
        self.inputOutputNeurons()
        
        # calculate number of weights
        self.nWeights = self.numWeights()
        
        # set activation function
        self.actFunc = self.functionSelection()
        
        # set indices at which weight matrix to be split for matrix multiplication
        self.splitIndices = self.splitIndices()
        
    def getANN_Hyperparameters(self):
        return [self.func, self.activation, self.layerArch]
        
    def getnWeights(self): # getter methonds for number of weights
        return self.nWeights
        
    def inputOutputNeurons(self): # a private method to neuralNetwork class
        # Set number neurons in the Input layer
        if self.func in ('XOR','Complex'):
            self.layerArch.insert(0,2) # XOR & Complex functions are based on two input variables
        else:
            self.layerArch.insert(0,1) # Linear, Cubic, Sine, Tanh functions are based on single input variable
       
        # Set number of neurons in the Output layer
        self.layerArch.append(1) # only single output value is expected from the fuction
        
    def numWeights(self):# a private method to neuralNetwork class
        n_weights = sum(self.layerArch[i]*self.layerArch[i+1] for i in range(len(self.layerArch)-1))
        return n_weights
    
    def functionSelection(self):# a private method to neuralNetwork class
        return activation_funcs[self.activation]
    
    def splitIndices(self):
        indices = []
        for i in range(len(self.layerArch)-1):
            indices.append(self.layerArch[i]*self.layerArch[i+1])

        splitIndices = []
        splitIndices.append(indices[0])
        for j in range(1,len(indices)-1):
            splitIndices.append(splitIndices[j-1] + indices[j])

        return splitIndices
    
    def forward(self, weights):
        
        # to do: check the length of list of weigths matches the number weights
        
        wArray = np.split(weights,self.splitIndices)
        #print("splitIndices",self.splitIndices)
        #print("wArray",wArray)
        #print("layerArch", self.layerArch)
        
        wMatrix=[]
        for i in range(0,len(self.layerArch)-1):
            wMatrix.append(wArray[i].reshape(self.layerArch[i+1],self.layerArch[i]))
        #print("wArray after reshape", wMatrix)
    
        desiredArray = np.copy(self.outputArray)
        predictArray = []
        
        for i in range(len(self.inputArray)):
            ih = self.inputArray[i].reshape(-1,1)
            for j in range(0,len(self.layerArch)-1):
                #print("wMatrix = ", wMatrix[j], "ih = ", ih)
                ih = np.matmul(wMatrix[j],ih)
            
                if j != (len(self.layerArch)-1):
                    ih = self.actFunc(ih)
            predictArray.append(ih)
            
        #print(len(desiredArray), len(predictArray))

        squeezePredict = np.squeeze(predictArray)

        mse = ((desiredArray - squeezePredict)**2).mean(axis = None)
       
        return mse.tolist()

# %%
'''
a = [[ 0.23750601],
 [ 0.16600618],
 [-0.15851644],
 [ 0.10666603],
 [ 0.21195092]]
print(a)

b = np.asarray(a)
print(b)
print(type(b))
def function(val):
    return val*0

print(b[1])
b[1]= -b[1]
print(b[1])
'''
# Out:
# '\na = [[ 0.23750601],\n [ 0.16600618],\n [-0.15851644],\n [ 0.10666603],\n [ 0.21195092]]\nprint(a)\n\nb = np.asarray(a)\nprint(b)\nprint(type(b))\ndef function(val):\n    return val*0\n\nprint(b[1])\nb[1]= -b[1]\nprint(b[1])\n'

# %% [markdown]
# **2. Create PSO Class**<br>
# swarmsize - desired swarm size i.e. weight array<br>
# $ \alpha \gets$ inertia weight i.e. proportion of velocity to be retained<br>
# $ \beta \gets$ cognitive weight i.e. proportion of personal best to be retained<br>
# $ \delta \gets$ social weight i.e. proportion of global best to be retained<br>
# $ \epsilon \gets$ jump size of a particle<br><br>
# **Enforcing Boundaries**: boundaries are enforced by rebounding the position by reversing the inertia weight<br>

# %%
class ParticleSwarmOptimizer:    
    def __init__(self, swarm_size,pso_alpha, pso_beta, pso_delta, max_epochs, bound_max, bound_min, ann):
        # PSO parameters
        self.swarmSize = swarm_size # number of particles in swarm
        self.psoAlpha = pso_alpha # inertia weight
        self.psoBeta = pso_beta # cognitive weight 
        self.psoDelta = pso_delta # social weight
        self.maxEpochs = max_epochs # maximum number of iterations

        self.bound_max = bound_max
        self.bound_min = bound_min
        
        self.ann = ann # neural network
        self.dim = self.ann.getnWeights() # no. of weights in nurol network = dimension of particle
        
        self.swarm = [Particles(self.dim, self.ann) for i in range(swarm_size)] #create swarm with swarm_size particles
  
        # initialise global best position
        self.best_swarm_pos = np.ones(self.dim)
        
    def getSwarmSize(self):
        return self.swarmSize # no of particles in swarm
    
    def getFinalWeights(self):
        return self.best_swarm_pos
    
    def getPSO_Hyperparameters(self):
        return [self.swarmSize, self.psoAlpha, self.psoBeta, self.psoDelta, self.maxEpochs, self.bound_max, self.bound_min]
   
    def forward(self):
        #Data collection for report and graph
        report = '' # string for run report
        ann_hp = self.ann.getANN_Hyperparameters()
        report +=('Function:{}\nANN Hyperparameters: activation function {}, layer arch {}\n'.format(ann_hp[0],ann_hp[1],ann_hp[2]))
        report +=('PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(self.swarmSize,self.psoAlpha,self.psoBeta,self.psoDelta,self.maxEpochs))
        report += '\n-------------------------------------------------------------------------------------'  
        report += '\n-------------------------------------------------------------------------------------\n'    
        data_Swarm_best = []
        data_Particle_current_best= []
        data_Particle_current_worst = []
        data_particle_current_average = []
        epoch_count =[]
        
        # initialise global best position and fittness/error
        best_swarm_err = 500
 
        epoch = 0
        while epoch < self.maxEpochs: # run until fixed number of iterations
            #data1= []
            #Update global best
            for ii in range(self.swarmSize): # for each particle in swarm/population
                
                position_ii = self.swarm[ii].getPosition()
                err_ii = (self.swarm[ii].getError())
  
                # update Global/swarm best error and position if found comparing fitness/error
                if err_ii < best_swarm_err:
                    best_swarm_err = err_ii
                    self.best_swarm_pos = position_ii
            #data1.extend([epoch+1,best_swarm_err])
            data_Swarm_best.append(best_swarm_err)
            epoch_count.append(epoch+1)
            
            #data2=[]
            pcb= 100 # setting to high error
            pcw= -100 # setting to low error
            pca=0
            for i in range(self.swarmSize): # for each particle in swarm/population

                # Gather information            
                position_i = self.swarm[i].getPosition()
                velocity_i = self.swarm[i].getVelocity()
                best_part_error_i = self.swarm[i].getBestPartErr()
                best_part_position_i = self.swarm[i].getBestPartPos()
                err_i = self.swarm[i].getError()
                
                report += ('epoch:{:03d} ,particle:{:02d}, par err:{:0.4f}, best part err:{:0.4f}, best swarm err:{:0.4f}'.
                      format(epoch+1, i+1, err_i, best_part_error_i ,best_swarm_err))+'\n'
                               
                #data2.extend([err_i,best_part_error_i])
                if pcb > err_i:
                    pcb = err_i
                if pcw < err_i:
                    pcw = err_i
                pca += err_i
                  
                
                # compute particle new velocity
                for k in range(self.dim): # for each dimension/weight in particle i
                    a = self.psoAlpha*velocity_i[k]
                    b = self.psoBeta*(best_part_position_i[k] - position_i[k])
                    c = self.psoDelta*(self.best_swarm_pos[k] - position_i[k])
                    velocity_i[k] = a+b+c
                    
                # compute particle new position as temp for checking bounds
                temp = np.add(position_i,velocity_i)
                
                # enforcing boundaries by rebounding particle with reversing the interia
                kk=0
                while kk < self.dim:
                    if temp[kk] >= self.bound_max or temp[kk] <= self.bound_min:
                        #position_f = (np.random.rand((self.dim)).astype(np.float32)-0.5)/2
                        #velocity_i = (np.random.rand((self.dim)).astype(np.float32)-0.5)/2
                        velocity_i[kk] = velocity_i[kk]- self.psoAlpha*velocity_i[k]
                        #print('weights breached at weights#',kk)
                    kk +=1
                
                # compute particle new position as temp
                position_f = np.add(position_i,velocity_i)

                # compute new fitness
                new_err = self.ann.forward(position_f)
                
                # update particle best error and position if found comparing fitness/error
                if new_err < best_part_error_i:
                    self.swarm[i].setBestPartErr(new_err)
                    self.swarm[i].setBestPartPos(position_f)
                
                # update particle class parameters              
                self.swarm[i].setPosition(position_f) # update particle position
                self.swarm[i].setVelocity(velocity_i) #update particle velocity
                self.swarm[i].setError(new_err) #update particle current error
                
                #print('epoch:{:03d} ,particle:{:02d}, par err:{:0.5f}, best part err:{:0.5f}, best swarm err:{:0.2f}'.
                      #format(epoch+1, i+1, new_err, self.swarm[i].getBestPartErr() ,best_swarm_err))
            pca = pca/self.swarmSize
            #data1.extend(data2)
            #self.data.append(data1)
            data_Particle_current_best.append(pcb)
            data_Particle_current_worst.append(pcw)
            data_particle_current_average.append(pca)
            report += '\n-------------------------------------------------------------------------------------\n'  
            epoch += 1
        return best_swarm_err, report, epoch_count,data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average

# %% [markdown]
# **3. Create Particles Class**

# %%
class Particles:
    def __init__(self, dim, ann):
        self.dim = dim
        self.ann =ann
        
        # initialise particle best position and velocity with random values 
        self.position = (np.random.rand((self.dim)).astype(np.float32)-0.5)/2 #current position; initialized with random
        self.velocity = (np.random.rand((self.dim)).astype(np.float32)-0.5)/2 #current velocity; initialized with random
        
        self.err = self.ann.forward(self.position)  #compute error for initial position
        
        self.best_part_pos = np.copy(self.position) # intialize particle best position as intial position
        self.best_part_err = self.err  #intialized particle best error as self error from intial position
        
    # getter methods    
    #def getDim(self): return self.dim
    def getPosition(self):return self.position
    def getVelocity(self):return self.velocity
    def getError(self):return self.err
    def getBestPartErr(self):return self.best_part_err
    def getBestPartPos(self):return self.best_part_pos

    
    # setter methods    
    def setPosition(self,pos):self.position = np.copy(pos)
    def setVelocity(self,vel):self.velocity = np.copy(vel)
    def setError(self,err): self.err = err
    def setBestPartErr(self,best_err): self.best_part_err = best_err
    def setBestPartPos(self,best_pos): self.best_part_pos = best_pos

# %% [markdown]
# **Select function from User input**

# %%
'''
# Set function from User input
func = input('Choose the function name \n(Options: Linear, Cubic, Sine, TanH, XOR, Complex) = ')
'''
# Out:
# "\n# Set function from User input\nfunc = input('Choose the function name \n(Options: Linear, Cubic, Sine, TanH, XOR, Complex) = ')\n"

# %% [markdown]
# **Set Hyperparameters from User input**

# %%
'''
# Set Hyperparameters from User input

# set number of hidden layers
hidden_layers = int(input('Enter number of hidden layers = '))


# set number of neurons in the hidden layers
if(hidden_layers > 0):
    hidden_layer_neurons = []
    for layer in range(hidden_layers):
        hidden_layer_neurons.append(int(input('Enter number of nodes in hidden layer {}= '.format(layer+1))))
  
# set activation function
activation = input('Enter the activation function \n(Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian) = ')
'''
# Out:
# "\n# Set Hyperparameters from User input\n\n# set number of hidden layers\nhidden_layers = int(input('Enter number of hidden layers = '))\n\n\n# set number of neurons in the hidden layers\nif(hidden_layers > 0):\n    hidden_layer_neurons = []\n    for layer in range(hidden_layers):\n        hidden_layer_neurons.append(int(input('Enter number of nodes in hidden layer {}= '.format(layer+1))))\n  \n# set activation function\nactivation = input('Enter the activation function \n(Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian) = ')\n"

# %% [markdown]
# **Setting ANN Hyperparameters**

# %%
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)
hidden_layer_neurons = [7,7]
activation = 'Sigmoid' # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)

# %%
# to do: handling errors & exceptions

# %%
'''
#check only
for i in range(len(hidden_layer_neurons)):
    print("number of neurons in hidden layer {} is {}".format(i+1,hidden_layer_neurons[i]))
'''
# Out:
# '\n#check only\nfor i in range(len(hidden_layer_neurons)):\n    print("number of neurons in hidden layer {} is {}".format(i+1,hidden_layer_neurons[i]))\n'

# %%
activation_funcs = {
    'Null': lambda x: x*0,
    'Sigmoid': lambda x: 1/(1 + np.exp(-x)),
    'Hyperbolic Tangent': lambda x: np.tanh(x),
    'Cosine': lambda x: np.cos(x),
    'Gaussian': lambda x: np.exp(-x**2/2),
        }

# %%
'''
#check only
activate = activation_funcs[activation]
print ('Output: Selected activation -',activate(.5))

print('Output: Null -',(.5)*0
print('Output: Sigmoid -',1/(1 + np.exp(-.5)))
print('Output: Hyperbolic Tangent -',np.tanh(.5))
print('Output: Cosine -',np.cos(.5))
print('Output: Gaussian -',np.exp(-.5**2/2))
'''
# Out:
# "\n#check only\nactivate = activation_funcs[activation]\nprint ('Output: Selected activation -',activate(.5))\n\nprint('Output: Null -',(.5)*0\nprint('Output: Sigmoid -',1/(1 + np.exp(-.5)))\nprint('Output: Hyperbolic Tangent -',np.tanh(.5))\nprint('Output: Cosine -',np.cos(.5))\nprint('Output: Gaussian -',np.exp(-.5**2/2))\n"

# %% [markdown]
# **Reading data from the .txt file**

# %%
'''
# load the training data from .txt file into a list
def read_data(func):
txt_address = {'Linear':'Data/1in_linear.txt',
               'Cubic':'Data/1in_cubic.txt',
               'Sine':'Data/1in_sine.txt',
               'TanH':'Data/1in_tanh.txt',
               'XOR':'Data/2in_xor.txt',
               'Complex':'Data/2in_complex.txt'}

train_data_file = open(txt_address[func],'r')
line_data = train_data_file.readlines()
train_data_file.close()

train_list = []
for line in line_data:
    line = line.strip().split()
    for d in line:
        train_list.append(float(d))
        
#check     
#print(train_list)

if func in ('XOR','Complex'):
    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,3)
    X,Y = train_array[:,0:2], train_array[:,-1]

elif func in ('Linear', 'Cubic', 'Sine', 'TanH'):
    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,2)
    X,Y = train_array[:,0], train_array[:,-1]
else:
    "error reading data"
    
#print(train_array)
#print(X)
#print(Y)
'''
# Out:
# '\n# load the training data from .txt file into a list\ndef read_data(func):\ntxt_address = {\'Linear\':\'Data/1in_linear.txt\',\n               \'Cubic\':\'Data/1in_cubic.txt\',\n               \'Sine\':\'Data/1in_sine.txt\',\n               \'TanH\':\'Data/1in_tanh.txt\',\n               \'XOR\':\'Data/2in_xor.txt\',\n               \'Complex\':\'Data/2in_complex.txt\'}\n\ntrain_data_file = open(txt_address[func],\'r\')\nline_data = train_data_file.readlines()\ntrain_data_file.close()\n\ntrain_list = []\nfor line in line_data:\n    line = line.strip().split()\n    for d in line:\n        train_list.append(float(d))\n        \n#check     \n#print(train_list)\n\nif func in (\'XOR\',\'Complex\'):\n    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,3)\n    X,Y = train_array[:,0:2], train_array[:,-1]\n\nelif func in (\'Linear\', \'Cubic\', \'Sine\', \'TanH\'):\n    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,2)\n    X,Y = train_array[:,0], train_array[:,-1]\nelse:\n    "error reading data"\n    \n#print(train_array)\n#print(X)\n#print(Y)\n'

# %%
# load the training data from .txt file into a list
def read_data(func):
    txt_address = {'Linear':'Data/1in_linear.txt',
                   'Cubic':'Data/1in_cubic.txt',
                   'Sine':'Data/1in_sine.txt',
                   'TanH':'Data/1in_tanh.txt',
                   'XOR':'Data/2in_xor.txt',
                   'Complex':'Data/2in_complex.txt'}

    train_data_file = open(txt_address[func],'r')
    line_data = train_data_file.readlines()
    train_data_file.close()

    train_list = []
    for line in line_data:
        line = line.strip().split()
        for d in line:
            train_list.append(float(d))
        
    #check     
    #print(train_list)

    if func in ('XOR','Complex'):
        train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,3)
        X,Y = train_array[:,0:2], train_array[:,-1]

    elif func in ('Linear', 'Cubic', 'Sine', 'TanH'):
        train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,2)
        X,Y = train_array[:,0], train_array[:,-1]
    else:
        "error reading data"    
    #print(train_array)
    #print(X)
    #print(Y)
    
    return X,Y

# %%
X,Y = read_data(func)
#create instance of neural network
ann1 = NeuralNetwork(func, hidden_layer_neurons, activation, X,Y)

# %% [markdown]
# **Setting PSO Hyperparameters**

# %%
swarm_size = 15
pso_alpha = 0.9 #0.729
pso_beta = 1.6 #1.49
pso_delta = 1.6 #1.49

max_epochs = 150
bound =50

bound_max = bound
bound_min = -bound


pso1 = ParticleSwarmOptimizer(swarm_size,pso_alpha,pso_beta,pso_delta,max_epochs, bound_max, bound_min, ann1)

# %% [markdown]
# **Run PSO optimizer**

# %%
best_swarm_err, report, epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average= pso1.forward()

# %%
print(best_swarm_err)
# Out:
# 0.079642653465271

# %%
print(report)
# Out:
# Function:Cubic
# ANN Hyperparameters: activation function Sigmoid, layer arch [1, 7, 7, 1]
# PSO Hyperparameters: swarm size15, inertia weight0.9, cognitive weight1.6, social weight1.6, epochs150
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# epoch:001 ,particle:01, par err:0.5427, best part err:0.5427, best swarm err:0.3430
# epoch:001 ,particle:02, par err:0.3501, best part err:0.3501, best swarm err:0.3430
# epoch:001 ,particle:03, par err:0.3712, best part err:0.3712, best swarm err:0.3430
# epoch:001 ,particle:04, par err:0.3730, best part err:0.3730, best swarm err:0.3430
# epoch:001 ,particle:05, par err:0.3430, best part err:0.3430, best swarm err:0.3430
# epoch:001 ,particle:06, par err:0.3973, best part err:0.3973, best swarm err:0.3430
# epoch:001 ,particle:07, par err:0.4160, best part err:0.4160, best swarm err:0.3430
# epoch:001 ,particle:08, par err:0.4421, best part err:0.4421, best swarm err:0.3430
# epoch:001 ,particle:09, par err:0.3717, best part err:0.3717, best swarm err:0.3430
# epoch:001 ,particle:10, par err:0.4222, best part err:0.4222, best swarm err:0.3430
# epoch:001 ,particle:11, par err:0.3796, best part err:0.3796, best swarm err:0.3430
# epoch:001 ,particle:12, par err:0.3728, best part err:0.3728, best swarm err:0.3430
# epoch:001 ,particle:13, par err:0.3905, best part err:0.3905, best swarm err:0.3430
# epoch:001 ,particle:14, par err:0.4254, best part err:0.4254, best swarm err:0.3430
# epoch:001 ,particle:15, par err:0.3720, best part err:0.3720, best swarm err:0.3430
#
# -------------------------------------------------------------------------------------
# epoch:002 ,particle:01, par err:0.2843, best part err:0.2843, best swarm err:0.2441
# epoch:002 ,particle:02, par err:0.3366, best part err:0.3366, best swarm err:0.2441
# epoch:002 ,particle:03, par err:0.3458, best part err:0.3458, best swarm err:0.2441
# epoch:002 ,particle:04, par err:0.3475, best part err:0.3475, best swarm err:0.2441
# epoch:002 ,particle:05, par err:0.3559, best part err:0.3430, best swarm err:0.2441
# epoch:002 ,particle:06, par err:0.3636, best part err:0.3636, best swarm err:0.2441
# epoch:002 ,particle:07, par err:0.2441, best part err:0.2441, best swarm err:0.2441
# epoch:002 ,particle:08, par err:0.3036, best part err:0.3036, best swarm err:0.2441
# epoch:002 ,particle:09, par err:0.3292, best part err:0.3292, best swarm err:0.2441
# epoch:002 ,particle:10, par err:0.2872, best part err:0.2872, best swarm err:0.2441
# epoch:002 ,particle:11, par err:0.2860, best part err:0.2860, best swarm err:0.2441
# epoch:002 ,particle:12, par err:0.3270, best part err:0.3270, best swarm err:0.2441
# epoch:002 ,particle:13, par err:0.3222, best part err:0.3222, best swarm err:0.2441
# epoch:002 ,particle:14, par err:0.3271, best part err:0.3271, best swarm err:0.2441
# epoch:002 ,particle:15, par err:0.3652, best part err:0.3652, best swarm err:0.2441
#
# -------------------------------------------------------------------------------------
# epoch:003 ,particle:01, par err:0.1800, best part err:0.1800, best swarm err:0.1798
# epoch:003 ,particle:02, par err:0.2165, best part err:0.2165, best swarm err:0.1798
# epoch:003 ,particle:03, par err:0.1943, best part err:0.1943, best swarm err:0.1798
# epoch:003 ,particle:04, par err:0.2030, best part err:0.2030, best swarm err:0.1798
# epoch:003 ,particle:05, par err:0.2003, best part err:0.2003, best swarm err:0.1798
# epoch:003 ,particle:06, par err:0.2148, best part err:0.2148, best swarm err:0.1798
# epoch:003 ,particle:07, par err:0.1803, best part err:0.1803, best swarm err:0.1798
# epoch:003 ,particle:08, par err:0.1931, best part err:0.1931, best swarm err:0.1798
# epoch:003 ,particle:09, par err:0.1997, best part err:0.1997, best swarm err:0.1798
# epoch:003 ,particle:10, par err:0.1798, best part err:0.1798, best swarm err:0.1798
# epoch:003 ,particle:11, par err:0.1991, best part err:0.1991, best swarm err:0.1798
# epoch:003 ,particle:12, par err:0.2228, best part err:0.2228, best swarm err:0.1798
# epoch:003 ,particle:13, par err:0.2169, best part err:0.2169, best swarm err:0.1798
# epoch:003 ,particle:14, par err:0.1949, best part err:0.1949, best swarm err:0.1798
# epoch:003 ,particle:15, par err:0.2069, best part err:0.2069, best swarm err:0.1798
#
# -------------------------------------------------------------------------------------
# epoch:004 ,particle:01, par err:0.1552, best part err:0.1552, best swarm err:0.1552
# epoch:004 ,particle:02, par err:0.1575, best part err:0.1575, best swarm err:0.1552
# epoch:004 ,particle:03, par err:0.1574, best part err:0.1574, best swarm err:0.1552
# epoch:004 ,particle:04, par err:0.1580, best part err:0.1580, best swarm err:0.1552
# epoch:004 ,particle:05, par err:0.1553, best part err:0.1553, best swarm err:0.1552
# epoch:004 ,particle:06, par err:0.1574, best part err:0.1574, best swarm err:0.1552
# epoch:004 ,particle:07, par err:0.1606, best part err:0.1606, best swarm err:0.1552
# epoch:004 ,particle:08, par err:0.1556, best part err:0.1556, best swarm err:0.1552
# epoch:004 ,particle:09, par err:0.1586, best part err:0.1586, best swarm err:0.1552
# epoch:004 ,particle:10, par err:0.1594, best part err:0.1594, best swarm err:0.1552
# epoch:004 ,particle:11, par err:0.1610, best part err:0.1610, best swarm err:0.1552
# epoch:004 ,particle:12, par err:0.1573, best part err:0.1573, best swarm err:0.1552
# epoch:004 ,particle:13, par err:0.1557, best part err:0.1557, best swarm err:0.1552
# epoch:004 ,particle:14, par err:0.1554, best part err:0.1554, best swarm err:0.1552
# epoch:004 ,particle:15, par err:0.1572, best part err:0.1572, best swarm err:0.1552
#
# -------------------------------------------------------------------------------------
# epoch:005 ,particle:01, par err:0.1511, best part err:0.1511, best swarm err:0.1511
# epoch:005 ,particle:02, par err:0.1515, best part err:0.1515, best swarm err:0.1511
# epoch:005 ,particle:03, par err:0.1513, best part err:0.1513, best swarm err:0.1511
# epoch:005 ,particle:04, par err:0.1517, best part err:0.1517, best swarm err:0.1511
# epoch:005 ,particle:05, par err:0.1519, best part err:0.1519, best swarm err:0.1511
# epoch:005 ,particle:06, par err:0.1524, best part err:0.1524, best swarm err:0.1511
# epoch:005 ,particle:07, par err:0.1516, best part err:0.1516, best swarm err:0.1511
# epoch:005 ,particle:08, par err:0.1520, best part err:0.1520, best swarm err:0.1511
# epoch:005 ,particle:09, par err:0.1523, best part err:0.1523, best swarm err:0.1511
# epoch:005 ,particle:10, par err:0.1527, best part err:0.1527, best swarm err:0.1511
# epoch:005 ,particle:11, par err:0.1525, best part err:0.1525, best swarm err:0.1511
# epoch:005 ,particle:12, par err:0.1517, best part err:0.1517, best swarm err:0.1511
# epoch:005 ,particle:13, par err:0.1514, best part err:0.1514, best swarm err:0.1511
# epoch:005 ,particle:14, par err:0.1519, best part err:0.1519, best swarm err:0.1511
# epoch:005 ,particle:15, par err:0.1519, best part err:0.1519, best swarm err:0.1511
#
# -------------------------------------------------------------------------------------
# epoch:006 ,particle:01, par err:0.1512, best part err:0.1511, best swarm err:0.1511
# epoch:006 ,particle:02, par err:0.1512, best part err:0.1512, best swarm err:0.1511
# epoch:006 ,particle:03, par err:0.1514, best part err:0.1513, best swarm err:0.1511
# epoch:006 ,particle:04, par err:0.1513, best part err:0.1513, best swarm err:0.1511
# epoch:006 ,particle:05, par err:0.1513, best part err:0.1513, best swarm err:0.1511
# epoch:006 ,particle:06, par err:0.1511, best part err:0.1511, best swarm err:0.1511
# epoch:006 ,particle:07, par err:0.1513, best part err:0.1513, best swarm err:0.1511
# epoch:006 ,particle:08, par err:0.1512, best part err:0.1512, best swarm err:0.1511
# epoch:006 ,particle:09, par err:0.1511, best part err:0.1511, best swarm err:0.1511
# epoch:006 ,particle:10, par err:0.1513, best part err:0.1513, best swarm err:0.1511
# epoch:006 ,particle:11, par err:0.1513, best part err:0.1513, best swarm err:0.1511
# epoch:006 ,particle:12, par err:0.1512, best part err:0.1512, best swarm err:0.1511
# epoch:006 ,particle:13, par err:0.1513, best part err:0.1513, best swarm err:0.1511
# epoch:006 ,particle:14, par err:0.1512, best part err:0.1512, best swarm err:0.1511
# epoch:006 ,particle:15, par err:0.1512, best part err:0.1512, best swarm err:0.1511
#
# -------------------------------------------------------------------------------------
# epoch:007 ,particle:01, par err:0.1507, best part err:0.1507, best swarm err:0.1503
# epoch:007 ,particle:02, par err:0.1513, best part err:0.1512, best swarm err:0.1503
# epoch:007 ,particle:03, par err:0.1503, best part err:0.1503, best swarm err:0.1503
# epoch:007 ,particle:04, par err:0.1514, best part err:0.1513, best swarm err:0.1503
# epoch:007 ,particle:05, par err:0.1512, best part err:0.1512, best swarm err:0.1503
# epoch:007 ,particle:06, par err:0.1510, best part err:0.1510, best swarm err:0.1503
# epoch:007 ,particle:07, par err:0.1514, best part err:0.1513, best swarm err:0.1503
# epoch:007 ,particle:08, par err:0.1511, best part err:0.1511, best swarm err:0.1503
# epoch:007 ,particle:09, par err:0.1513, best part err:0.1511, best swarm err:0.1503
# epoch:007 ,particle:10, par err:0.1514, best part err:0.1513, best swarm err:0.1503
# epoch:007 ,particle:11, par err:0.1513, best part err:0.1513, best swarm err:0.1503
# epoch:007 ,particle:12, par err:0.1512, best part err:0.1512, best swarm err:0.1503
# epoch:007 ,particle:13, par err:0.1512, best part err:0.1512, best swarm err:0.1503
# epoch:007 ,particle:14, par err:0.1513, best part err:0.1512, best swarm err:0.1503
# epoch:007 ,particle:15, par err:0.1512, best part err:0.1512, best swarm err:0.1503
#
# -------------------------------------------------------------------------------------
# epoch:008 ,particle:01, par err:0.1497, best part err:0.1497, best swarm err:0.1492
# epoch:008 ,particle:02, par err:0.1590, best part err:0.1512, best swarm err:0.1492
# epoch:008 ,particle:03, par err:0.1508, best part err:0.1503, best swarm err:0.1492
# epoch:008 ,particle:04, par err:0.1607, best part err:0.1513, best swarm err:0.1492
# epoch:008 ,particle:05, par err:0.1495, best part err:0.1495, best swarm err:0.1492
# epoch:008 ,particle:06, par err:0.1496, best part err:0.1496, best swarm err:0.1492
# epoch:008 ,particle:07, par err:0.1651, best part err:0.1513, best swarm err:0.1492
# epoch:008 ,particle:08, par err:0.1499, best part err:0.1499, best swarm err:0.1492
# epoch:008 ,particle:09, par err:0.1620, best part err:0.1511, best swarm err:0.1492
# epoch:008 ,particle:10, par err:0.1688, best part err:0.1513, best swarm err:0.1492
# epoch:008 ,particle:11, par err:0.1632, best part err:0.1513, best swarm err:0.1492
# epoch:008 ,particle:12, par err:0.1590, best part err:0.1512, best swarm err:0.1492
# epoch:008 ,particle:13, par err:0.1492, best part err:0.1492, best swarm err:0.1492
# epoch:008 ,particle:14, par err:0.1670, best part err:0.1512, best swarm err:0.1492
# epoch:008 ,particle:15, par err:0.1591, best part err:0.1512, best swarm err:0.1492
#
# -------------------------------------------------------------------------------------
# epoch:009 ,particle:01, par err:0.1518, best part err:0.1497, best swarm err:0.1492
# epoch:009 ,particle:02, par err:0.1509, best part err:0.1509, best swarm err:0.1492
# epoch:009 ,particle:03, par err:0.1505, best part err:0.1503, best swarm err:0.1492
# epoch:009 ,particle:04, par err:0.1511, best part err:0.1511, best swarm err:0.1492
# epoch:009 ,particle:05, par err:0.1681, best part err:0.1495, best swarm err:0.1492
# epoch:009 ,particle:06, par err:0.1658, best part err:0.1496, best swarm err:0.1492
# epoch:009 ,particle:07, par err:0.1512, best part err:0.1512, best swarm err:0.1492
# epoch:009 ,particle:08, par err:0.1629, best part err:0.1499, best swarm err:0.1492
# epoch:009 ,particle:09, par err:0.1507, best part err:0.1507, best swarm err:0.1492
# epoch:009 ,particle:10, par err:0.1511, best part err:0.1511, best swarm err:0.1492
# epoch:009 ,particle:11, par err:0.1510, best part err:0.1510, best swarm err:0.1492
# epoch:009 ,particle:12, par err:0.1506, best part err:0.1506, best swarm err:0.1492
# epoch:009 ,particle:13, par err:0.1621, best part err:0.1492, best swarm err:0.1492
# epoch:009 ,particle:14, par err:0.1508, best part err:0.1508, best swarm err:0.1492
# epoch:009 ,particle:15, par err:0.1507, best part err:0.1507, best swarm err:0.1492
#
# -------------------------------------------------------------------------------------
# epoch:010 ,particle:01, par err:0.1510, best part err:0.1497, best swarm err:0.1492
# epoch:010 ,particle:02, par err:0.1499, best part err:0.1499, best swarm err:0.1492
# epoch:010 ,particle:03, par err:0.1505, best part err:0.1503, best swarm err:0.1492
# epoch:010 ,particle:04, par err:0.1506, best part err:0.1506, best swarm err:0.1492
# epoch:010 ,particle:05, par err:0.1513, best part err:0.1495, best swarm err:0.1492
# epoch:010 ,particle:06, par err:0.1512, best part err:0.1496, best swarm err:0.1492
# epoch:010 ,particle:07, par err:0.1505, best part err:0.1505, best swarm err:0.1492
# epoch:010 ,particle:08, par err:0.1513, best part err:0.1499, best swarm err:0.1492
# epoch:010 ,particle:09, par err:0.1502, best part err:0.1502, best swarm err:0.1492
# epoch:010 ,particle:10, par err:0.1503, best part err:0.1503, best swarm err:0.1492
# epoch:010 ,particle:11, par err:0.1502, best part err:0.1502, best swarm err:0.1492
# epoch:010 ,particle:12, par err:0.1497, best part err:0.1497, best swarm err:0.1492
# epoch:010 ,particle:13, par err:0.1513, best part err:0.1492, best swarm err:0.1492
# epoch:010 ,particle:14, par err:0.1499, best part err:0.1499, best swarm err:0.1492
# epoch:010 ,particle:15, par err:0.1496, best part err:0.1496, best swarm err:0.1492
#
# -------------------------------------------------------------------------------------
# epoch:011 ,particle:01, par err:0.1513, best part err:0.1497, best swarm err:0.1492
# epoch:011 ,particle:02, par err:0.1562, best part err:0.1499, best swarm err:0.1492
# epoch:011 ,particle:03, par err:0.1494, best part err:0.1494, best swarm err:0.1492
# epoch:011 ,particle:04, par err:0.1550, best part err:0.1506, best swarm err:0.1492
# epoch:011 ,particle:05, par err:0.1606, best part err:0.1495, best swarm err:0.1492
# epoch:011 ,particle:06, par err:0.1593, best part err:0.1496, best swarm err:0.1492
# epoch:011 ,particle:07, par err:0.1555, best part err:0.1505, best swarm err:0.1492
# epoch:011 ,particle:08, par err:0.1568, best part err:0.1499, best swarm err:0.1492
# epoch:011 ,particle:09, par err:0.1561, best part err:0.1502, best swarm err:0.1492
# epoch:011 ,particle:10, par err:0.1567, best part err:0.1503, best swarm err:0.1492
# epoch:011 ,particle:11, par err:0.1578, best part err:0.1502, best swarm err:0.1492
# epoch:011 ,particle:12, par err:0.1555, best part err:0.1497, best swarm err:0.1492
# epoch:011 ,particle:13, par err:0.1576, best part err:0.1492, best swarm err:0.1492
# epoch:011 ,particle:14, par err:0.1548, best part err:0.1499, best swarm err:0.1492
# epoch:011 ,particle:15, par err:0.1551, best part err:0.1496, best swarm err:0.1492
#
# -------------------------------------------------------------------------------------
# epoch:012 ,particle:01, par err:0.1493, best part err:0.1493, best swarm err:0.1483
# epoch:012 ,particle:02, par err:0.1512, best part err:0.1499, best swarm err:0.1483
# epoch:012 ,particle:03, par err:0.1483, best part err:0.1483, best swarm err:0.1483
# epoch:012 ,particle:04, par err:0.1514, best part err:0.1506, best swarm err:0.1483
# epoch:012 ,particle:05, par err:0.1495, best part err:0.1495, best swarm err:0.1483
# epoch:012 ,particle:06, par err:0.1497, best part err:0.1496, best swarm err:0.1483
# epoch:012 ,particle:07, par err:0.1514, best part err:0.1505, best swarm err:0.1483
# epoch:012 ,particle:08, par err:0.1495, best part err:0.1495, best swarm err:0.1483
# epoch:012 ,particle:09, par err:0.1511, best part err:0.1502, best swarm err:0.1483
# epoch:012 ,particle:10, par err:0.1513, best part err:0.1503, best swarm err:0.1483
# epoch:012 ,particle:11, par err:0.1513, best part err:0.1502, best swarm err:0.1483
# epoch:012 ,particle:12, par err:0.1510, best part err:0.1497, best swarm err:0.1483
# epoch:012 ,particle:13, par err:0.1494, best part err:0.1492, best swarm err:0.1483
# epoch:012 ,particle:14, par err:0.1511, best part err:0.1499, best swarm err:0.1483
# epoch:012 ,particle:15, par err:0.1511, best part err:0.1496, best swarm err:0.1483
#
# -------------------------------------------------------------------------------------
# epoch:013 ,particle:01, par err:0.1494, best part err:0.1493, best swarm err:0.1460
# epoch:013 ,particle:02, par err:0.1464, best part err:0.1464, best swarm err:0.1460
# epoch:013 ,particle:03, par err:0.1475, best part err:0.1475, best swarm err:0.1460
# epoch:013 ,particle:04, par err:0.1478, best part err:0.1478, best swarm err:0.1460
# epoch:013 ,particle:05, par err:0.1507, best part err:0.1495, best swarm err:0.1460
# epoch:013 ,particle:06, par err:0.1505, best part err:0.1496, best swarm err:0.1460
# epoch:013 ,particle:07, par err:0.1460, best part err:0.1460, best swarm err:0.1460
# epoch:013 ,particle:08, par err:0.1495, best part err:0.1495, best swarm err:0.1460
# epoch:013 ,particle:09, par err:0.1477, best part err:0.1477, best swarm err:0.1460
# epoch:013 ,particle:10, par err:0.1473, best part err:0.1473, best swarm err:0.1460
# epoch:013 ,particle:11, par err:0.1465, best part err:0.1465, best swarm err:0.1460
# epoch:013 ,particle:12, par err:0.1469, best part err:0.1469, best swarm err:0.1460
# epoch:013 ,particle:13, par err:0.1507, best part err:0.1492, best swarm err:0.1460
# epoch:013 ,particle:14, par err:0.1471, best part err:0.1471, best swarm err:0.1460
# epoch:013 ,particle:15, par err:0.1460, best part err:0.1460, best swarm err:0.1460
#
# -------------------------------------------------------------------------------------
# epoch:014 ,particle:01, par err:0.1431, best part err:0.1431, best swarm err:0.1317
# epoch:014 ,particle:02, par err:0.1385, best part err:0.1385, best swarm err:0.1317
# epoch:014 ,particle:03, par err:0.1441, best part err:0.1441, best swarm err:0.1317
# epoch:014 ,particle:04, par err:0.1317, best part err:0.1317, best swarm err:0.1317
# epoch:014 ,particle:05, par err:0.1463, best part err:0.1463, best swarm err:0.1317
# epoch:014 ,particle:06, par err:0.1479, best part err:0.1479, best swarm err:0.1317
# epoch:014 ,particle:07, par err:0.1429, best part err:0.1429, best swarm err:0.1317
# epoch:014 ,particle:08, par err:0.1445, best part err:0.1445, best swarm err:0.1317
# epoch:014 ,particle:09, par err:0.1393, best part err:0.1393, best swarm err:0.1317
# epoch:014 ,particle:10, par err:0.1356, best part err:0.1356, best swarm err:0.1317
# epoch:014 ,particle:11, par err:0.1484, best part err:0.1465, best swarm err:0.1317
# epoch:014 ,particle:12, par err:0.1412, best part err:0.1412, best swarm err:0.1317
# epoch:014 ,particle:13, par err:0.1445, best part err:0.1445, best swarm err:0.1317
# epoch:014 ,particle:14, par err:0.1382, best part err:0.1382, best swarm err:0.1317
# epoch:014 ,particle:15, par err:0.1434, best part err:0.1434, best swarm err:0.1317
#
# -------------------------------------------------------------------------------------
# epoch:015 ,particle:01, par err:0.1440, best part err:0.1431, best swarm err:0.1169
# epoch:015 ,particle:02, par err:0.1586, best part err:0.1385, best swarm err:0.1169
# epoch:015 ,particle:03, par err:0.1169, best part err:0.1169, best swarm err:0.1169
# epoch:015 ,particle:04, par err:0.1547, best part err:0.1317, best swarm err:0.1169
# epoch:015 ,particle:05, par err:0.1749, best part err:0.1463, best swarm err:0.1169
# epoch:015 ,particle:06, par err:0.1717, best part err:0.1479, best swarm err:0.1169
# epoch:015 ,particle:07, par err:0.1667, best part err:0.1429, best swarm err:0.1169
# epoch:015 ,particle:08, par err:0.1583, best part err:0.1445, best swarm err:0.1169
# epoch:015 ,particle:09, par err:0.1552, best part err:0.1393, best swarm err:0.1169
# epoch:015 ,particle:10, par err:0.1617, best part err:0.1356, best swarm err:0.1169
# epoch:015 ,particle:11, par err:0.1367, best part err:0.1367, best swarm err:0.1169
# epoch:015 ,particle:12, par err:0.1492, best part err:0.1412, best swarm err:0.1169
# epoch:015 ,particle:13, par err:0.1700, best part err:0.1445, best swarm err:0.1169
# epoch:015 ,particle:14, par err:0.1594, best part err:0.1382, best swarm err:0.1169
# epoch:015 ,particle:15, par err:0.1543, best part err:0.1434, best swarm err:0.1169
#
# -------------------------------------------------------------------------------------
# epoch:016 ,particle:01, par err:0.1375, best part err:0.1375, best swarm err:0.0986
# epoch:016 ,particle:02, par err:0.1213, best part err:0.1213, best swarm err:0.0986
# epoch:016 ,particle:03, par err:0.1736, best part err:0.1169, best swarm err:0.0986
# epoch:016 ,particle:04, par err:0.1265, best part err:0.1265, best swarm err:0.0986
# epoch:016 ,particle:05, par err:0.1455, best part err:0.1455, best swarm err:0.0986
# epoch:016 ,particle:06, par err:0.1439, best part err:0.1439, best swarm err:0.0986
# epoch:016 ,particle:07, par err:0.1128, best part err:0.1128, best swarm err:0.0986
# epoch:016 ,particle:08, par err:0.1376, best part err:0.1376, best swarm err:0.0986
# epoch:016 ,particle:09, par err:0.1273, best part err:0.1273, best swarm err:0.0986
# epoch:016 ,particle:10, par err:0.1272, best part err:0.1272, best swarm err:0.0986
# epoch:016 ,particle:11, par err:0.0986, best part err:0.0986, best swarm err:0.0986
# epoch:016 ,particle:12, par err:0.1273, best part err:0.1273, best swarm err:0.0986
# epoch:016 ,particle:13, par err:0.1418, best part err:0.1418, best swarm err:0.0986
# epoch:016 ,particle:14, par err:0.1275, best part err:0.1275, best swarm err:0.0986
# epoch:016 ,particle:15, par err:0.1226, best part err:0.1226, best swarm err:0.0986
#
# -------------------------------------------------------------------------------------
# epoch:017 ,particle:01, par err:0.0868, best part err:0.0868, best swarm err:0.0847
# epoch:017 ,particle:02, par err:0.0915, best part err:0.0915, best swarm err:0.0847
# epoch:017 ,particle:03, par err:0.1359, best part err:0.1169, best swarm err:0.0847
# epoch:017 ,particle:04, par err:0.0866, best part err:0.0866, best swarm err:0.0847
# epoch:017 ,particle:05, par err:0.1029, best part err:0.1029, best swarm err:0.0847
# epoch:017 ,particle:06, par err:0.0945, best part err:0.0945, best swarm err:0.0847
# epoch:017 ,particle:07, par err:0.1008, best part err:0.1008, best swarm err:0.0847
# epoch:017 ,particle:08, par err:0.0871, best part err:0.0871, best swarm err:0.0847
# epoch:017 ,particle:09, par err:0.0868, best part err:0.0868, best swarm err:0.0847
# epoch:017 ,particle:10, par err:0.0870, best part err:0.0870, best swarm err:0.0847
# epoch:017 ,particle:11, par err:0.1175, best part err:0.0986, best swarm err:0.0847
# epoch:017 ,particle:12, par err:0.0882, best part err:0.0882, best swarm err:0.0847
# epoch:017 ,particle:13, par err:0.0882, best part err:0.0882, best swarm err:0.0847
# epoch:017 ,particle:14, par err:0.0847, best part err:0.0847, best swarm err:0.0847
# epoch:017 ,particle:15, par err:0.0929, best part err:0.0929, best swarm err:0.0847
#
# -------------------------------------------------------------------------------------
# epoch:018 ,particle:01, par err:0.0953, best part err:0.0868, best swarm err:0.0847
# epoch:018 ,particle:02, par err:0.0920, best part err:0.0915, best swarm err:0.0847
# epoch:018 ,particle:03, par err:0.1068, best part err:0.1068, best swarm err:0.0847
# epoch:018 ,particle:04, par err:0.0967, best part err:0.0866, best swarm err:0.0847
# epoch:018 ,particle:05, par err:0.0945, best part err:0.0945, best swarm err:0.0847
# epoch:018 ,particle:06, par err:0.0947, best part err:0.0945, best swarm err:0.0847
# epoch:018 ,particle:07, par err:0.0906, best part err:0.0906, best swarm err:0.0847
# epoch:018 ,particle:08, par err:0.0938, best part err:0.0871, best swarm err:0.0847
# epoch:018 ,particle:09, par err:0.0962, best part err:0.0868, best swarm err:0.0847
# epoch:018 ,particle:10, par err:0.0940, best part err:0.0870, best swarm err:0.0847
# epoch:018 ,particle:11, par err:0.1495, best part err:0.0986, best swarm err:0.0847
# epoch:018 ,particle:12, par err:0.0986, best part err:0.0882, best swarm err:0.0847
# epoch:018 ,particle:13, par err:0.0931, best part err:0.0882, best swarm err:0.0847
# epoch:018 ,particle:14, par err:0.0974, best part err:0.0847, best swarm err:0.0847
# epoch:018 ,particle:15, par err:0.0989, best part err:0.0929, best swarm err:0.0847
#
# -------------------------------------------------------------------------------------
# epoch:019 ,particle:01, par err:0.1455, best part err:0.0868, best swarm err:0.0847
# epoch:019 ,particle:02, par err:0.1315, best part err:0.0915, best swarm err:0.0847
# epoch:019 ,particle:03, par err:0.1344, best part err:0.1068, best swarm err:0.0847
# epoch:019 ,particle:04, par err:0.1386, best part err:0.0866, best swarm err:0.0847
# epoch:019 ,particle:05, par err:0.1119, best part err:0.0945, best swarm err:0.0847
# epoch:019 ,particle:06, par err:0.1495, best part err:0.0945, best swarm err:0.0847
# epoch:019 ,particle:07, par err:0.0950, best part err:0.0906, best swarm err:0.0847
# epoch:019 ,particle:08, par err:0.1454, best part err:0.0871, best swarm err:0.0847
# epoch:019 ,particle:09, par err:0.1377, best part err:0.0868, best swarm err:0.0847
# epoch:019 ,particle:10, par err:0.1379, best part err:0.0870, best swarm err:0.0847
# epoch:019 ,particle:11, par err:0.1352, best part err:0.0986, best swarm err:0.0847
# epoch:019 ,particle:12, par err:0.1368, best part err:0.0882, best swarm err:0.0847
# epoch:019 ,particle:13, par err:0.1494, best part err:0.0882, best swarm err:0.0847
# epoch:019 ,particle:14, par err:0.1366, best part err:0.0847, best swarm err:0.0847
# epoch:019 ,particle:15, par err:0.1304, best part err:0.0929, best swarm err:0.0847
#
# -------------------------------------------------------------------------------------
# epoch:020 ,particle:01, par err:0.1033, best part err:0.0868, best swarm err:0.0847
# epoch:020 ,particle:02, par err:0.1018, best part err:0.0915, best swarm err:0.0847
# epoch:020 ,particle:03, par err:0.1381, best part err:0.1068, best swarm err:0.0847
# epoch:020 ,particle:04, par err:0.1047, best part err:0.0866, best swarm err:0.0847
# epoch:020 ,particle:05, par err:0.0868, best part err:0.0868, best swarm err:0.0847
# epoch:020 ,particle:06, par err:0.1244, best part err:0.0945, best swarm err:0.0847
# epoch:020 ,particle:07, par err:0.1179, best part err:0.0906, best swarm err:0.0847
# epoch:020 ,particle:08, par err:0.1157, best part err:0.0871, best swarm err:0.0847
# epoch:020 ,particle:09, par err:0.1065, best part err:0.0868, best swarm err:0.0847
# epoch:020 ,particle:10, par err:0.1038, best part err:0.0870, best swarm err:0.0847
# epoch:020 ,particle:11, par err:0.0880, best part err:0.0880, best swarm err:0.0847
# epoch:020 ,particle:12, par err:0.1026, best part err:0.0882, best swarm err:0.0847
# epoch:020 ,particle:13, par err:0.1172, best part err:0.0882, best swarm err:0.0847
# epoch:020 ,particle:14, par err:0.0957, best part err:0.0847, best swarm err:0.0847
# epoch:020 ,particle:15, par err:0.1106, best part err:0.0929, best swarm err:0.0847
#
# -------------------------------------------------------------------------------------
# epoch:021 ,particle:01, par err:0.0870, best part err:0.0868, best swarm err:0.0847
# epoch:021 ,particle:02, par err:0.0864, best part err:0.0864, best swarm err:0.0847
# epoch:021 ,particle:03, par err:0.1502, best part err:0.1068, best swarm err:0.0847
# epoch:021 ,particle:04, par err:0.0864, best part err:0.0864, best swarm err:0.0847
# epoch:021 ,particle:05, par err:0.1252, best part err:0.0868, best swarm err:0.0847
# epoch:021 ,particle:06, par err:0.0873, best part err:0.0873, best swarm err:0.0847
# epoch:021 ,particle:07, par err:0.0937, best part err:0.0906, best swarm err:0.0847
# epoch:021 ,particle:08, par err:0.0872, best part err:0.0871, best swarm err:0.0847
# epoch:021 ,particle:09, par err:0.0865, best part err:0.0865, best swarm err:0.0847
# epoch:021 ,particle:10, par err:0.0864, best part err:0.0864, best swarm err:0.0847
# epoch:021 ,particle:11, par err:0.1456, best part err:0.0880, best swarm err:0.0847
# epoch:021 ,particle:12, par err:0.0866, best part err:0.0866, best swarm err:0.0847
# epoch:021 ,particle:13, par err:0.0871, best part err:0.0871, best swarm err:0.0847
# epoch:021 ,particle:14, par err:0.0863, best part err:0.0847, best swarm err:0.0847
# epoch:021 ,particle:15, par err:0.0868, best part err:0.0868, best swarm err:0.0847
#
# -------------------------------------------------------------------------------------
# epoch:022 ,particle:01, par err:0.1299, best part err:0.0868, best swarm err:0.0847
# epoch:022 ,particle:02, par err:0.1013, best part err:0.0864, best swarm err:0.0847
# epoch:022 ,particle:03, par err:0.0864, best part err:0.0864, best swarm err:0.0847
# epoch:022 ,particle:04, par err:0.1003, best part err:0.0864, best swarm err:0.0847
# epoch:022 ,particle:05, par err:0.1046, best part err:0.0868, best swarm err:0.0847
# epoch:022 ,particle:06, par err:0.1105, best part err:0.0873, best swarm err:0.0847
# epoch:022 ,particle:07, par err:0.0850, best part err:0.0850, best swarm err:0.0847
# epoch:022 ,particle:08, par err:0.1302, best part err:0.0871, best swarm err:0.0847
# epoch:022 ,particle:09, par err:0.1027, best part err:0.0865, best swarm err:0.0847
# epoch:022 ,particle:10, par err:0.1007, best part err:0.0864, best swarm err:0.0847
# epoch:022 ,particle:11, par err:0.1579, best part err:0.0880, best swarm err:0.0847
# epoch:022 ,particle:12, par err:0.1031, best part err:0.0866, best swarm err:0.0847
# epoch:022 ,particle:13, par err:0.1084, best part err:0.0871, best swarm err:0.0847
# epoch:022 ,particle:14, par err:0.1149, best part err:0.0847, best swarm err:0.0847
# epoch:022 ,particle:15, par err:0.1080, best part err:0.0868, best swarm err:0.0847
#
# -------------------------------------------------------------------------------------
# epoch:023 ,particle:01, par err:0.0996, best part err:0.0868, best swarm err:0.0847
# epoch:023 ,particle:02, par err:0.1051, best part err:0.0864, best swarm err:0.0847
# epoch:023 ,particle:03, par err:0.1332, best part err:0.0864, best swarm err:0.0847
# epoch:023 ,particle:04, par err:0.1099, best part err:0.0864, best swarm err:0.0847
# epoch:023 ,particle:05, par err:0.1234, best part err:0.0868, best swarm err:0.0847
# epoch:023 ,particle:06, par err:0.1365, best part err:0.0873, best swarm err:0.0847
# epoch:023 ,particle:07, par err:0.0914, best part err:0.0850, best swarm err:0.0847
# epoch:023 ,particle:08, par err:0.1042, best part err:0.0871, best swarm err:0.0847
# epoch:023 ,particle:09, par err:0.1123, best part err:0.0865, best swarm err:0.0847
# epoch:023 ,particle:10, par err:0.1084, best part err:0.0864, best swarm err:0.0847
# epoch:023 ,particle:11, par err:0.1206, best part err:0.0880, best swarm err:0.0847
# epoch:023 ,particle:12, par err:0.1061, best part err:0.0866, best swarm err:0.0847
# epoch:023 ,particle:13, par err:0.1259, best part err:0.0871, best swarm err:0.0847
# epoch:023 ,particle:14, par err:0.0976, best part err:0.0847, best swarm err:0.0847
# epoch:023 ,particle:15, par err:0.1167, best part err:0.0868, best swarm err:0.0847
#
# -------------------------------------------------------------------------------------
# epoch:024 ,particle:01, par err:0.1016, best part err:0.0868, best swarm err:0.0833
# epoch:024 ,particle:02, par err:0.0901, best part err:0.0864, best swarm err:0.0833
# epoch:024 ,particle:03, par err:0.1594, best part err:0.0864, best swarm err:0.0833
# epoch:024 ,particle:04, par err:0.0900, best part err:0.0864, best swarm err:0.0833
# epoch:024 ,particle:05, par err:0.0838, best part err:0.0838, best swarm err:0.0833
# epoch:024 ,particle:06, par err:0.0957, best part err:0.0873, best swarm err:0.0833
# epoch:024 ,particle:07, par err:0.1003, best part err:0.0850, best swarm err:0.0833
# epoch:024 ,particle:08, par err:0.1025, best part err:0.0871, best swarm err:0.0833
# epoch:024 ,particle:09, par err:0.0911, best part err:0.0865, best swarm err:0.0833
# epoch:024 ,particle:10, par err:0.0901, best part err:0.0864, best swarm err:0.0833
# epoch:024 ,particle:11, par err:0.0833, best part err:0.0833, best swarm err:0.0833
# epoch:024 ,particle:12, par err:0.0907, best part err:0.0866, best swarm err:0.0833
# epoch:024 ,particle:13, par err:0.0942, best part err:0.0871, best swarm err:0.0833
# epoch:024 ,particle:14, par err:0.0939, best part err:0.0847, best swarm err:0.0833
# epoch:024 ,particle:15, par err:0.0936, best part err:0.0868, best swarm err:0.0833
#
# -------------------------------------------------------------------------------------
# epoch:025 ,particle:01, par err:0.0996, best part err:0.0868, best swarm err:0.0833
# epoch:025 ,particle:02, par err:0.0848, best part err:0.0848, best swarm err:0.0833
# epoch:025 ,particle:03, par err:0.1288, best part err:0.0864, best swarm err:0.0833
# epoch:025 ,particle:04, par err:0.0848, best part err:0.0848, best swarm err:0.0833
# epoch:025 ,particle:05, par err:0.1237, best part err:0.0838, best swarm err:0.0833
# epoch:025 ,particle:06, par err:0.0851, best part err:0.0851, best swarm err:0.0833
# epoch:025 ,particle:07, par err:0.0948, best part err:0.0850, best swarm err:0.0833
# epoch:025 ,particle:08, par err:0.1046, best part err:0.0871, best swarm err:0.0833
# epoch:025 ,particle:09, par err:0.0849, best part err:0.0849, best swarm err:0.0833
# epoch:025 ,particle:10, par err:0.0848, best part err:0.0848, best swarm err:0.0833
# epoch:025 ,particle:11, par err:0.0906, best part err:0.0833, best swarm err:0.0833
# epoch:025 ,particle:12, par err:0.0850, best part err:0.0850, best swarm err:0.0833
# epoch:025 ,particle:13, par err:0.0851, best part err:0.0851, best swarm err:0.0833
# epoch:025 ,particle:14, par err:0.0891, best part err:0.0847, best swarm err:0.0833
# epoch:025 ,particle:15, par err:0.0852, best part err:0.0852, best swarm err:0.0833
#
# -------------------------------------------------------------------------------------
# epoch:026 ,particle:01, par err:0.0963, best part err:0.0868, best swarm err:0.0833
# epoch:026 ,particle:02, par err:0.0854, best part err:0.0848, best swarm err:0.0833
# epoch:026 ,particle:03, par err:0.0846, best part err:0.0846, best swarm err:0.0833
# epoch:026 ,particle:04, par err:0.0848, best part err:0.0848, best swarm err:0.0833
# epoch:026 ,particle:05, par err:0.1268, best part err:0.0838, best swarm err:0.0833
# epoch:026 ,particle:06, par err:0.0861, best part err:0.0851, best swarm err:0.0833
# epoch:026 ,particle:07, par err:0.0853, best part err:0.0850, best swarm err:0.0833
# epoch:026 ,particle:08, par err:0.0977, best part err:0.0871, best swarm err:0.0833
# epoch:026 ,particle:09, par err:0.0853, best part err:0.0849, best swarm err:0.0833
# epoch:026 ,particle:10, par err:0.0850, best part err:0.0848, best swarm err:0.0833
# epoch:026 ,particle:11, par err:0.1305, best part err:0.0833, best swarm err:0.0833
# epoch:026 ,particle:12, par err:0.0858, best part err:0.0850, best swarm err:0.0833
# epoch:026 ,particle:13, par err:0.0863, best part err:0.0851, best swarm err:0.0833
# epoch:026 ,particle:14, par err:0.0952, best part err:0.0847, best swarm err:0.0833
# epoch:026 ,particle:15, par err:0.0871, best part err:0.0852, best swarm err:0.0833
#
# -------------------------------------------------------------------------------------
# epoch:027 ,particle:01, par err:0.1286, best part err:0.0868, best swarm err:0.0833
# epoch:027 ,particle:02, par err:0.0944, best part err:0.0848, best swarm err:0.0833
# epoch:027 ,particle:03, par err:0.1005, best part err:0.0846, best swarm err:0.0833
# epoch:027 ,particle:04, par err:0.0939, best part err:0.0848, best swarm err:0.0833
# epoch:027 ,particle:05, par err:0.1025, best part err:0.0838, best swarm err:0.0833
# epoch:027 ,particle:06, par err:0.1020, best part err:0.0851, best swarm err:0.0833
# epoch:027 ,particle:07, par err:0.0895, best part err:0.0850, best swarm err:0.0833
# epoch:027 ,particle:08, par err:0.1294, best part err:0.0871, best swarm err:0.0833
# epoch:027 ,particle:09, par err:0.0955, best part err:0.0849, best swarm err:0.0833
# epoch:027 ,particle:10, par err:0.0941, best part err:0.0848, best swarm err:0.0833
# epoch:027 ,particle:11, par err:0.0887, best part err:0.0833, best swarm err:0.0833
# epoch:027 ,particle:12, par err:0.0953, best part err:0.0850, best swarm err:0.0833
# epoch:027 ,particle:13, par err:0.1000, best part err:0.0851, best swarm err:0.0833
# epoch:027 ,particle:14, par err:0.1155, best part err:0.0847, best swarm err:0.0833
# epoch:027 ,particle:15, par err:0.0994, best part err:0.0852, best swarm err:0.0833
#
# -------------------------------------------------------------------------------------
# epoch:028 ,particle:01, par err:0.0911, best part err:0.0868, best swarm err:0.0828
# epoch:028 ,particle:02, par err:0.0830, best part err:0.0830, best swarm err:0.0828
# epoch:028 ,particle:03, par err:0.1346, best part err:0.0846, best swarm err:0.0828
# epoch:028 ,particle:04, par err:0.0828, best part err:0.0828, best swarm err:0.0828
# epoch:028 ,particle:05, par err:0.0838, best part err:0.0838, best swarm err:0.0828
# epoch:028 ,particle:06, par err:0.0830, best part err:0.0830, best swarm err:0.0828
# epoch:028 ,particle:07, par err:0.0987, best part err:0.0850, best swarm err:0.0828
# epoch:028 ,particle:08, par err:0.0926, best part err:0.0871, best swarm err:0.0828
# epoch:028 ,particle:09, par err:0.0828, best part err:0.0828, best swarm err:0.0828
# epoch:028 ,particle:10, par err:0.0828, best part err:0.0828, best swarm err:0.0828
# epoch:028 ,particle:11, par err:0.0839, best part err:0.0833, best swarm err:0.0828
# epoch:028 ,particle:12, par err:0.0830, best part err:0.0830, best swarm err:0.0828
# epoch:028 ,particle:13, par err:0.0831, best part err:0.0831, best swarm err:0.0828
# epoch:028 ,particle:14, par err:0.0874, best part err:0.0847, best swarm err:0.0828
# epoch:028 ,particle:15, par err:0.0831, best part err:0.0831, best swarm err:0.0828
#
# -------------------------------------------------------------------------------------
# epoch:029 ,particle:01, par err:0.0971, best part err:0.0868, best swarm err:0.0828
# epoch:029 ,particle:02, par err:0.0887, best part err:0.0830, best swarm err:0.0828
# epoch:029 ,particle:03, par err:0.0879, best part err:0.0846, best swarm err:0.0828
# epoch:029 ,particle:04, par err:0.0872, best part err:0.0828, best swarm err:0.0828
# epoch:029 ,particle:05, par err:0.1259, best part err:0.0838, best swarm err:0.0828
# epoch:029 ,particle:06, par err:0.0870, best part err:0.0830, best swarm err:0.0828
# epoch:029 ,particle:07, par err:0.0873, best part err:0.0850, best swarm err:0.0828
# epoch:029 ,particle:08, par err:0.0987, best part err:0.0871, best swarm err:0.0828
# epoch:029 ,particle:09, par err:0.0881, best part err:0.0828, best swarm err:0.0828
# epoch:029 ,particle:10, par err:0.0878, best part err:0.0828, best swarm err:0.0828
# epoch:029 ,particle:11, par err:0.1250, best part err:0.0833, best swarm err:0.0828
# epoch:029 ,particle:12, par err:0.0910, best part err:0.0830, best swarm err:0.0828
# epoch:029 ,particle:13, par err:0.0886, best part err:0.0831, best swarm err:0.0828
# epoch:029 ,particle:14, par err:0.0944, best part err:0.0847, best swarm err:0.0828
# epoch:029 ,particle:15, par err:0.0933, best part err:0.0831, best swarm err:0.0828
#
# -------------------------------------------------------------------------------------
# epoch:030 ,particle:01, par err:0.1247, best part err:0.0868, best swarm err:0.0828
# epoch:030 ,particle:02, par err:0.0992, best part err:0.0830, best swarm err:0.0828
# epoch:030 ,particle:03, par err:0.0847, best part err:0.0846, best swarm err:0.0828
# epoch:030 ,particle:04, par err:0.0985, best part err:0.0828, best swarm err:0.0828
# epoch:030 ,particle:05, par err:0.1281, best part err:0.0838, best swarm err:0.0828
# epoch:030 ,particle:06, par err:0.1080, best part err:0.0830, best swarm err:0.0828
# epoch:030 ,particle:07, par err:0.0847, best part err:0.0847, best swarm err:0.0828
# epoch:030 ,particle:08, par err:0.1256, best part err:0.0871, best swarm err:0.0828
# epoch:030 ,particle:09, par err:0.1003, best part err:0.0828, best swarm err:0.0828
# epoch:030 ,particle:10, par err:0.0987, best part err:0.0828, best swarm err:0.0828
# epoch:030 ,particle:11, par err:0.0929, best part err:0.0833, best swarm err:0.0828
# epoch:030 ,particle:12, par err:0.1001, best part err:0.0830, best swarm err:0.0828
# epoch:030 ,particle:13, par err:0.1057, best part err:0.0831, best swarm err:0.0828
# epoch:030 ,particle:14, par err:0.1120, best part err:0.0847, best swarm err:0.0828
# epoch:030 ,particle:15, par err:0.1046, best part err:0.0831, best swarm err:0.0828
#
# -------------------------------------------------------------------------------------
# epoch:031 ,particle:01, par err:0.1042, best part err:0.0868, best swarm err:0.0828
# epoch:031 ,particle:02, par err:0.0874, best part err:0.0830, best swarm err:0.0828
# epoch:031 ,particle:03, par err:0.1179, best part err:0.0846, best swarm err:0.0828
# epoch:031 ,particle:04, par err:0.0860, best part err:0.0828, best swarm err:0.0828
# epoch:031 ,particle:05, par err:0.1049, best part err:0.0838, best swarm err:0.0828
# epoch:031 ,particle:06, par err:0.0861, best part err:0.0830, best swarm err:0.0828
# epoch:031 ,particle:07, par err:0.0940, best part err:0.0847, best swarm err:0.0828
# epoch:031 ,particle:08, par err:0.1110, best part err:0.0871, best swarm err:0.0828
# epoch:031 ,particle:09, par err:0.0869, best part err:0.0828, best swarm err:0.0828
# epoch:031 ,particle:10, par err:0.0865, best part err:0.0828, best swarm err:0.0828
# epoch:031 ,particle:11, par err:0.0935, best part err:0.0833, best swarm err:0.0828
# epoch:031 ,particle:12, par err:0.0893, best part err:0.0830, best swarm err:0.0828
# epoch:031 ,particle:13, par err:0.0875, best part err:0.0831, best swarm err:0.0828
# epoch:031 ,particle:14, par err:0.0977, best part err:0.0847, best swarm err:0.0828
# epoch:031 ,particle:15, par err:0.0917, best part err:0.0831, best swarm err:0.0828
#
# -------------------------------------------------------------------------------------
# epoch:032 ,particle:01, par err:0.0844, best part err:0.0844, best swarm err:0.0828
# epoch:032 ,particle:02, par err:0.0831, best part err:0.0830, best swarm err:0.0828
# epoch:032 ,particle:03, par err:0.0922, best part err:0.0846, best swarm err:0.0828
# epoch:032 ,particle:04, par err:0.0830, best part err:0.0828, best swarm err:0.0828
# epoch:032 ,particle:05, par err:0.0871, best part err:0.0838, best swarm err:0.0828
# epoch:032 ,particle:06, par err:0.0831, best part err:0.0830, best swarm err:0.0828
# epoch:032 ,particle:07, par err:0.0869, best part err:0.0847, best swarm err:0.0828
# epoch:032 ,particle:08, par err:0.0848, best part err:0.0848, best swarm err:0.0828
# epoch:032 ,particle:09, par err:0.0830, best part err:0.0828, best swarm err:0.0828
# epoch:032 ,particle:10, par err:0.0830, best part err:0.0828, best swarm err:0.0828
# epoch:032 ,particle:11, par err:0.0842, best part err:0.0833, best swarm err:0.0828
# epoch:032 ,particle:12, par err:0.0832, best part err:0.0830, best swarm err:0.0828
# epoch:032 ,particle:13, par err:0.0832, best part err:0.0831, best swarm err:0.0828
# epoch:032 ,particle:14, par err:0.0830, best part err:0.0830, best swarm err:0.0828
# epoch:032 ,particle:15, par err:0.0832, best part err:0.0831, best swarm err:0.0828
#
# -------------------------------------------------------------------------------------
# epoch:033 ,particle:01, par err:0.1183, best part err:0.0844, best swarm err:0.0828
# epoch:033 ,particle:02, par err:0.0897, best part err:0.0830, best swarm err:0.0828
# epoch:033 ,particle:03, par err:0.0915, best part err:0.0846, best swarm err:0.0828
# epoch:033 ,particle:04, par err:0.0896, best part err:0.0828, best swarm err:0.0828
# epoch:033 ,particle:05, par err:0.1108, best part err:0.0838, best swarm err:0.0828
# epoch:033 ,particle:06, par err:0.0926, best part err:0.0830, best swarm err:0.0828
# epoch:033 ,particle:07, par err:0.0871, best part err:0.0847, best swarm err:0.0828
# epoch:033 ,particle:08, par err:0.1165, best part err:0.0848, best swarm err:0.0828
# epoch:033 ,particle:09, par err:0.0904, best part err:0.0828, best swarm err:0.0828
# epoch:033 ,particle:10, par err:0.0898, best part err:0.0828, best swarm err:0.0828
# epoch:033 ,particle:11, par err:0.0896, best part err:0.0833, best swarm err:0.0828
# epoch:033 ,particle:12, par err:0.0902, best part err:0.0830, best swarm err:0.0828
# epoch:033 ,particle:13, par err:0.0920, best part err:0.0831, best swarm err:0.0828
# epoch:033 ,particle:14, par err:0.1091, best part err:0.0830, best swarm err:0.0828
# epoch:033 ,particle:15, par err:0.0920, best part err:0.0831, best swarm err:0.0828
#
# -------------------------------------------------------------------------------------
# epoch:034 ,particle:01, par err:0.1072, best part err:0.0844, best swarm err:0.0828
# epoch:034 ,particle:02, par err:0.0893, best part err:0.0830, best swarm err:0.0828
# epoch:034 ,particle:03, par err:0.0836, best part err:0.0836, best swarm err:0.0828
# epoch:034 ,particle:04, par err:0.0874, best part err:0.0828, best swarm err:0.0828
# epoch:034 ,particle:05, par err:0.1226, best part err:0.0838, best swarm err:0.0828
# epoch:034 ,particle:06, par err:0.0869, best part err:0.0830, best swarm err:0.0828
# epoch:034 ,particle:07, par err:0.0828, best part err:0.0828, best swarm err:0.0828
# epoch:034 ,particle:08, par err:0.1181, best part err:0.0848, best swarm err:0.0828
# epoch:034 ,particle:09, par err:0.0885, best part err:0.0828, best swarm err:0.0828
# epoch:034 ,particle:10, par err:0.0881, best part err:0.0828, best swarm err:0.0828
# epoch:034 ,particle:11, par err:0.1151, best part err:0.0833, best swarm err:0.0828
# epoch:034 ,particle:12, par err:0.0921, best part err:0.0830, best swarm err:0.0828
# epoch:034 ,particle:13, par err:0.0890, best part err:0.0831, best swarm err:0.0828
# epoch:034 ,particle:14, par err:0.0988, best part err:0.0830, best swarm err:0.0828
# epoch:034 ,particle:15, par err:0.0951, best part err:0.0831, best swarm err:0.0828
#
# -------------------------------------------------------------------------------------
# epoch:035 ,particle:01, par err:0.1172, best part err:0.0844, best swarm err:0.0828
# epoch:035 ,particle:02, par err:0.0873, best part err:0.0830, best swarm err:0.0828
# epoch:035 ,particle:03, par err:0.0849, best part err:0.0836, best swarm err:0.0828
# epoch:035 ,particle:04, par err:0.0872, best part err:0.0828, best swarm err:0.0828
# epoch:035 ,particle:05, par err:0.0847, best part err:0.0838, best swarm err:0.0828
# epoch:035 ,particle:06, par err:0.0887, best part err:0.0830, best swarm err:0.0828
# epoch:035 ,particle:07, par err:0.0841, best part err:0.0828, best swarm err:0.0828
# epoch:035 ,particle:08, par err:0.1174, best part err:0.0848, best swarm err:0.0828
# epoch:035 ,particle:09, par err:0.0877, best part err:0.0828, best swarm err:0.0828
# epoch:035 ,particle:10, par err:0.0873, best part err:0.0828, best swarm err:0.0828
# epoch:035 ,particle:11, par err:0.0845, best part err:0.0833, best swarm err:0.0828
# epoch:035 ,particle:12, par err:0.0877, best part err:0.0830, best swarm err:0.0828
# epoch:035 ,particle:13, par err:0.0884, best part err:0.0831, best swarm err:0.0828
# epoch:035 ,particle:14, par err:0.1062, best part err:0.0830, best swarm err:0.0828
# epoch:035 ,particle:15, par err:0.0889, best part err:0.0831, best swarm err:0.0828
#
# -------------------------------------------------------------------------------------
# epoch:036 ,particle:01, par err:0.0831, best part err:0.0831, best swarm err:0.0828
# epoch:036 ,particle:02, par err:0.0830, best part err:0.0830, best swarm err:0.0828
# epoch:036 ,particle:03, par err:0.0956, best part err:0.0836, best swarm err:0.0828
# epoch:036 ,particle:04, par err:0.0829, best part err:0.0828, best swarm err:0.0828
# epoch:036 ,particle:05, par err:0.0847, best part err:0.0838, best swarm err:0.0828
# ...
# epoch:139 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:04, par err:0.0800, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:05, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:06, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:07, par err:0.0799, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:08, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:10, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:14, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:139 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0797
#
# -------------------------------------------------------------------------------------
# epoch:140 ,particle:01, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:04, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:07, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:08, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:10, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:140 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0797
#
# -------------------------------------------------------------------------------------
# epoch:141 ,particle:01, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:04, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:07, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:08, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:10, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:141 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0797
#
# -------------------------------------------------------------------------------------
# epoch:142 ,particle:01, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:02, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:04, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:05, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:06, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:07, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:08, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:10, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:14, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:142 ,particle:15, par err:0.0798, best part err:0.0797, best swarm err:0.0797
#
# -------------------------------------------------------------------------------------
# epoch:143 ,particle:01, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:03, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:04, par err:0.0799, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:07, par err:0.0799, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:08, par err:0.0799, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:10, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:143 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0797
#
# -------------------------------------------------------------------------------------
# epoch:144 ,particle:01, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:04, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:07, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:08, par err:0.0799, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:10, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:144 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0797
#
# -------------------------------------------------------------------------------------
# epoch:145 ,particle:01, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:04, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:07, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:08, par err:0.0798, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:10, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0797
# epoch:145 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0797
#
# -------------------------------------------------------------------------------------
# epoch:146 ,particle:01, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:146 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:04, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:07, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:08, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:10, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:146 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:146 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0796
#
# -------------------------------------------------------------------------------------
# epoch:147 ,particle:01, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:147 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:04, par err:0.0799, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:07, par err:0.0799, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:08, par err:0.0798, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:10, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:147 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:147 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0796
#
# -------------------------------------------------------------------------------------
# epoch:148 ,particle:01, par err:0.0798, best part err:0.0796, best swarm err:0.0796
# epoch:148 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:03, par err:0.0798, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:04, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:07, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:08, par err:0.0799, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:10, par err:0.0798, best part err:0.0796, best swarm err:0.0796
# epoch:148 ,particle:11, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:148 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0796
#
# -------------------------------------------------------------------------------------
# epoch:149 ,particle:01, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:149 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:04, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:149 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:07, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:149 ,particle:08, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:09, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:10, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:149 ,particle:11, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:149 ,particle:12, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:13, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:149 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0796
#
# -------------------------------------------------------------------------------------
# epoch:150 ,particle:01, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:02, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:150 ,particle:03, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:150 ,particle:04, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:05, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:150 ,particle:06, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:150 ,particle:07, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:08, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:09, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:10, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:11, par err:0.0797, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:12, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:13, par err:0.0796, best part err:0.0796, best swarm err:0.0796
# epoch:150 ,particle:14, par err:0.0797, best part err:0.0797, best swarm err:0.0796
# epoch:150 ,particle:15, par err:0.0797, best part err:0.0797, best swarm err:0.0796
#
# -------------------------------------------------------------------------------------

# %%
#np.savetxt('report01.txt',report)

# %%
ann_hp = pso1.ann.getANN_Hyperparameters()
pso_hp = pso1.getPSO_Hyperparameters()

plot_string = 'Function:{}\nANN Hyperparameters: Act func- {}, Layer Arch {}\n'.format(ann_hp[0],ann_hp[1],ann_hp[2])
plot_string += 'PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(pso_hp[0],pso_hp[1],pso_hp[2],pso_hp[3],pso_hp[4])


plt.figure(figsize = (10,10))
plt.plot(epoch_count,data_Swarm_best,'b', label='SwarmBestQuality')
plt.plot(epoch_count,data_Particle_current_best,'c', label='CurrentBestQuality')
plt.plot(epoch_count,data_Particle_current_worst,'r', label='CurrentWorstQuality')
plt.plot(epoch_count,data_particle_current_average,'y', label='CurrentAverageQuality')
plt.ylabel('Error')
plt.xlabel('Epoch')

#plt.legend(title='Parameter where:')
plt.legend(loc='center right', shadow=False, fontsize='medium')
plt.title('QUALITIES',fontsize='x-large')


plt.text(0.95, 0.01, plot_string,
        verticalalignment='top', horizontalalignment='left',
        color='green', fontsize=10)

plt.savefig('foo.png')

# %%
i_range = 1 #ann hyperparameters variant
j_range = 4 #pso hyperparameters variant
k_repeats = 15 #repeat each configuration sicne PSO is stocastic process

#Select Function:
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)

#Select ANN Hyperparameters
hidden_layer_neurons = [7,7]
activation = 'Sigmoid' # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)
X,Y = read_data(func)

#Select PSO Hyperparameters
swarm_size = [5, 10, 15, 30]
pso_alpha = 0.9 #0.729
pso_beta = 1.6 #1.49
pso_delta = 1.6 #1.49
max_epochs = 25
bound =50
bound_max = bound
bound_min = -bound


# initiate list of ann and pso objects
ann_list = []
pso_list= []

data_graph =[]
data_err_box =[]
for i in range(i_range):
    ann_list.append(NeuralNetwork(func, hidden_layer_neurons, activation, X,Y))
    for j in range(j_range):
        box_temp = []
        graph_temp = []
        pso_list_temp = []
        for k in range(k_repeats):
            pso_list_temp.append(ParticleSwarmOptimizer(swarm_size[j],pso_alpha,pso_beta,pso_delta,max_epochs, bound_max, bound_min, ann_list[i]))
            
            best_swarm_err, report, epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average = pso_list_temp[k].forward()
            
            box_temp.append(best_swarm_err)
            #data_graph.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])
            graph_temp.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])

        data_err_box.append(box_temp)
        data_graph.append(graph_temp)
        pso_list.append(pso_list_temp)
    
    fig,ax=plt.subplots()
    ax.boxplot(data_err_box)

# %%
pso_hp = []
ann_hp = []
plot_string = []

varients = i_range*j_range

#Set Sub plots parameters
nx = 1
ny = varients
dxs = 6
dys = 8
fig, axs = plt.subplots(ny, nx, sharey = True, figsize=(dxs*nx, dys*ny))
fig.suptitle('QUALITIES',fontsize='x-large')

for ij in range(varients):
    best_ind = np.argmin(data_err_box[ij])
    pso_hp.append(pso_list[ij][best_ind].getPSO_Hyperparameters())
    ann_hp.append(pso_list[ij][best_ind].ann.getANN_Hyperparameters())
    
    temp_string = 'Function:{}\nANN Hyperparameters: Act func- {}, Layer Arch {}\n'.format(ann_hp[ij][0],ann_hp[ij][1],ann_hp[ij][2])
    temp_string += 'PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(pso_hp[ij][0],pso_hp[ij][1],pso_hp[ij][2],pso_hp[ij][3],pso_hp[ij][4])
    plot_string.append(temp_string)

    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][3], 'b', label='SwarmBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][4],'c', label='CurrentBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][5],'r', label='CurrentWorstQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][6],'y', label='CurrentAverageQuality')
    
    axs[ij].legend(loc='center right', shadow=False, fontsize='medium')
    axs[ij].set_title(plot_string[ij],fontsize='small')
    
#axs.set(xlabel= 'Epoch' , ylable = 'Error')

# %%
print(len(pso_list))
print(len(pso_list[0]))
print(len(ann_list))
# Out:
# 4
# 15
# 1

# %%
print(len(data_graph))
print(len(data_graph[0]))
print(len(data_graph[0][0]))

len(data_err_box)
len(data_err_box[0])

# %%
data_graph[0][0][0]

# %%
data_graph[0][0][3]

# %%
print(data_err_box[0])
print(np.argmin(data_err_box[0]))

# %%
plt.figure(figsize = (10,10))
plt.plot(epoch_count,data_Swarm_best,'b', label='SwarmBestQuality')
plt.plot(epoch_count,data_Particle_current_best,'c', label='CurrentBestQuality')
plt.plot(epoch_count,data_Particle_current_worst,'r', label='CurrentWorstQuality')
plt.plot(epoch_count,data_particle_current_average,'y', label='CurrentAverageQuality')
plt.ylabel('Error')
plt.xlabel('Epoch')

#plt.legend(title='Parameter where:')
plt.legend(loc='center right', shadow=False, fontsize='medium')
plt.title('QUALITIES',fontsize='x-large')


plt.text(0.95, 0.01, plot_string,
        verticalalignment='top', horizontalalignment='left',
        color='green', fontsize=10)

plt.savefig('foo.png')

# %%
data_err_box = [[0.08482979983091354, 0.08392835408449173, 0.08371108770370483, 0.08370077610015869, 0.08356551080942154, 0.0835561528801918, 0.08199528604745865, 0.07882919907569885, 0.07862982153892517, 0.0786231979727745], [0.07758678495883942, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019]]

# %%
print(data_err_box[1])

# %%
fig,ax=plt.subplots()
ax.boxplot(data_err_box)

# %%
plt.boxplot(data_err_box[0])

# %%
plt.boxplot(data_err_box[1],1)
