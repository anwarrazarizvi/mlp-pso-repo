# %% [markdown]
# ## Function Approximation
# ### Using the PSO algorithm to optimise the ANN's parameters

# %% [markdown]
# **Import Resources**

# %%
# import resources

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **1. Create Neural Network Class**

# %%
class NeuralNetwork:    
    def __init__(self, func, hiddenLayerNeurons, activation, inputList, outputList):
        self.func = func # name of the function to be optimized
        self.layerArch = list.copy(hiddenLayerNeurons) #list of neurons in the hidden layers
        self.activation = activation # name of the activation fuction
          
        self.inputArray = inputList # array of given input dataset
        self.outputArray = outputList # array of the desired output dataset
        #print(self.inputArray,self.outputArray)
        
        # adding input and output layers to the hidden neurons list
        self.inputOutputNeurons()
        
        # calculate number of weights
        self.nWeights = self.numWeights()
        
        # set activation function
        self.actFunc = self.functionSelection()
        
        # set indices at which weight matrix to be split for matrix multiplication
        self.splitIndices = self.splitIndices()
        
    def getANN_Hyperparameters(self):
        return [self.func, self.activation, self.layerArch]
        
    def getnWeights(self): # getter methonds for number of weights
        return self.nWeights
        
    def inputOutputNeurons(self): # a private method to neuralNetwork class
        # Set number neurons in the Input layer
        if self.func in ('XOR','Complex'):
            self.layerArch.insert(0,2) # XOR & Complex functions are based on two input variables
        else:
            self.layerArch.insert(0,1) # Linear, Cubic, Sine, Tanh functions are based on single input variable
       
        # Set number of neurons in the Output layer
        self.layerArch.append(1) # only single output value is expected from the fuction
        
    def numWeights(self):# a private method to neuralNetwork class
        n_weights = sum(self.layerArch[i]*self.layerArch[i+1] for i in range(len(self.layerArch)-1))
        return n_weights
    
    def functionSelection(self):# a private method to neuralNetwork class
        return activation_funcs[self.activation]
    
    def splitIndices(self):
        indices = []
        for i in range(len(self.layerArch)-1):
            indices.append(self.layerArch[i]*self.layerArch[i+1])

        splitIndices = []
        splitIndices.append(indices[0])
        for j in range(1,len(indices)-1):
            splitIndices.append(splitIndices[j-1] + indices[j])

        return splitIndices
    
    def forward(self, weights):
        
        # to do: check the length of list of weigths matches the number weights
        
        wArray = np.split(weights,self.splitIndices)
        #print("splitIndices",self.splitIndices)
        #print("wArray",wArray)
        #print("layerArch", self.layerArch)
        
        wMatrix=[]
        for i in range(0,len(self.layerArch)-1):
            wMatrix.append(wArray[i].reshape(self.layerArch[i+1],self.layerArch[i]))
        #print("wArray after reshape", wMatrix)
    
        desiredArray = np.copy(self.outputArray)
        predictArray = []
        
        for i in range(len(self.inputArray)):
            ih = self.inputArray[i].reshape(-1,1)
            for j in range(0,len(self.layerArch)-1):
                #print("wMatrix = ", wMatrix[j], "ih = ", ih)
                ih = np.matmul(wMatrix[j],ih)
            
                if j != (len(self.layerArch)-1):
                    ih = self.actFunc(ih)
            predictArray.append(ih)
            
        #print(len(desiredArray), len(predictArray))

        squeezePredict = np.squeeze(predictArray)

        mse = ((desiredArray - squeezePredict)**2).mean(axis = None)
       
        return mse.tolist()

# %%
'''
a = [[ 0.23750601],
 [ 0.16600618],
 [-0.15851644],
 [ 0.10666603],
 [ 0.21195092]]
print(a)

b = np.asarray(a)
print(b)
print(type(b))
def function(val):
    return val*0

print(b[1])
b[1]= -b[1]
print(b[1])
'''
# Out:
# '\na = [[ 0.23750601],\n [ 0.16600618],\n [-0.15851644],\n [ 0.10666603],\n [ 0.21195092]]\nprint(a)\n\nb = np.asarray(a)\nprint(b)\nprint(type(b))\ndef function(val):\n    return val*0\n\nprint(b[1])\nb[1]= -b[1]\nprint(b[1])\n'

# %% [markdown]
# **2. Create PSO Class**<br>
# swarmsize - desired swarm size i.e. weight array<br>
# $ \alpha \gets$ inertia weight i.e. proportion of velocity to be retained<br>
# $ \beta \gets$ cognitive weight i.e. proportion of personal best to be retained<br>
# $ \delta \gets$ social weight i.e. proportion of global best to be retained<br>
# $ \epsilon \gets$ jump size of a particle (assumed 1 for this study)<br><br>
# **Enforcing Boundaries**: boundaries are enforced by rebounding the position by reversing the inertia weight<br>

# %%
class ParticleSwarmOptimizer:    
    def __init__(self, swarm_size,pso_alpha, pso_beta, pso_delta, max_epochs, bound_max, bound_min, ann):
        # PSO parameters
        self.swarmSize = swarm_size # number of particles in swarm
        self.psoAlpha = pso_alpha # inertia weight
        self.psoBeta = pso_beta # cognitive weight 
        self.psoDelta = pso_delta # social weight
        self.maxEpochs = max_epochs # maximum number of iterations

        self.bound_max = bound_max
        self.bound_min = bound_min
        
        self.ann = ann # neural network
        self.dim = self.ann.getnWeights() # no. of weights in nurol network = dimension of particle
        
        self.swarm = [Particles(self.dim, self.ann) for i in range(swarm_size)] #create swarm with swarm_size particles
  
        # initialise global best position
        self.best_swarm_pos = np.ones(self.dim)
        
    def getSwarmSize(self):
        return self.swarmSize # no of particles in swarm
    
    def getFinalWeights(self):
        return self.best_swarm_pos
    
    def getPSO_Hyperparameters(self):
        return [self.swarmSize, self.psoAlpha, self.psoBeta, self.psoDelta, self.maxEpochs, self.bound_max, self.bound_min]
   
    def forward(self):
        #Data collection for report and graph
        report = '' # string for run report
        ann_hp = self.ann.getANN_Hyperparameters()
        report +=('Function:{}\nANN Hyperparameters: activation function {}, layer arch {}\n'.format(ann_hp[0],ann_hp[1],ann_hp[2]))
        report +=('PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(self.swarmSize,self.psoAlpha,self.psoBeta,self.psoDelta,self.maxEpochs))
        report += '\n-------------------------------------------------------------------------------------'  
        report += '\n-------------------------------------------------------------------------------------\n'    
        data_Swarm_best = []
        data_Particle_current_best= []
        data_Particle_current_worst = []
        data_particle_current_average = []
        epoch_count =[]
        
        # initialise global best position and fittness/error
        best_swarm_err = 500
 
        epoch = 0
        while epoch < self.maxEpochs: # run until fixed number of iterations
            #data1= []
            #Update global best
            for ii in range(self.swarmSize): # for each particle in swarm/population
                
                position_ii = self.swarm[ii].getPosition()
                err_ii = (self.swarm[ii].getError())
  
                # update Global/swarm best error and position if found comparing fitness/error
                if err_ii < best_swarm_err:
                    best_swarm_err = err_ii
                    self.best_swarm_pos = position_ii
            #data1.extend([epoch+1,best_swarm_err])
            data_Swarm_best.append(best_swarm_err)
            epoch_count.append(epoch+1)
            
            #data2=[]
            pcb= 100 # setting to high error
            pcw= -100 # setting to low error
            pca=0
            for i in range(self.swarmSize): # for each particle in swarm/population

                # Gather information            
                position_i = self.swarm[i].getPosition()
                velocity_i = self.swarm[i].getVelocity()
                best_part_error_i = self.swarm[i].getBestPartErr()
                best_part_position_i = self.swarm[i].getBestPartPos()
                err_i = self.swarm[i].getError()
                
                report += ('epoch:{:03d} ,particle:{:02d}, par err:{:0.4f}, best part err:{:0.4f}, best swarm err:{:0.4f}'.
                      format(epoch+1, i+1, err_i, best_part_error_i ,best_swarm_err))+'\n'
                               
                #data2.extend([err_i,best_part_error_i])
                if pcb > err_i:
                    pcb = err_i
                if pcw < err_i:
                    pcw = err_i
                pca += err_i
                  
                
                # compute particle new velocity
                for k in range(self.dim): # for each dimension/weight in particle i
                    a = self.psoAlpha*velocity_i[k]
                    b = self.psoBeta*(best_part_position_i[k] - position_i[k])
                    c = self.psoDelta*(self.best_swarm_pos[k] - position_i[k])
                    velocity_i[k] = a+b+c
                    
                # compute particle new position as temp for checking bounds
                temp = np.add(position_i,velocity_i)
                
                # enforcing boundaries by rebounding particle with reversing the interia
                kk=0
                while kk < self.dim:
                    if temp[kk] >= self.bound_max or temp[kk] <= self.bound_min:
                        #position_f = (np.random.rand((self.dim)).astype(np.float32)-0.5)/2
                        #velocity_i = (np.random.rand((self.dim)).astype(np.float32)-0.5)/2
                        velocity_i[kk] = velocity_i[kk]- self.psoAlpha*velocity_i[k]
                        #print('weights breached at weights#',kk)
                    kk +=1
                
                # compute particle new position as temp
                position_f = np.add(position_i,velocity_i)

                # compute new fitness
                new_err = self.ann.forward(position_f)
                
                # update particle best error and position if found comparing fitness/error
                if new_err < best_part_error_i:
                    self.swarm[i].setBestPartErr(new_err)
                    self.swarm[i].setBestPartPos(position_f)
                
                # update particle class parameters              
                self.swarm[i].setPosition(position_f) # update particle position
                self.swarm[i].setVelocity(velocity_i) #update particle velocity
                self.swarm[i].setError(new_err) #update particle current error
                
                #print('epoch:{:03d} ,particle:{:02d}, par err:{:0.5f}, best part err:{:0.5f}, best swarm err:{:0.2f}'.
                      #format(epoch+1, i+1, new_err, self.swarm[i].getBestPartErr() ,best_swarm_err))
            pca = pca/self.swarmSize
            #data1.extend(data2)
            #self.data.append(data1)
            data_Particle_current_best.append(pcb)
            data_Particle_current_worst.append(pcw)
            data_particle_current_average.append(pca)
            report += '\n-------------------------------------------------------------------------------------\n'  
            epoch += 1
        return best_swarm_err, report, epoch_count,data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average

# %% [markdown]
# **3. Create Particles Class**

# %%
class Particles:
    def __init__(self, dim, ann):
        self.dim = dim
        self.ann =ann
        
        # initialise particle best position and velocity with random values 
        self.position = (np.random.rand((self.dim)).astype(np.float32)-0.5)/2 #current position; initialized with random
        self.velocity = (np.random.rand((self.dim)).astype(np.float32)-0.5)/2 #current velocity; initialized with random
        
        self.err = self.ann.forward(self.position)  #compute error for initial position
        
        self.best_part_pos = np.copy(self.position) # intialize particle best position as intial position
        self.best_part_err = self.err  #intialized particle best error as self error from intial position
        
    # getter methods    
    #def getDim(self): return self.dim
    def getPosition(self):return self.position
    def getVelocity(self):return self.velocity
    def getError(self):return self.err
    def getBestPartErr(self):return self.best_part_err
    def getBestPartPos(self):return self.best_part_pos

    
    # setter methods    
    def setPosition(self,pos):self.position = np.copy(pos)
    def setVelocity(self,vel):self.velocity = np.copy(vel)
    def setError(self,err): self.err = err
    def setBestPartErr(self,best_err): self.best_part_err = best_err
    def setBestPartPos(self,best_pos): self.best_part_pos = best_pos

# %% [markdown]
# **Select function from User input**

# %%
'''
# Set function from User input
func = input('Choose the function name \n(Options: Linear, Cubic, Sine, TanH, XOR, Complex) = ')
'''
# Out:
# "\n# Set function from User input\nfunc = input('Choose the function name \n(Options: Linear, Cubic, Sine, TanH, XOR, Complex) = ')\n"

# %% [markdown]
# **Set Hyperparameters from User input**

# %%
'''
# Set Hyperparameters from User input

# set number of hidden layers
hidden_layers = int(input('Enter number of hidden layers = '))


# set number of neurons in the hidden layers
if(hidden_layers > 0):
    hidden_layer_neurons = []
    for layer in range(hidden_layers):
        hidden_layer_neurons.append(int(input('Enter number of nodes in hidden layer {}= '.format(layer+1))))
  
# set activation function
activation = input('Enter the activation function \n(Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian) = ')
'''
# Out:
# "\n# Set Hyperparameters from User input\n\n# set number of hidden layers\nhidden_layers = int(input('Enter number of hidden layers = '))\n\n\n# set number of neurons in the hidden layers\nif(hidden_layers > 0):\n    hidden_layer_neurons = []\n    for layer in range(hidden_layers):\n        hidden_layer_neurons.append(int(input('Enter number of nodes in hidden layer {}= '.format(layer+1))))\n  \n# set activation function\nactivation = input('Enter the activation function \n(Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian) = ')\n"

# %% [markdown]
# **Setting ANN Hyperparameters**

# %%
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)
hidden_layer_neurons = [7,7]
activation = 'Sigmoid' # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)

# %%
# to do: handling errors & exceptions

# %%
'''
#check only
for i in range(len(hidden_layer_neurons)):
    print("number of neurons in hidden layer {} is {}".format(i+1,hidden_layer_neurons[i]))
'''
# Out:
# '\n#check only\nfor i in range(len(hidden_layer_neurons)):\n    print("number of neurons in hidden layer {} is {}".format(i+1,hidden_layer_neurons[i]))\n'

# %%
activation_funcs = {
    'Null': lambda x: x*0,
    'Sigmoid': lambda x: 1/(1 + np.exp(-x)),
    'Hyperbolic Tangent': lambda x: np.tanh(x),
    'Cosine': lambda x: np.cos(x),
    'Gaussian': lambda x: np.exp(-x**2/2),
        }

# %%
'''
#check only
activate = activation_funcs[activation]
print ('Output: Selected activation -',activate(.5))

print('Output: Null -',(.5)*0
print('Output: Sigmoid -',1/(1 + np.exp(-.5)))
print('Output: Hyperbolic Tangent -',np.tanh(.5))
print('Output: Cosine -',np.cos(.5))
print('Output: Gaussian -',np.exp(-.5**2/2))
'''
# Out:
# "\n#check only\nactivate = activation_funcs[activation]\nprint ('Output: Selected activation -',activate(.5))\n\nprint('Output: Null -',(.5)*0\nprint('Output: Sigmoid -',1/(1 + np.exp(-.5)))\nprint('Output: Hyperbolic Tangent -',np.tanh(.5))\nprint('Output: Cosine -',np.cos(.5))\nprint('Output: Gaussian -',np.exp(-.5**2/2))\n"

# %% [markdown]
# **Reading data from the .txt file**

# %%
'''
# load the training data from .txt file into a list
def read_data(func):
txt_address = {'Linear':'Data/1in_linear.txt',
               'Cubic':'Data/1in_cubic.txt',
               'Sine':'Data/1in_sine.txt',
               'TanH':'Data/1in_tanh.txt',
               'XOR':'Data/2in_xor.txt',
               'Complex':'Data/2in_complex.txt'}

train_data_file = open(txt_address[func],'r')
line_data = train_data_file.readlines()
train_data_file.close()

train_list = []
for line in line_data:
    line = line.strip().split()
    for d in line:
        train_list.append(float(d))
        
#check     
#print(train_list)

if func in ('XOR','Complex'):
    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,3)
    X,Y = train_array[:,0:2], train_array[:,-1]

elif func in ('Linear', 'Cubic', 'Sine', 'TanH'):
    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,2)
    X,Y = train_array[:,0], train_array[:,-1]
else:
    "error reading data"
    
#print(train_array)
#print(X)
#print(Y)
'''
# Out:
# '\n# load the training data from .txt file into a list\ndef read_data(func):\ntxt_address = {\'Linear\':\'Data/1in_linear.txt\',\n               \'Cubic\':\'Data/1in_cubic.txt\',\n               \'Sine\':\'Data/1in_sine.txt\',\n               \'TanH\':\'Data/1in_tanh.txt\',\n               \'XOR\':\'Data/2in_xor.txt\',\n               \'Complex\':\'Data/2in_complex.txt\'}\n\ntrain_data_file = open(txt_address[func],\'r\')\nline_data = train_data_file.readlines()\ntrain_data_file.close()\n\ntrain_list = []\nfor line in line_data:\n    line = line.strip().split()\n    for d in line:\n        train_list.append(float(d))\n        \n#check     \n#print(train_list)\n\nif func in (\'XOR\',\'Complex\'):\n    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,3)\n    X,Y = train_array[:,0:2], train_array[:,-1]\n\nelif func in (\'Linear\', \'Cubic\', \'Sine\', \'TanH\'):\n    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,2)\n    X,Y = train_array[:,0], train_array[:,-1]\nelse:\n    "error reading data"\n    \n#print(train_array)\n#print(X)\n#print(Y)\n'

# %%
# load the training data from .txt file into a list
def read_data(func):
    txt_address = {'Linear':'Data/1in_linear.txt',
                   'Cubic':'Data/1in_cubic.txt',
                   'Sine':'Data/1in_sine.txt',
                   'TanH':'Data/1in_tanh.txt',
                   'XOR':'Data/2in_xor.txt',
                   'Complex':'Data/2in_complex.txt'}

    train_data_file = open(txt_address[func],'r')
    line_data = train_data_file.readlines()
    train_data_file.close()

    train_list = []
    for line in line_data:
        line = line.strip().split()
        for d in line:
            train_list.append(float(d))
        
    #check     
    #print(train_list)

    if func in ('XOR','Complex'):
        train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,3)
        X,Y = train_array[:,0:2], train_array[:,-1]

    elif func in ('Linear', 'Cubic', 'Sine', 'TanH'):
        train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,2)
        X,Y = train_array[:,0], train_array[:,-1]
    else:
        "error reading data"    
    #print(train_array)
    #print(X)
    #print(Y)
    
    return X,Y

# %%
X,Y = read_data(func)
#create instance of neural network
ann1 = NeuralNetwork(func, hidden_layer_neurons, activation, X,Y)

# %% [markdown]
# **Setting PSO Hyperparameters**

# %%
swarm_size = 15
pso_alpha = 0.9 #0.729
pso_beta = 1.6 #1.49
pso_delta = 1.6 #1.49

max_epochs = 150
bound =50

bound_max = bound
bound_min = -bound


pso1 = ParticleSwarmOptimizer(swarm_size,pso_alpha,pso_beta,pso_delta,max_epochs, bound_max, bound_min, ann1)

# %% [markdown]
# **Run PSO optimizer**

# %%
best_swarm_err, report, epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average= pso1.forward()

# %%
print(best_swarm_err)
# Out:
# 0.07705782353878021

# %%
print(report)
# Out:
# Function:Cubic
# ANN Hyperparameters: activation function Sigmoid, layer arch [1, 7, 7, 1]
# PSO Hyperparameters: swarm size15, inertia weight0.9, cognitive weight1.6, social weight1.6, epochs150
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# epoch:001 ,particle:01, par err:0.3758, best part err:0.3758, best swarm err:0.3336
# epoch:001 ,particle:02, par err:0.3693, best part err:0.3693, best swarm err:0.3336
# epoch:001 ,particle:03, par err:0.4009, best part err:0.4009, best swarm err:0.3336
# epoch:001 ,particle:04, par err:0.3458, best part err:0.3458, best swarm err:0.3336
# epoch:001 ,particle:05, par err:0.3336, best part err:0.3336, best swarm err:0.3336
# epoch:001 ,particle:06, par err:0.3920, best part err:0.3920, best swarm err:0.3336
# epoch:001 ,particle:07, par err:0.4302, best part err:0.4302, best swarm err:0.3336
# epoch:001 ,particle:08, par err:0.4327, best part err:0.4327, best swarm err:0.3336
# epoch:001 ,particle:09, par err:0.4538, best part err:0.4538, best swarm err:0.3336
# epoch:001 ,particle:10, par err:0.3739, best part err:0.3739, best swarm err:0.3336
# epoch:001 ,particle:11, par err:0.3798, best part err:0.3798, best swarm err:0.3336
# epoch:001 ,particle:12, par err:0.4827, best part err:0.4827, best swarm err:0.3336
# epoch:001 ,particle:13, par err:0.3403, best part err:0.3403, best swarm err:0.3336
# epoch:001 ,particle:14, par err:0.3720, best part err:0.3720, best swarm err:0.3336
# epoch:001 ,particle:15, par err:0.4478, best part err:0.4478, best swarm err:0.3336
#
# -------------------------------------------------------------------------------------
# epoch:002 ,particle:01, par err:0.3050, best part err:0.3050, best swarm err:0.2489
# epoch:002 ,particle:02, par err:0.3737, best part err:0.3693, best swarm err:0.2489
# epoch:002 ,particle:03, par err:0.2857, best part err:0.2857, best swarm err:0.2489
# epoch:002 ,particle:04, par err:0.3948, best part err:0.3458, best swarm err:0.2489
# epoch:002 ,particle:05, par err:0.2773, best part err:0.2773, best swarm err:0.2489
# epoch:002 ,particle:06, par err:0.3631, best part err:0.3631, best swarm err:0.2489
# epoch:002 ,particle:07, par err:0.3404, best part err:0.3404, best swarm err:0.2489
# epoch:002 ,particle:08, par err:0.2974, best part err:0.2974, best swarm err:0.2489
# epoch:002 ,particle:09, par err:0.3571, best part err:0.3571, best swarm err:0.2489
# epoch:002 ,particle:10, par err:0.3358, best part err:0.3358, best swarm err:0.2489
# epoch:002 ,particle:11, par err:0.2517, best part err:0.2517, best swarm err:0.2489
# epoch:002 ,particle:12, par err:0.3250, best part err:0.3250, best swarm err:0.2489
# epoch:002 ,particle:13, par err:0.3255, best part err:0.3255, best swarm err:0.2489
# epoch:002 ,particle:14, par err:0.3207, best part err:0.3207, best swarm err:0.2489
# epoch:002 ,particle:15, par err:0.2489, best part err:0.2489, best swarm err:0.2489
#
# -------------------------------------------------------------------------------------
# epoch:003 ,particle:01, par err:0.1996, best part err:0.1996, best swarm err:0.1788
# epoch:003 ,particle:02, par err:0.2102, best part err:0.2102, best swarm err:0.1788
# epoch:003 ,particle:03, par err:0.1840, best part err:0.1840, best swarm err:0.1788
# epoch:003 ,particle:04, par err:0.2029, best part err:0.2029, best swarm err:0.1788
# epoch:003 ,particle:05, par err:0.2110, best part err:0.2110, best swarm err:0.1788
# epoch:003 ,particle:06, par err:0.1947, best part err:0.1947, best swarm err:0.1788
# epoch:003 ,particle:07, par err:0.2008, best part err:0.2008, best swarm err:0.1788
# epoch:003 ,particle:08, par err:0.1855, best part err:0.1855, best swarm err:0.1788
# epoch:003 ,particle:09, par err:0.1913, best part err:0.1913, best swarm err:0.1788
# epoch:003 ,particle:10, par err:0.1993, best part err:0.1993, best swarm err:0.1788
# epoch:003 ,particle:11, par err:0.1901, best part err:0.1901, best swarm err:0.1788
# epoch:003 ,particle:12, par err:0.1788, best part err:0.1788, best swarm err:0.1788
# epoch:003 ,particle:13, par err:0.2095, best part err:0.2095, best swarm err:0.1788
# epoch:003 ,particle:14, par err:0.1961, best part err:0.1961, best swarm err:0.1788
# epoch:003 ,particle:15, par err:0.1802, best part err:0.1802, best swarm err:0.1788
#
# -------------------------------------------------------------------------------------
# epoch:004 ,particle:01, par err:0.1512, best part err:0.1512, best swarm err:0.1502
# epoch:004 ,particle:02, par err:0.1507, best part err:0.1507, best swarm err:0.1502
# epoch:004 ,particle:03, par err:0.1524, best part err:0.1524, best swarm err:0.1502
# epoch:004 ,particle:04, par err:0.1502, best part err:0.1502, best swarm err:0.1502
# epoch:004 ,particle:05, par err:0.1525, best part err:0.1525, best swarm err:0.1502
# epoch:004 ,particle:06, par err:0.1513, best part err:0.1513, best swarm err:0.1502
# epoch:004 ,particle:07, par err:0.1505, best part err:0.1505, best swarm err:0.1502
# epoch:004 ,particle:08, par err:0.1526, best part err:0.1526, best swarm err:0.1502
# epoch:004 ,particle:09, par err:0.1506, best part err:0.1506, best swarm err:0.1502
# epoch:004 ,particle:10, par err:0.1535, best part err:0.1535, best swarm err:0.1502
# epoch:004 ,particle:11, par err:0.1560, best part err:0.1560, best swarm err:0.1502
# epoch:004 ,particle:12, par err:0.1504, best part err:0.1504, best swarm err:0.1502
# epoch:004 ,particle:13, par err:0.1505, best part err:0.1505, best swarm err:0.1502
# epoch:004 ,particle:14, par err:0.1544, best part err:0.1544, best swarm err:0.1502
# epoch:004 ,particle:15, par err:0.1552, best part err:0.1552, best swarm err:0.1502
#
# -------------------------------------------------------------------------------------
# epoch:005 ,particle:01, par err:0.1479, best part err:0.1479, best swarm err:0.1457
# epoch:005 ,particle:02, par err:0.1457, best part err:0.1457, best swarm err:0.1457
# epoch:005 ,particle:03, par err:0.1484, best part err:0.1484, best swarm err:0.1457
# epoch:005 ,particle:04, par err:0.1460, best part err:0.1460, best swarm err:0.1457
# epoch:005 ,particle:05, par err:0.1472, best part err:0.1472, best swarm err:0.1457
# epoch:005 ,particle:06, par err:0.1463, best part err:0.1463, best swarm err:0.1457
# epoch:005 ,particle:07, par err:0.1470, best part err:0.1470, best swarm err:0.1457
# epoch:005 ,particle:08, par err:0.1466, best part err:0.1466, best swarm err:0.1457
# epoch:005 ,particle:09, par err:0.1473, best part err:0.1473, best swarm err:0.1457
# epoch:005 ,particle:10, par err:0.1477, best part err:0.1477, best swarm err:0.1457
# epoch:005 ,particle:11, par err:0.1504, best part err:0.1504, best swarm err:0.1457
# epoch:005 ,particle:12, par err:0.1463, best part err:0.1463, best swarm err:0.1457
# epoch:005 ,particle:13, par err:0.1468, best part err:0.1468, best swarm err:0.1457
# epoch:005 ,particle:14, par err:0.1472, best part err:0.1472, best swarm err:0.1457
# epoch:005 ,particle:15, par err:0.1478, best part err:0.1478, best swarm err:0.1457
#
# -------------------------------------------------------------------------------------
# epoch:006 ,particle:01, par err:0.1481, best part err:0.1479, best swarm err:0.1457
# epoch:006 ,particle:02, par err:0.1473, best part err:0.1457, best swarm err:0.1457
# epoch:006 ,particle:03, par err:0.1478, best part err:0.1478, best swarm err:0.1457
# epoch:006 ,particle:04, par err:0.1475, best part err:0.1460, best swarm err:0.1457
# epoch:006 ,particle:05, par err:0.1475, best part err:0.1472, best swarm err:0.1457
# epoch:006 ,particle:06, par err:0.1478, best part err:0.1463, best swarm err:0.1457
# epoch:006 ,particle:07, par err:0.1486, best part err:0.1470, best swarm err:0.1457
# epoch:006 ,particle:08, par err:0.1465, best part err:0.1465, best swarm err:0.1457
# epoch:006 ,particle:09, par err:0.1476, best part err:0.1473, best swarm err:0.1457
# epoch:006 ,particle:10, par err:0.1478, best part err:0.1477, best swarm err:0.1457
# epoch:006 ,particle:11, par err:0.1482, best part err:0.1482, best swarm err:0.1457
# epoch:006 ,particle:12, par err:0.1477, best part err:0.1463, best swarm err:0.1457
# epoch:006 ,particle:13, par err:0.1481, best part err:0.1468, best swarm err:0.1457
# epoch:006 ,particle:14, par err:0.1485, best part err:0.1472, best swarm err:0.1457
# epoch:006 ,particle:15, par err:0.1479, best part err:0.1478, best swarm err:0.1457
#
# -------------------------------------------------------------------------------------
# epoch:007 ,particle:01, par err:0.1579, best part err:0.1479, best swarm err:0.1422
# epoch:007 ,particle:02, par err:0.1535, best part err:0.1457, best swarm err:0.1422
# epoch:007 ,particle:03, par err:0.1448, best part err:0.1448, best swarm err:0.1422
# epoch:007 ,particle:04, par err:0.1531, best part err:0.1460, best swarm err:0.1422
# epoch:007 ,particle:05, par err:0.1604, best part err:0.1472, best swarm err:0.1422
# epoch:007 ,particle:06, par err:0.1572, best part err:0.1463, best swarm err:0.1422
# epoch:007 ,particle:07, par err:0.1552, best part err:0.1470, best swarm err:0.1422
# epoch:007 ,particle:08, par err:0.1464, best part err:0.1464, best swarm err:0.1422
# epoch:007 ,particle:09, par err:0.1558, best part err:0.1473, best swarm err:0.1422
# epoch:007 ,particle:10, par err:0.1603, best part err:0.1477, best swarm err:0.1422
# epoch:007 ,particle:11, par err:0.1422, best part err:0.1422, best swarm err:0.1422
# epoch:007 ,particle:12, par err:0.1577, best part err:0.1463, best swarm err:0.1422
# epoch:007 ,particle:13, par err:0.1560, best part err:0.1468, best swarm err:0.1422
# epoch:007 ,particle:14, par err:0.1643, best part err:0.1472, best swarm err:0.1422
# epoch:007 ,particle:15, par err:0.1688, best part err:0.1478, best swarm err:0.1422
#
# -------------------------------------------------------------------------------------
# epoch:008 ,particle:01, par err:0.1449, best part err:0.1449, best swarm err:0.1329
# epoch:008 ,particle:02, par err:0.1413, best part err:0.1413, best swarm err:0.1329
# epoch:008 ,particle:03, par err:0.1351, best part err:0.1351, best swarm err:0.1329
# epoch:008 ,particle:04, par err:0.1430, best part err:0.1430, best swarm err:0.1329
# epoch:008 ,particle:05, par err:0.1436, best part err:0.1436, best swarm err:0.1329
# epoch:008 ,particle:06, par err:0.1442, best part err:0.1442, best swarm err:0.1329
# epoch:008 ,particle:07, par err:0.1448, best part err:0.1448, best swarm err:0.1329
# epoch:008 ,particle:08, par err:0.1381, best part err:0.1381, best swarm err:0.1329
# epoch:008 ,particle:09, par err:0.1439, best part err:0.1439, best swarm err:0.1329
# epoch:008 ,particle:10, par err:0.1433, best part err:0.1433, best swarm err:0.1329
# epoch:008 ,particle:11, par err:0.1329, best part err:0.1329, best swarm err:0.1329
# epoch:008 ,particle:12, par err:0.1407, best part err:0.1407, best swarm err:0.1329
# epoch:008 ,particle:13, par err:0.1436, best part err:0.1436, best swarm err:0.1329
# epoch:008 ,particle:14, par err:0.1428, best part err:0.1428, best swarm err:0.1329
# epoch:008 ,particle:15, par err:0.1447, best part err:0.1447, best swarm err:0.1329
#
# -------------------------------------------------------------------------------------
# epoch:009 ,particle:01, par err:0.1245, best part err:0.1245, best swarm err:0.1159
# epoch:009 ,particle:02, par err:0.1205, best part err:0.1205, best swarm err:0.1159
# epoch:009 ,particle:03, par err:0.1159, best part err:0.1159, best swarm err:0.1159
# epoch:009 ,particle:04, par err:0.1251, best part err:0.1251, best swarm err:0.1159
# epoch:009 ,particle:05, par err:0.1233, best part err:0.1233, best swarm err:0.1159
# epoch:009 ,particle:06, par err:0.1261, best part err:0.1261, best swarm err:0.1159
# epoch:009 ,particle:07, par err:0.1300, best part err:0.1300, best swarm err:0.1159
# epoch:009 ,particle:08, par err:0.1191, best part err:0.1191, best swarm err:0.1159
# epoch:009 ,particle:09, par err:0.1255, best part err:0.1255, best swarm err:0.1159
# epoch:009 ,particle:10, par err:0.1257, best part err:0.1257, best swarm err:0.1159
# epoch:009 ,particle:11, par err:0.1224, best part err:0.1224, best swarm err:0.1159
# epoch:009 ,particle:12, par err:0.1269, best part err:0.1269, best swarm err:0.1159
# epoch:009 ,particle:13, par err:0.1289, best part err:0.1289, best swarm err:0.1159
# epoch:009 ,particle:14, par err:0.1320, best part err:0.1320, best swarm err:0.1159
# epoch:009 ,particle:15, par err:0.1227, best part err:0.1227, best swarm err:0.1159
#
# -------------------------------------------------------------------------------------
# epoch:010 ,particle:01, par err:0.1721, best part err:0.1245, best swarm err:0.1099
# epoch:010 ,particle:02, par err:0.1540, best part err:0.1205, best swarm err:0.1099
# epoch:010 ,particle:03, par err:0.1139, best part err:0.1139, best swarm err:0.1099
# epoch:010 ,particle:04, par err:0.1565, best part err:0.1251, best swarm err:0.1099
# epoch:010 ,particle:05, par err:0.1789, best part err:0.1233, best swarm err:0.1099
# epoch:010 ,particle:06, par err:0.1715, best part err:0.1261, best swarm err:0.1099
# epoch:010 ,particle:07, par err:0.1697, best part err:0.1300, best swarm err:0.1099
# epoch:010 ,particle:08, par err:0.1118, best part err:0.1118, best swarm err:0.1099
# epoch:010 ,particle:09, par err:0.1525, best part err:0.1255, best swarm err:0.1099
# epoch:010 ,particle:10, par err:0.1713, best part err:0.1257, best swarm err:0.1099
# epoch:010 ,particle:11, par err:0.1099, best part err:0.1099, best swarm err:0.1099
# epoch:010 ,particle:12, par err:0.1490, best part err:0.1269, best swarm err:0.1099
# epoch:010 ,particle:13, par err:0.1780, best part err:0.1289, best swarm err:0.1099
# epoch:010 ,particle:14, par err:0.1644, best part err:0.1320, best swarm err:0.1099
# epoch:010 ,particle:15, par err:0.1531, best part err:0.1227, best swarm err:0.1099
#
# -------------------------------------------------------------------------------------
# epoch:011 ,particle:01, par err:0.1372, best part err:0.1245, best swarm err:0.1099
# epoch:011 ,particle:02, par err:0.1268, best part err:0.1205, best swarm err:0.1099
# epoch:011 ,particle:03, par err:0.1354, best part err:0.1139, best swarm err:0.1099
# epoch:011 ,particle:04, par err:0.1319, best part err:0.1251, best swarm err:0.1099
# epoch:011 ,particle:05, par err:0.1337, best part err:0.1233, best swarm err:0.1099
# epoch:011 ,particle:06, par err:0.1363, best part err:0.1261, best swarm err:0.1099
# epoch:011 ,particle:07, par err:0.1375, best part err:0.1300, best swarm err:0.1099
# epoch:011 ,particle:08, par err:0.1454, best part err:0.1118, best swarm err:0.1099
# epoch:011 ,particle:09, par err:0.1349, best part err:0.1255, best swarm err:0.1099
# epoch:011 ,particle:10, par err:0.1341, best part err:0.1257, best swarm err:0.1099
# epoch:011 ,particle:11, par err:0.1468, best part err:0.1099, best swarm err:0.1099
# epoch:011 ,particle:12, par err:0.1297, best part err:0.1269, best swarm err:0.1099
# epoch:011 ,particle:13, par err:0.1364, best part err:0.1289, best swarm err:0.1099
# epoch:011 ,particle:14, par err:0.1353, best part err:0.1320, best swarm err:0.1099
# epoch:011 ,particle:15, par err:0.1366, best part err:0.1227, best swarm err:0.1099
#
# -------------------------------------------------------------------------------------
# epoch:012 ,particle:01, par err:0.1037, best part err:0.1037, best swarm err:0.1037
# epoch:012 ,particle:02, par err:0.1074, best part err:0.1074, best swarm err:0.1037
# epoch:012 ,particle:03, par err:0.1173, best part err:0.1139, best swarm err:0.1037
# epoch:012 ,particle:04, par err:0.1096, best part err:0.1096, best swarm err:0.1037
# epoch:012 ,particle:05, par err:0.1075, best part err:0.1075, best swarm err:0.1037
# epoch:012 ,particle:06, par err:0.1077, best part err:0.1077, best swarm err:0.1037
# epoch:012 ,particle:07, par err:0.1122, best part err:0.1122, best swarm err:0.1037
# epoch:012 ,particle:08, par err:0.1205, best part err:0.1118, best swarm err:0.1037
# epoch:012 ,particle:09, par err:0.1093, best part err:0.1093, best swarm err:0.1037
# epoch:012 ,particle:10, par err:0.1092, best part err:0.1092, best swarm err:0.1037
# epoch:012 ,particle:11, par err:0.1256, best part err:0.1099, best swarm err:0.1037
# epoch:012 ,particle:12, par err:0.1110, best part err:0.1110, best swarm err:0.1037
# epoch:012 ,particle:13, par err:0.1076, best part err:0.1076, best swarm err:0.1037
# epoch:012 ,particle:14, par err:0.1136, best part err:0.1136, best swarm err:0.1037
# epoch:012 ,particle:15, par err:0.1085, best part err:0.1085, best swarm err:0.1037
#
# -------------------------------------------------------------------------------------
# epoch:013 ,particle:01, par err:0.1584, best part err:0.1037, best swarm err:0.0936
# epoch:013 ,particle:02, par err:0.1118, best part err:0.1074, best swarm err:0.0936
# epoch:013 ,particle:03, par err:0.0939, best part err:0.0939, best swarm err:0.0936
# epoch:013 ,particle:04, par err:0.1219, best part err:0.1096, best swarm err:0.0936
# epoch:013 ,particle:05, par err:0.1491, best part err:0.1075, best swarm err:0.0936
# epoch:013 ,particle:06, par err:0.1543, best part err:0.1077, best swarm err:0.0936
# epoch:013 ,particle:07, par err:0.1376, best part err:0.1122, best swarm err:0.0936
# epoch:013 ,particle:08, par err:0.0936, best part err:0.0936, best swarm err:0.0936
# epoch:013 ,particle:09, par err:0.1330, best part err:0.1093, best swarm err:0.0936
# epoch:013 ,particle:10, par err:0.1430, best part err:0.1092, best swarm err:0.0936
# epoch:013 ,particle:11, par err:0.0937, best part err:0.0937, best swarm err:0.0936
# epoch:013 ,particle:12, par err:0.1227, best part err:0.1110, best swarm err:0.0936
# epoch:013 ,particle:13, par err:0.1561, best part err:0.1076, best swarm err:0.0936
# epoch:013 ,particle:14, par err:0.1505, best part err:0.1136, best swarm err:0.0936
# epoch:013 ,particle:15, par err:0.1312, best part err:0.1085, best swarm err:0.0936
#
# -------------------------------------------------------------------------------------
# epoch:014 ,particle:01, par err:0.1184, best part err:0.1037, best swarm err:0.0936
# epoch:014 ,particle:02, par err:0.1005, best part err:0.1005, best swarm err:0.0936
# epoch:014 ,particle:03, par err:0.1345, best part err:0.0939, best swarm err:0.0936
# epoch:014 ,particle:04, par err:0.1112, best part err:0.1096, best swarm err:0.0936
# epoch:014 ,particle:05, par err:0.1169, best part err:0.1075, best swarm err:0.0936
# epoch:014 ,particle:06, par err:0.1186, best part err:0.1077, best swarm err:0.0936
# epoch:014 ,particle:07, par err:0.1202, best part err:0.1122, best swarm err:0.0936
# epoch:014 ,particle:08, par err:0.1499, best part err:0.0936, best swarm err:0.0936
# epoch:014 ,particle:09, par err:0.1170, best part err:0.1093, best swarm err:0.0936
# epoch:014 ,particle:10, par err:0.1171, best part err:0.1092, best swarm err:0.0936
# epoch:014 ,particle:11, par err:0.1633, best part err:0.0937, best swarm err:0.0936
# epoch:014 ,particle:12, par err:0.1117, best part err:0.1110, best swarm err:0.0936
# epoch:014 ,particle:13, par err:0.1226, best part err:0.1076, best swarm err:0.0936
# epoch:014 ,particle:14, par err:0.1197, best part err:0.1136, best swarm err:0.0936
# epoch:014 ,particle:15, par err:0.1190, best part err:0.1085, best swarm err:0.0936
#
# -------------------------------------------------------------------------------------
# epoch:015 ,particle:01, par err:0.1161, best part err:0.1037, best swarm err:0.0936
# epoch:015 ,particle:02, par err:0.0948, best part err:0.0948, best swarm err:0.0936
# epoch:015 ,particle:03, par err:0.1235, best part err:0.0939, best swarm err:0.0936
# epoch:015 ,particle:04, par err:0.1092, best part err:0.1092, best swarm err:0.0936
# epoch:015 ,particle:05, par err:0.1172, best part err:0.1075, best swarm err:0.0936
# epoch:015 ,particle:06, par err:0.1148, best part err:0.1077, best swarm err:0.0936
# epoch:015 ,particle:07, par err:0.1124, best part err:0.1122, best swarm err:0.0936
# epoch:015 ,particle:08, par err:0.1261, best part err:0.0936, best swarm err:0.0936
# epoch:015 ,particle:09, par err:0.1039, best part err:0.1039, best swarm err:0.0936
# epoch:015 ,particle:10, par err:0.1119, best part err:0.1092, best swarm err:0.0936
# epoch:015 ,particle:11, par err:0.1315, best part err:0.0937, best swarm err:0.0936
# epoch:015 ,particle:12, par err:0.1028, best part err:0.1028, best swarm err:0.0936
# epoch:015 ,particle:13, par err:0.1130, best part err:0.1076, best swarm err:0.0936
# epoch:015 ,particle:14, par err:0.1071, best part err:0.1071, best swarm err:0.0936
# epoch:015 ,particle:15, par err:0.1074, best part err:0.1074, best swarm err:0.0936
#
# -------------------------------------------------------------------------------------
# epoch:016 ,particle:01, par err:0.0945, best part err:0.0945, best swarm err:0.0936
# epoch:016 ,particle:02, par err:0.1095, best part err:0.0948, best swarm err:0.0936
# epoch:016 ,particle:03, par err:0.1137, best part err:0.0939, best swarm err:0.0936
# epoch:016 ,particle:04, par err:0.1801, best part err:0.1092, best swarm err:0.0936
# epoch:016 ,particle:05, par err:0.0944, best part err:0.0944, best swarm err:0.0936
# epoch:016 ,particle:06, par err:0.0944, best part err:0.0944, best swarm err:0.0936
# epoch:016 ,particle:07, par err:0.0942, best part err:0.0942, best swarm err:0.0936
# epoch:016 ,particle:08, par err:0.1292, best part err:0.0936, best swarm err:0.0936
# epoch:016 ,particle:09, par err:0.2045, best part err:0.1039, best swarm err:0.0936
# epoch:016 ,particle:10, par err:0.0939, best part err:0.0939, best swarm err:0.0936
# epoch:016 ,particle:11, par err:0.1370, best part err:0.0937, best swarm err:0.0936
# epoch:016 ,particle:12, par err:0.1887, best part err:0.1028, best swarm err:0.0936
# epoch:016 ,particle:13, par err:0.0939, best part err:0.0939, best swarm err:0.0936
# epoch:016 ,particle:14, par err:0.2555, best part err:0.1071, best swarm err:0.0936
# epoch:016 ,particle:15, par err:0.2190, best part err:0.1074, best swarm err:0.0936
#
# -------------------------------------------------------------------------------------
# epoch:017 ,particle:01, par err:0.0966, best part err:0.0945, best swarm err:0.0936
# epoch:017 ,particle:02, par err:0.1001, best part err:0.0948, best swarm err:0.0936
# epoch:017 ,particle:03, par err:0.0939, best part err:0.0939, best swarm err:0.0936
# epoch:017 ,particle:04, par err:0.1171, best part err:0.1092, best swarm err:0.0936
# epoch:017 ,particle:05, par err:0.0958, best part err:0.0944, best swarm err:0.0936
# epoch:017 ,particle:06, par err:0.0974, best part err:0.0944, best swarm err:0.0936
# epoch:017 ,particle:07, par err:0.0965, best part err:0.0942, best swarm err:0.0936
# epoch:017 ,particle:08, par err:0.0942, best part err:0.0936, best swarm err:0.0936
# epoch:017 ,particle:09, par err:0.1219, best part err:0.1039, best swarm err:0.0936
# epoch:017 ,particle:10, par err:0.0988, best part err:0.0939, best swarm err:0.0936
# epoch:017 ,particle:11, par err:0.0951, best part err:0.0937, best swarm err:0.0936
# epoch:017 ,particle:12, par err:0.1179, best part err:0.1028, best swarm err:0.0936
# epoch:017 ,particle:13, par err:0.1007, best part err:0.0939, best swarm err:0.0936
# epoch:017 ,particle:14, par err:0.1258, best part err:0.1071, best swarm err:0.0936
# epoch:017 ,particle:15, par err:0.1211, best part err:0.1074, best swarm err:0.0936
#
# -------------------------------------------------------------------------------------
# epoch:018 ,particle:01, par err:0.1371, best part err:0.0945, best swarm err:0.0936
# epoch:018 ,particle:02, par err:0.0946, best part err:0.0946, best swarm err:0.0936
# epoch:018 ,particle:03, par err:0.1142, best part err:0.0939, best swarm err:0.0936
# epoch:018 ,particle:04, par err:0.2203, best part err:0.1092, best swarm err:0.0936
# epoch:018 ,particle:05, par err:0.1449, best part err:0.0944, best swarm err:0.0936
# epoch:018 ,particle:06, par err:0.1377, best part err:0.0944, best swarm err:0.0936
# epoch:018 ,particle:07, par err:0.1344, best part err:0.0942, best swarm err:0.0936
# epoch:018 ,particle:08, par err:0.1145, best part err:0.0936, best swarm err:0.0936
# epoch:018 ,particle:09, par err:0.2511, best part err:0.1039, best swarm err:0.0936
# epoch:018 ,particle:10, par err:0.1366, best part err:0.0939, best swarm err:0.0936
# epoch:018 ,particle:11, par err:0.1209, best part err:0.0937, best swarm err:0.0936
# epoch:018 ,particle:12, par err:0.2445, best part err:0.1028, best swarm err:0.0936
# epoch:018 ,particle:13, par err:0.1376, best part err:0.0939, best swarm err:0.0936
# epoch:018 ,particle:14, par err:0.3786, best part err:0.1071, best swarm err:0.0936
# epoch:018 ,particle:15, par err:0.2871, best part err:0.1074, best swarm err:0.0936
#
# -------------------------------------------------------------------------------------
# epoch:019 ,particle:01, par err:0.0945, best part err:0.0945, best swarm err:0.0936
# epoch:019 ,particle:02, par err:0.1605, best part err:0.0946, best swarm err:0.0936
# epoch:019 ,particle:03, par err:0.1341, best part err:0.0939, best swarm err:0.0936
# epoch:019 ,particle:04, par err:0.0958, best part err:0.0958, best swarm err:0.0936
# epoch:019 ,particle:05, par err:0.0941, best part err:0.0941, best swarm err:0.0936
# epoch:019 ,particle:06, par err:0.0945, best part err:0.0944, best swarm err:0.0936
# epoch:019 ,particle:07, par err:0.0948, best part err:0.0942, best swarm err:0.0936
# epoch:019 ,particle:08, par err:0.1538, best part err:0.0936, best swarm err:0.0936
# epoch:019 ,particle:09, par err:0.0963, best part err:0.0963, best swarm err:0.0936
# epoch:019 ,particle:10, par err:0.0963, best part err:0.0939, best swarm err:0.0936
# epoch:019 ,particle:11, par err:0.1665, best part err:0.0937, best swarm err:0.0936
# epoch:019 ,particle:12, par err:0.0952, best part err:0.0952, best swarm err:0.0936
# epoch:019 ,particle:13, par err:0.0969, best part err:0.0939, best swarm err:0.0936
# epoch:019 ,particle:14, par err:0.0966, best part err:0.0966, best swarm err:0.0936
# epoch:019 ,particle:15, par err:0.0962, best part err:0.0962, best swarm err:0.0936
#
# -------------------------------------------------------------------------------------
# epoch:020 ,particle:01, par err:0.1006, best part err:0.0945, best swarm err:0.0934
# epoch:020 ,particle:02, par err:0.0974, best part err:0.0946, best swarm err:0.0934
# epoch:020 ,particle:03, par err:0.1031, best part err:0.0939, best swarm err:0.0934
# epoch:020 ,particle:04, par err:0.1015, best part err:0.0958, best swarm err:0.0934
# epoch:020 ,particle:05, par err:0.0994, best part err:0.0941, best swarm err:0.0934
# epoch:020 ,particle:06, par err:0.0934, best part err:0.0934, best swarm err:0.0934
# epoch:020 ,particle:07, par err:0.0935, best part err:0.0935, best swarm err:0.0934
# epoch:020 ,particle:08, par err:0.1044, best part err:0.0936, best swarm err:0.0934
# epoch:020 ,particle:09, par err:0.1080, best part err:0.0963, best swarm err:0.0934
# epoch:020 ,particle:10, par err:0.0938, best part err:0.0938, best swarm err:0.0934
# epoch:020 ,particle:11, par err:0.1069, best part err:0.0937, best swarm err:0.0934
# epoch:020 ,particle:12, par err:0.1050, best part err:0.0952, best swarm err:0.0934
# epoch:020 ,particle:13, par err:0.0939, best part err:0.0939, best swarm err:0.0934
# epoch:020 ,particle:14, par err:0.1109, best part err:0.0966, best swarm err:0.0934
# epoch:020 ,particle:15, par err:0.1130, best part err:0.0962, best swarm err:0.0934
#
# -------------------------------------------------------------------------------------
# epoch:021 ,particle:01, par err:0.1245, best part err:0.0945, best swarm err:0.0933
# epoch:021 ,particle:02, par err:0.1204, best part err:0.0946, best swarm err:0.0933
# epoch:021 ,particle:03, par err:0.0976, best part err:0.0939, best swarm err:0.0933
# epoch:021 ,particle:04, par err:0.2672, best part err:0.0958, best swarm err:0.0933
# epoch:021 ,particle:05, par err:0.1269, best part err:0.0941, best swarm err:0.0933
# epoch:021 ,particle:06, par err:0.0949, best part err:0.0934, best swarm err:0.0933
# epoch:021 ,particle:07, par err:0.0951, best part err:0.0935, best swarm err:0.0933
# epoch:021 ,particle:08, par err:0.0965, best part err:0.0936, best swarm err:0.0933
# epoch:021 ,particle:09, par err:0.3343, best part err:0.0963, best swarm err:0.0933
# epoch:021 ,particle:10, par err:0.0936, best part err:0.0936, best swarm err:0.0933
# epoch:021 ,particle:11, par err:0.0977, best part err:0.0937, best swarm err:0.0933
# epoch:021 ,particle:12, par err:0.3327, best part err:0.0952, best swarm err:0.0933
# epoch:021 ,particle:13, par err:0.0933, best part err:0.0933, best swarm err:0.0933
# epoch:021 ,particle:14, par err:0.5452, best part err:0.0966, best swarm err:0.0933
# epoch:021 ,particle:15, par err:0.4126, best part err:0.0962, best swarm err:0.0933
#
# -------------------------------------------------------------------------------------
# epoch:022 ,particle:01, par err:0.0933, best part err:0.0933, best swarm err:0.0909
# epoch:022 ,particle:02, par err:0.1069, best part err:0.0946, best swarm err:0.0909
# epoch:022 ,particle:03, par err:0.1234, best part err:0.0939, best swarm err:0.0909
# epoch:022 ,particle:04, par err:0.0917, best part err:0.0917, best swarm err:0.0909
# epoch:022 ,particle:05, par err:0.0920, best part err:0.0920, best swarm err:0.0909
# epoch:022 ,particle:06, par err:0.0909, best part err:0.0909, best swarm err:0.0909
# epoch:022 ,particle:07, par err:0.0932, best part err:0.0932, best swarm err:0.0909
# epoch:022 ,particle:08, par err:0.1353, best part err:0.0936, best swarm err:0.0909
# epoch:022 ,particle:09, par err:0.0983, best part err:0.0963, best swarm err:0.0909
# epoch:022 ,particle:10, par err:0.0968, best part err:0.0936, best swarm err:0.0909
# epoch:022 ,particle:11, par err:0.1541, best part err:0.0937, best swarm err:0.0909
# epoch:022 ,particle:12, par err:0.0948, best part err:0.0948, best swarm err:0.0909
# epoch:022 ,particle:13, par err:0.0969, best part err:0.0933, best swarm err:0.0909
# epoch:022 ,particle:14, par err:0.0995, best part err:0.0966, best swarm err:0.0909
# epoch:022 ,particle:15, par err:0.0974, best part err:0.0962, best swarm err:0.0909
#
# -------------------------------------------------------------------------------------
# epoch:023 ,particle:01, par err:0.0956, best part err:0.0933, best swarm err:0.0889
# epoch:023 ,particle:02, par err:0.1027, best part err:0.0946, best swarm err:0.0889
# epoch:023 ,particle:03, par err:0.1124, best part err:0.0939, best swarm err:0.0889
# epoch:023 ,particle:04, par err:0.0926, best part err:0.0917, best swarm err:0.0889
# epoch:023 ,particle:05, par err:0.0934, best part err:0.0920, best swarm err:0.0889
# epoch:023 ,particle:06, par err:0.0889, best part err:0.0889, best swarm err:0.0889
# epoch:023 ,particle:07, par err:0.0907, best part err:0.0907, best swarm err:0.0889
# epoch:023 ,particle:08, par err:0.1138, best part err:0.0936, best swarm err:0.0889
# epoch:023 ,particle:09, par err:0.0977, best part err:0.0963, best swarm err:0.0889
# epoch:023 ,particle:10, par err:0.0941, best part err:0.0936, best swarm err:0.0889
# epoch:023 ,particle:11, par err:0.1174, best part err:0.0937, best swarm err:0.0889
# epoch:023 ,particle:12, par err:0.1045, best part err:0.0948, best swarm err:0.0889
# epoch:023 ,particle:13, par err:0.0941, best part err:0.0933, best swarm err:0.0889
# epoch:023 ,particle:14, par err:0.0986, best part err:0.0966, best swarm err:0.0889
# epoch:023 ,particle:15, par err:0.0980, best part err:0.0962, best swarm err:0.0889
#
# -------------------------------------------------------------------------------------
# epoch:024 ,particle:01, par err:0.1031, best part err:0.0933, best swarm err:0.0889
# epoch:024 ,particle:02, par err:0.1675, best part err:0.0946, best swarm err:0.0889
# epoch:024 ,particle:03, par err:0.0918, best part err:0.0918, best swarm err:0.0889
# epoch:024 ,particle:04, par err:0.1776, best part err:0.0917, best swarm err:0.0889
# epoch:024 ,particle:05, par err:0.0989, best part err:0.0920, best swarm err:0.0889
# epoch:024 ,particle:06, par err:0.0891, best part err:0.0889, best swarm err:0.0889
# epoch:024 ,particle:07, par err:0.0908, best part err:0.0907, best swarm err:0.0889
# epoch:024 ,particle:08, par err:0.0975, best part err:0.0936, best swarm err:0.0889
# epoch:024 ,particle:09, par err:0.1947, best part err:0.0963, best swarm err:0.0889
# epoch:024 ,particle:10, par err:0.0901, best part err:0.0901, best swarm err:0.0889
# epoch:024 ,particle:11, par err:0.0993, best part err:0.0937, best swarm err:0.0889
# epoch:024 ,particle:12, par err:0.2604, best part err:0.0948, best swarm err:0.0889
# epoch:024 ,particle:13, par err:0.0897, best part err:0.0897, best swarm err:0.0889
# epoch:024 ,particle:14, par err:0.2694, best part err:0.0966, best swarm err:0.0889
# epoch:024 ,particle:15, par err:0.2096, best part err:0.0962, best swarm err:0.0889
#
# -------------------------------------------------------------------------------------
# epoch:025 ,particle:01, par err:0.0977, best part err:0.0933, best swarm err:0.0882
# epoch:025 ,particle:02, par err:0.0956, best part err:0.0946, best swarm err:0.0882
# epoch:025 ,particle:03, par err:0.1347, best part err:0.0918, best swarm err:0.0882
# epoch:025 ,particle:04, par err:0.0973, best part err:0.0917, best swarm err:0.0882
# epoch:025 ,particle:05, par err:0.0955, best part err:0.0920, best swarm err:0.0882
# epoch:025 ,particle:06, par err:0.0914, best part err:0.0889, best swarm err:0.0882
# epoch:025 ,particle:07, par err:0.0959, best part err:0.0907, best swarm err:0.0882
# epoch:025 ,particle:08, par err:0.0982, best part err:0.0936, best swarm err:0.0882
# epoch:025 ,particle:09, par err:0.1045, best part err:0.0963, best swarm err:0.0882
# epoch:025 ,particle:10, par err:0.0882, best part err:0.0882, best swarm err:0.0882
# epoch:025 ,particle:11, par err:0.1009, best part err:0.0937, best swarm err:0.0882
# epoch:025 ,particle:12, par err:0.1003, best part err:0.0948, best swarm err:0.0882
# epoch:025 ,particle:13, par err:0.0882, best part err:0.0882, best swarm err:0.0882
# epoch:025 ,particle:14, par err:0.1071, best part err:0.0966, best swarm err:0.0882
# epoch:025 ,particle:15, par err:0.1084, best part err:0.0962, best swarm err:0.0882
#
# -------------------------------------------------------------------------------------
# epoch:026 ,particle:01, par err:0.0900, best part err:0.0900, best swarm err:0.0869
# epoch:026 ,particle:02, par err:0.0869, best part err:0.0869, best swarm err:0.0869
# epoch:026 ,particle:03, par err:0.1127, best part err:0.0918, best swarm err:0.0869
# epoch:026 ,particle:04, par err:0.0904, best part err:0.0904, best swarm err:0.0869
# epoch:026 ,particle:05, par err:0.0889, best part err:0.0889, best swarm err:0.0869
# epoch:026 ,particle:06, par err:0.0895, best part err:0.0889, best swarm err:0.0869
# epoch:026 ,particle:07, par err:0.0893, best part err:0.0893, best swarm err:0.0869
# epoch:026 ,particle:08, par err:0.1056, best part err:0.0936, best swarm err:0.0869
# epoch:026 ,particle:09, par err:0.1200, best part err:0.0963, best swarm err:0.0869
# epoch:026 ,particle:10, par err:0.0882, best part err:0.0882, best swarm err:0.0869
# epoch:026 ,particle:11, par err:0.1163, best part err:0.0937, best swarm err:0.0869
# epoch:026 ,particle:12, par err:0.0917, best part err:0.0917, best swarm err:0.0869
# epoch:026 ,particle:13, par err:0.0878, best part err:0.0878, best swarm err:0.0869
# epoch:026 ,particle:14, par err:0.1300, best part err:0.0966, best swarm err:0.0869
# epoch:026 ,particle:15, par err:0.1164, best part err:0.0962, best swarm err:0.0869
#
# -------------------------------------------------------------------------------------
# epoch:027 ,particle:01, par err:0.0900, best part err:0.0900, best swarm err:0.0869
# epoch:027 ,particle:02, par err:0.0918, best part err:0.0869, best swarm err:0.0869
# epoch:027 ,particle:03, par err:0.1144, best part err:0.0918, best swarm err:0.0869
# epoch:027 ,particle:04, par err:0.0906, best part err:0.0904, best swarm err:0.0869
# epoch:027 ,particle:05, par err:0.0989, best part err:0.0889, best swarm err:0.0869
# epoch:027 ,particle:06, par err:0.1035, best part err:0.0889, best swarm err:0.0869
# epoch:027 ,particle:07, par err:0.1105, best part err:0.0893, best swarm err:0.0869
# epoch:027 ,particle:08, par err:0.1099, best part err:0.0936, best swarm err:0.0869
# epoch:027 ,particle:09, par err:0.0957, best part err:0.0957, best swarm err:0.0869
# epoch:027 ,particle:10, par err:0.0899, best part err:0.0882, best swarm err:0.0869
# epoch:027 ,particle:11, par err:0.1115, best part err:0.0937, best swarm err:0.0869
# epoch:027 ,particle:12, par err:0.1115, best part err:0.0917, best swarm err:0.0869
# epoch:027 ,particle:13, par err:0.0908, best part err:0.0878, best swarm err:0.0869
# epoch:027 ,particle:14, par err:0.0949, best part err:0.0949, best swarm err:0.0869
# epoch:027 ,particle:15, par err:0.0942, best part err:0.0942, best swarm err:0.0869
#
# -------------------------------------------------------------------------------------
# epoch:028 ,particle:01, par err:0.0922, best part err:0.0900, best swarm err:0.0869
# epoch:028 ,particle:02, par err:0.1001, best part err:0.0869, best swarm err:0.0869
# epoch:028 ,particle:03, par err:0.0947, best part err:0.0918, best swarm err:0.0869
# epoch:028 ,particle:04, par err:0.1030, best part err:0.0904, best swarm err:0.0869
# epoch:028 ,particle:05, par err:0.0957, best part err:0.0889, best swarm err:0.0869
# epoch:028 ,particle:06, par err:0.0994, best part err:0.0889, best swarm err:0.0869
# epoch:028 ,particle:07, par err:0.1019, best part err:0.0893, best swarm err:0.0869
# epoch:028 ,particle:08, par err:0.1020, best part err:0.0936, best swarm err:0.0869
# epoch:028 ,particle:09, par err:0.1013, best part err:0.0957, best swarm err:0.0869
# epoch:028 ,particle:10, par err:0.0948, best part err:0.0882, best swarm err:0.0869
# epoch:028 ,particle:11, par err:0.1017, best part err:0.0937, best swarm err:0.0869
# epoch:028 ,particle:12, par err:0.1009, best part err:0.0917, best swarm err:0.0869
# epoch:028 ,particle:13, par err:0.0949, best part err:0.0878, best swarm err:0.0869
# epoch:028 ,particle:14, par err:0.1027, best part err:0.0949, best swarm err:0.0869
# epoch:028 ,particle:15, par err:0.1039, best part err:0.0942, best swarm err:0.0869
#
# -------------------------------------------------------------------------------------
# epoch:029 ,particle:01, par err:0.1003, best part err:0.0900, best swarm err:0.0866
# epoch:029 ,particle:02, par err:0.0897, best part err:0.0869, best swarm err:0.0866
# epoch:029 ,particle:03, par err:0.1020, best part err:0.0918, best swarm err:0.0866
# epoch:029 ,particle:04, par err:0.0922, best part err:0.0904, best swarm err:0.0866
# epoch:029 ,particle:05, par err:0.1024, best part err:0.0889, best swarm err:0.0866
# epoch:029 ,particle:06, par err:0.0893, best part err:0.0889, best swarm err:0.0866
# epoch:029 ,particle:07, par err:0.1048, best part err:0.0893, best swarm err:0.0866
# epoch:029 ,particle:08, par err:0.0955, best part err:0.0936, best swarm err:0.0866
# epoch:029 ,particle:09, par err:0.1424, best part err:0.0957, best swarm err:0.0866
# epoch:029 ,particle:10, par err:0.0866, best part err:0.0866, best swarm err:0.0866
# epoch:029 ,particle:11, par err:0.0984, best part err:0.0937, best swarm err:0.0866
# epoch:029 ,particle:12, par err:0.1075, best part err:0.0917, best swarm err:0.0866
# epoch:029 ,particle:13, par err:0.0874, best part err:0.0874, best swarm err:0.0866
# epoch:029 ,particle:14, par err:0.1672, best part err:0.0949, best swarm err:0.0866
# epoch:029 ,particle:15, par err:0.1391, best part err:0.0942, best swarm err:0.0866
#
# -------------------------------------------------------------------------------------
# epoch:030 ,particle:01, par err:0.0927, best part err:0.0900, best swarm err:0.0866
# epoch:030 ,particle:02, par err:0.0879, best part err:0.0869, best swarm err:0.0866
# epoch:030 ,particle:03, par err:0.1546, best part err:0.0918, best swarm err:0.0866
# epoch:030 ,particle:04, par err:0.0878, best part err:0.0878, best swarm err:0.0866
# epoch:030 ,particle:05, par err:0.0878, best part err:0.0878, best swarm err:0.0866
# epoch:030 ,particle:06, par err:0.0909, best part err:0.0889, best swarm err:0.0866
# epoch:030 ,particle:07, par err:0.0885, best part err:0.0885, best swarm err:0.0866
# epoch:030 ,particle:08, par err:0.1213, best part err:0.0936, best swarm err:0.0866
# epoch:030 ,particle:09, par err:0.0917, best part err:0.0917, best swarm err:0.0866
# epoch:030 ,particle:10, par err:0.0941, best part err:0.0866, best swarm err:0.0866
# epoch:030 ,particle:11, par err:0.1281, best part err:0.0937, best swarm err:0.0866
# epoch:030 ,particle:12, par err:0.0872, best part err:0.0872, best swarm err:0.0866
# epoch:030 ,particle:13, par err:0.0949, best part err:0.0874, best swarm err:0.0866
# epoch:030 ,particle:14, par err:0.0922, best part err:0.0922, best swarm err:0.0866
# epoch:030 ,particle:15, par err:0.0919, best part err:0.0919, best swarm err:0.0866
#
# -------------------------------------------------------------------------------------
# epoch:031 ,particle:01, par err:0.0875, best part err:0.0875, best swarm err:0.0866
# epoch:031 ,particle:02, par err:0.0942, best part err:0.0869, best swarm err:0.0866
# epoch:031 ,particle:03, par err:0.0997, best part err:0.0918, best swarm err:0.0866
# epoch:031 ,particle:04, par err:0.0877, best part err:0.0877, best swarm err:0.0866
# epoch:031 ,particle:05, par err:0.0933, best part err:0.0878, best swarm err:0.0866
# epoch:031 ,particle:06, par err:0.0966, best part err:0.0889, best swarm err:0.0866
# epoch:031 ,particle:07, par err:0.0929, best part err:0.0885, best swarm err:0.0866
# epoch:031 ,particle:08, par err:0.1041, best part err:0.0936, best swarm err:0.0866
# epoch:031 ,particle:09, par err:0.1136, best part err:0.0917, best swarm err:0.0866
# epoch:031 ,particle:10, par err:0.1021, best part err:0.0866, best swarm err:0.0866
# epoch:031 ,particle:11, par err:0.1079, best part err:0.0937, best swarm err:0.0866
# epoch:031 ,particle:12, par err:0.0992, best part err:0.0872, best swarm err:0.0866
# epoch:031 ,particle:13, par err:0.1020, best part err:0.0874, best swarm err:0.0866
# epoch:031 ,particle:14, par err:0.1146, best part err:0.0922, best swarm err:0.0866
# epoch:031 ,particle:15, par err:0.1234, best part err:0.0919, best swarm err:0.0866
#
# -------------------------------------------------------------------------------------
# epoch:032 ,particle:01, par err:0.0915, best part err:0.0875, best swarm err:0.0866
# epoch:032 ,particle:02, par err:0.0953, best part err:0.0869, best swarm err:0.0866
# epoch:032 ,particle:03, par err:0.0887, best part err:0.0887, best swarm err:0.0866
# epoch:032 ,particle:04, par err:0.0874, best part err:0.0874, best swarm err:0.0866
# epoch:032 ,particle:05, par err:0.1256, best part err:0.0878, best swarm err:0.0866
# epoch:032 ,particle:06, par err:0.0946, best part err:0.0889, best swarm err:0.0866
# epoch:032 ,particle:07, par err:0.1110, best part err:0.0885, best swarm err:0.0866
# epoch:032 ,particle:08, par err:0.0893, best part err:0.0893, best swarm err:0.0866
# epoch:032 ,particle:09, par err:0.1421, best part err:0.0917, best swarm err:0.0866
# epoch:032 ,particle:10, par err:0.0918, best part err:0.0866, best swarm err:0.0866
# epoch:032 ,particle:11, par err:0.0893, best part err:0.0893, best swarm err:0.0866
# epoch:032 ,particle:12, par err:0.1431, best part err:0.0872, best swarm err:0.0866
# epoch:032 ,particle:13, par err:0.0939, best part err:0.0874, best swarm err:0.0866
# epoch:032 ,particle:14, par err:0.1663, best part err:0.0922, best swarm err:0.0866
# epoch:032 ,particle:15, par err:0.1354, best part err:0.0919, best swarm err:0.0866
#
# -------------------------------------------------------------------------------------
# epoch:033 ,particle:01, par err:0.0928, best part err:0.0875, best swarm err:0.0866
# epoch:033 ,particle:02, par err:0.0871, best part err:0.0869, best swarm err:0.0866
# epoch:033 ,particle:03, par err:0.0923, best part err:0.0887, best swarm err:0.0866
# epoch:033 ,particle:04, par err:0.0874, best part err:0.0874, best swarm err:0.0866
# epoch:033 ,particle:05, par err:0.0902, best part err:0.0878, best swarm err:0.0866
# epoch:033 ,particle:06, par err:0.0887, best part err:0.0887, best swarm err:0.0866
# epoch:033 ,particle:07, par err:0.0903, best part err:0.0885, best swarm err:0.0866
# epoch:033 ,particle:08, par err:0.0941, best part err:0.0893, best swarm err:0.0866
# epoch:033 ,particle:09, par err:0.1058, best part err:0.0917, best swarm err:0.0866
# epoch:033 ,particle:10, par err:0.0871, best part err:0.0866, best swarm err:0.0866
# epoch:033 ,particle:11, par err:0.0968, best part err:0.0893, best swarm err:0.0866
# epoch:033 ,particle:12, par err:0.0945, best part err:0.0872, best swarm err:0.0866
# epoch:033 ,particle:13, par err:0.0871, best part err:0.0871, best swarm err:0.0866
# epoch:033 ,particle:14, par err:0.1070, best part err:0.0922, best swarm err:0.0866
# epoch:033 ,particle:15, par err:0.1114, best part err:0.0919, best swarm err:0.0866
#
# -------------------------------------------------------------------------------------
# epoch:034 ,particle:01, par err:0.0920, best part err:0.0875, best swarm err:0.0865
# epoch:034 ,particle:02, par err:0.0882, best part err:0.0869, best swarm err:0.0865
# epoch:034 ,particle:03, par err:0.1019, best part err:0.0887, best swarm err:0.0865
# epoch:034 ,particle:04, par err:0.0889, best part err:0.0874, best swarm err:0.0865
# epoch:034 ,particle:05, par err:0.0869, best part err:0.0869, best swarm err:0.0865
# epoch:034 ,particle:06, par err:0.0883, best part err:0.0883, best swarm err:0.0865
# epoch:034 ,particle:07, par err:0.0865, best part err:0.0865, best swarm err:0.0865
# epoch:034 ,particle:08, par err:0.1067, best part err:0.0893, best swarm err:0.0865
# epoch:034 ,particle:09, par err:0.0893, best part err:0.0893, best swarm err:0.0865
# epoch:034 ,particle:10, par err:0.0903, best part err:0.0866, best swarm err:0.0865
# epoch:034 ,particle:11, par err:0.1106, best part err:0.0893, best swarm err:0.0865
# epoch:034 ,particle:12, par err:0.0877, best part err:0.0872, best swarm err:0.0865
# epoch:034 ,particle:13, par err:0.0888, best part err:0.0871, best swarm err:0.0865
# epoch:034 ,particle:14, par err:0.0899, best part err:0.0899, best swarm err:0.0865
# epoch:034 ,particle:15, par err:0.0895, best part err:0.0895, best swarm err:0.0865
#
# -------------------------------------------------------------------------------------
# epoch:035 ,particle:01, par err:0.0866, best part err:0.0866, best swarm err:0.0862
# epoch:035 ,particle:02, par err:0.0928, best part err:0.0869, best swarm err:0.0862
# epoch:035 ,particle:03, par err:0.0939, best part err:0.0887, best swarm err:0.0862
# epoch:035 ,particle:04, par err:0.0862, best part err:0.0862, best swarm err:0.0862
# epoch:035 ,particle:05, par err:0.0870, best part err:0.0869, best swarm err:0.0862
# epoch:035 ,particle:06, par err:0.0895, best part err:0.0883, best swarm err:0.0862
# epoch:035 ,particle:07, par err:0.0885, best part err:0.0865, best swarm err:0.0862
# epoch:035 ,particle:08, par err:0.0973, best part err:0.0893, best swarm err:0.0862
# epoch:035 ,particle:09, par err:0.1694, best part err:0.0893, best swarm err:0.0862
# epoch:035 ,particle:10, par err:0.0929, best part err:0.0866, best swarm err:0.0862
# epoch:035 ,particle:11, par err:0.0992, best part err:0.0893, best swarm err:0.0862
# epoch:035 ,particle:12, par err:0.1112, best part err:0.0872, best swarm err:0.0862
# epoch:035 ,particle:13, par err:0.0944, best part err:0.0871, best swarm err:0.0862
# epoch:035 ,particle:14, par err:0.1990, best part err:0.0899, best swarm err:0.0862
# epoch:035 ,particle:15, par err:0.1748, best part err:0.0895, best swarm err:0.0862
#
# -------------------------------------------------------------------------------------
# epoch:036 ,particle:01, par err:0.0916, best part err:0.0866, best swarm err:0.0859
# epoch:036 ,particle:02, par err:0.0929, best part err:0.0869, best swarm err:0.0859
# epoch:036 ,particle:03, par err:0.0860, best part err:0.0860, best swarm err:0.0859
# epoch:036 ,particle:04, par err:0.0965, best part err:0.0862, best swarm err:0.0859
# epoch:036 ,particle:05, par err:0.0901, best part err:0.0869, best swarm err:0.0859
# ...
# epoch:139 ,particle:03, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:04, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:06, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:07, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:09, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:10, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:11, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:13, par err:0.0774, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:14, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:139 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:140 ,particle:01, par err:0.0781, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:03, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:04, par err:0.0782, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:05, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:06, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:07, par err:0.0781, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:09, par err:0.0799, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:10, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:11, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:13, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:14, par err:0.0776, best part err:0.0771, best swarm err:0.0771
# epoch:140 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:141 ,particle:01, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:03, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:04, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:05, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:06, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:07, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:09, par err:0.0777, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:10, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:11, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:13, par err:0.0774, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:14, par err:0.0774, best part err:0.0771, best swarm err:0.0771
# epoch:141 ,particle:15, par err:0.0772, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:142 ,particle:01, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:03, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:04, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:06, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:07, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:09, par err:0.0778, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:10, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:11, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:13, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:14, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:142 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:143 ,particle:01, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:03, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:04, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:06, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:07, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:09, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:10, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:11, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:13, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:14, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:143 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:144 ,particle:01, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:03, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:04, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:06, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:07, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:09, par err:0.0775, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:10, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:11, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:12, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:13, par err:0.0776, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:14, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:144 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:145 ,particle:01, par err:0.0779, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:03, par err:0.0774, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:04, par err:0.0779, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:05, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:06, par err:0.0774, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:07, par err:0.0779, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:09, par err:0.0795, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:10, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:11, par err:0.0774, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:13, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:14, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:145 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:146 ,particle:01, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:03, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:04, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:06, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:07, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:09, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:10, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:11, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:12, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:13, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:14, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:146 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:147 ,particle:01, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:03, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:04, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:06, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:07, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:09, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:10, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:11, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:13, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:14, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:147 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:148 ,particle:01, par err:0.0775, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:03, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:04, par err:0.0775, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:06, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:07, par err:0.0775, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:09, par err:0.0784, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:10, par err:0.0773, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:11, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:13, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:14, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:148 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:149 ,particle:01, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:03, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:04, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:06, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:07, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:09, par err:0.0775, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:10, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:11, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:12, par err:0.0772, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:13, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:14, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:149 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------
# epoch:150 ,particle:01, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:02, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:03, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:04, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:05, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:06, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:07, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:08, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:09, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:10, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:11, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:12, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:13, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:14, par err:0.0771, best part err:0.0771, best swarm err:0.0771
# epoch:150 ,particle:15, par err:0.0771, best part err:0.0771, best swarm err:0.0771
#
# -------------------------------------------------------------------------------------

# %%
#np.savetxt('report01.txt',report)

# %%
ann_hp = pso1.ann.getANN_Hyperparameters()
pso_hp = pso1.getPSO_Hyperparameters()

plot_string = 'Function:{}\nANN Hyperparameters: Act func- {}, Layer Arch {}\n'.format(ann_hp[0],ann_hp[1],ann_hp[2])
plot_string += 'PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(pso_hp[0],pso_hp[1],pso_hp[2],pso_hp[3],pso_hp[4])


plt.figure(figsize = (10,10))
plt.plot(epoch_count,data_Swarm_best,'b', label='SwarmBestQuality')
plt.plot(epoch_count,data_Particle_current_best,'c', label='CurrentBestQuality')
plt.plot(epoch_count,data_Particle_current_worst,'r', label='CurrentWorstQuality')
plt.plot(epoch_count,data_particle_current_average,'y', label='CurrentAverageQuality')
plt.ylabel('Error')
plt.xlabel('Epoch')

#plt.legend(title='Parameter where:')
plt.legend(loc='center right', shadow=False, fontsize='medium')
plt.title('QUALITIES',fontsize='x-large')


plt.text(0.95, 0.01, plot_string,
        verticalalignment='top', horizontalalignment='left',
        color='green', fontsize=10)

plt.savefig('foo.png')

# %% [markdown]
# ***Investigation 2.1: Varying Swarm Size***

# %%
i_range = 4 #hyperparameters variant
k_repeats = 15 #repeat each configuration sicne PSO is stocastic process

#Select Function:
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)

#Select ANN Hyperparameters
hidden_layer_neurons = [7,7]
activation = 'Sigmoid' # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)
X,Y = read_data(func)

#Select PSO Hyperparameters
swarm_size = [5, 10, 15, 30]
pso_alpha = 0.9 #0.729
pso_beta = 1.6 #1.49
pso_delta = 1.6 #1.49
max_epochs = 50
bound =50
bound_max = bound
bound_min = -bound


# initiate list of ann and pso objects
ann_list = []
pso_list= []

data_graph =[]
data_err_box =[]
for i in range(i_range):
    ann_list.append(NeuralNetwork(func, hidden_layer_neurons, activation, X,Y))
    
    box_temp = []
    graph_temp = []
    pso_list_temp = []
    for k in range(k_repeats):
        pso_list_temp.append(ParticleSwarmOptimizer(swarm_size[i],pso_alpha,pso_beta,pso_delta,max_epochs, bound_max, bound_min, ann_list[i]))
            
        best_swarm_err, report, epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average = pso_list_temp[k].forward()
            
        box_temp.append(best_swarm_err)
        #data_graph.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])
        graph_temp.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])

    data_err_box.append(box_temp)
    data_graph.append(graph_temp)
    pso_list.append(pso_list_temp)

#--------------------------------------------------------------------------------------#
#CREATE BOX PLOTS

fig,ax=plt.subplots()
ax.boxplot(data_err_box)
plt.savefig('varying_swarm_size_box.png')

#--------------------------------------------------------------------------------------#
#CREATE RUNNING GRAPHS

pso_hp = []
ann_hp = []
plot_string = []

#Set Sub plots parameters
nx = 1
ny = i_range
dxs = 8
dys = 6
fig, axs = plt.subplots(ny, nx, sharey = True, figsize=(dxs*nx, dys*ny))
fig.suptitle('QUALITIES',fontsize='x-large')


for ij in range(i_range):
    best_ind = np.argmin(data_err_box[ij])
    pso_hp.append(pso_list[ij][best_ind].getPSO_Hyperparameters())
    ann_hp.append(pso_list[ij][best_ind].ann.getANN_Hyperparameters())
    
    temp_string = 'Function:{}\nANN Hyperparameters: Act func- {}, Layer Arch {}\n'.format(ann_hp[ij][0],ann_hp[ij][1],ann_hp[ij][2])
    temp_string += 'PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(pso_hp[ij][0],pso_hp[ij][1],pso_hp[ij][2],pso_hp[ij][3],pso_hp[ij][4])
    plot_string.append(temp_string)

    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][3], 'b', label='SwarmBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][4],'c', label='CurrentBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][5],'r', label='CurrentWorstQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][6],'y', label='CurrentAverageQuality')
    
    axs[ij].legend(loc='center right', shadow=False, fontsize='medium')
    axs[ij].set_title(plot_string[ij],fontsize='small')
    

plt.savefig('varying_swarm_size_graphs.png')

#--------------------------------------------------------------------------------------#
#SAVING REPORT TO TXT
msg=''
for ii in range(i_range):
    for jj in range(k_repeats):
        msg += data_graph[ii][jj][1]
        msg += '/n'    
        
with open("varying_swarm_size_report.txt", "w") as text_file:
    text_file.write(msg)
# Out:
# C:\Users\arda0364\AppData\Local\Continuum\anaconda3\envs\BIC\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ***Investigation 2.2: Varying Activation Fuction***

# %%
i_range = 5 #hyperparameters variant
k_repeats = 15 #repeat each configuration sicne PSO is stocastic process

#Select Function:
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)

#Select ANN Hyperparameters
hidden_layer_neurons = [7,7]
activation = ['Null', 'Sigmoid', 'Hyperbolic Tangent', 'Cosine', 'Gaussian'] # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)
X,Y = read_data(func)

#Select PSO Hyperparameters
swarm_size = 15
pso_alpha = 0.9 #0.729
pso_beta = 1.6 #1.49
pso_delta = 1.6 #1.49
max_epochs = 25
bound =50
bound_max = bound
bound_min = -bound


# initiate list of ann and pso objects
ann_list = []
pso_list= []

data_graph =[]
data_err_box =[]
for i in range(i_range):
    ann_list.append(NeuralNetwork(func, hidden_layer_neurons, activation[i], X,Y))
    
    box_temp = []
    graph_temp = []
    pso_list_temp = []
    for k in range(k_repeats):
        pso_list_temp.append(ParticleSwarmOptimizer(swarm_size,pso_alpha,pso_beta,pso_delta,max_epochs, bound_max, bound_min, ann_list[i]))
            
        best_swarm_err, report, epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average = pso_list_temp[k].forward()
            
        box_temp.append(best_swarm_err)
        #data_graph.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])
        graph_temp.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])

    data_err_box.append(box_temp)
    data_graph.append(graph_temp)
    pso_list.append(pso_list_temp)

#--------------------------------------------------------------------------------------#
#CREATE BOX PLOTS

fig,ax=plt.subplots()
ax.boxplot(data_err_box)
plt.savefig('varying_Activation_function_box.png')

#--------------------------------------------------------------------------------------#
#CREATE RUNNING GRAPHS

pso_hp = []
ann_hp = []
plot_string = []

#Set Sub plots parameters
nx = 1
ny = i_range
dxs = 8
dys = 6
fig, axs = plt.subplots(ny, nx, sharey = True, figsize=(dxs*nx, dys*ny))
fig.suptitle('QUALITIES',fontsize='x-large')

for ij in range(i_range):
    best_ind = np.argmin(data_err_box[ij])
    pso_hp.append(pso_list[ij][best_ind].getPSO_Hyperparameters())
    ann_hp.append(pso_list[ij][best_ind].ann.getANN_Hyperparameters())
    
    temp_string = 'Function:{}\nANN Hyperparameters: Act func- {}, Layer Arch {}\n'.format(ann_hp[ij][0],ann_hp[ij][1],ann_hp[ij][2])
    temp_string += 'PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(pso_hp[ij][0],pso_hp[ij][1],pso_hp[ij][2],pso_hp[ij][3],pso_hp[ij][4])
    plot_string.append(temp_string)

    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][3], 'b', label='SwarmBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][4],'c', label='CurrentBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][5],'r', label='CurrentWorstQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][6],'y', label='CurrentAverageQuality')
    
    axs[ij].legend(loc='center right', shadow=False, fontsize='medium')
    axs[ij].set_title(plot_string[ij],fontsize='small')

plt.savefig('varying_Activation_function_graphs.png')

#--------------------------------------------------------------------------------------#
#SAVING REPORT TO TXT
msg=''
for ii in range(i_range):
    for jj in range(k_repeats):
        msg += data_graph[ii][jj][1]
        msg += '/n'    
        
with open("varying_Activation_function_report.txt", "w") as text_file:
    text_file.write(msg)

# %% [markdown]
# ***Investigation 2.3: Varying no. of layers in ANN***

# %%
i_range = 4 #hyperparameters variant
k_repeats = 15 #repeat each configuration sicne PSO is stocastic process

#Select Function:
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)

#Select ANN Hyperparameters
hidden_layer_neurons = [[7],[7,7],[7,7,7],[7,7,7,7]]
activation = 'Hyperbolic Tangent' # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)
X,Y = read_data(func)

#Select PSO Hyperparameters
swarm_size = 15
pso_alpha = 0.9 #0.729
pso_beta = 1.6 #1.49
pso_delta = 1.6 #1.49
max_epochs = 25
bound =50
bound_max = bound
bound_min = -bound


# initiate list of ann and pso objects
ann_list = []
pso_list= []

data_graph =[]
data_err_box =[]
for i in range(i_range):
    ann_list.append(NeuralNetwork(func, hidden_layer_neurons[i], activation, X,Y))
    
    box_temp = []
    graph_temp = []
    pso_list_temp = []
    for k in range(k_repeats):
        pso_list_temp.append(ParticleSwarmOptimizer(swarm_size,pso_alpha,pso_beta,pso_delta,max_epochs, bound_max, bound_min, ann_list[i]))
            
        best_swarm_err, report, epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average = pso_list_temp[k].forward()
            
        box_temp.append(best_swarm_err)
        #data_graph.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])
        graph_temp.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])

    data_err_box.append(box_temp)
    data_graph.append(graph_temp)
    pso_list.append(pso_list_temp)

#--------------------------------------------------------------------------------------#
#CREATE BOX PLOTS

fig,ax=plt.subplots()
ax.boxplot(data_err_box)
plt.savefig('varying_no_of_layers_box.png')

#--------------------------------------------------------------------------------------#
#CREATE RUNNING GRAPHS

pso_hp = []
ann_hp = []
plot_string = []

#Set Sub plots parameters
nx = 1
ny = i_range
dxs = 8
dys = 6
fig, axs = plt.subplots(ny, nx, sharey = True, figsize=(dxs*nx, dys*ny))
fig.suptitle('QUALITIES',fontsize='x-large')

for ij in range(i_range):
    best_ind = np.argmin(data_err_box[ij])
    pso_hp.append(pso_list[ij][best_ind].getPSO_Hyperparameters())
    ann_hp.append(pso_list[ij][best_ind].ann.getANN_Hyperparameters())
    
    temp_string = 'Function:{}\nANN Hyperparameters: Act func- {}, Layer Arch {}\n'.format(ann_hp[ij][0],ann_hp[ij][1],ann_hp[ij][2])
    temp_string += 'PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(pso_hp[ij][0],pso_hp[ij][1],pso_hp[ij][2],pso_hp[ij][3],pso_hp[ij][4])
    plot_string.append(temp_string)

    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][3], 'b', label='SwarmBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][4],'c', label='CurrentBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][5],'r', label='CurrentWorstQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][6],'y', label='CurrentAverageQuality')
    
    axs[ij].legend(loc='center right', shadow=False, fontsize='medium')
    axs[ij].set_title(plot_string[ij],fontsize='small')

plt.savefig('varying_no_of_layers_graphs.png')

#--------------------------------------------------------------------------------------#
#SAVING REPORT TO TXT
msg=''
for ii in range(i_range):
    for jj in range(k_repeats):
        msg += data_graph[ii][jj][1]
        msg += '/n'    
        
with open("varying_no_of_layers_report.txt", "w") as text_file:
    text_file.write(msg)

# %% [markdown]
# ***Investigation 2.4: Varying no. of neurons in ANN***

# %%
i_range = 4 #hyperparameters variant
k_repeats = 15 #repeat each configuration sicne PSO is stocastic process

#Select Function:
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)

#Select ANN Hyperparameters
hidden_layer_neurons = [[1,1],[5,3],[8,5],[10,8]]
activation = 'Sigmoid' # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)
X,Y = read_data(func)

#Select PSO Hyperparameters
swarm_size = 15
pso_alpha = 0.9 #0.729
pso_beta = 1.6 #1.49
pso_delta = 1.6 #1.49
max_epochs = 25
bound =50
bound_max = bound
bound_min = -bound


# initiate list of ann and pso objects
ann_list = []
pso_list= []

data_graph =[]
data_err_box =[]
for i in range(i_range):
    ann_list.append(NeuralNetwork(func, hidden_layer_neurons[i], activation, X,Y))
    
    box_temp = []
    graph_temp = []
    pso_list_temp = []
    for k in range(k_repeats):
        pso_list_temp.append(ParticleSwarmOptimizer(swarm_size,pso_alpha,pso_beta,pso_delta,max_epochs, bound_max, bound_min, ann_list[i]))
            
        best_swarm_err, report, epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average = pso_list_temp[k].forward()
            
        box_temp.append(best_swarm_err)
        #data_graph.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])
        graph_temp.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])

    data_err_box.append(box_temp)
    data_graph.append(graph_temp)
    pso_list.append(pso_list_temp)

#--------------------------------------------------------------------------------------#
#CREATE BOX PLOTS

fig,ax=plt.subplots()
ax.boxplot(data_err_box)
plt.savefig('varying_no_of_neurons_box.png')

#--------------------------------------------------------------------------------------#
#CREATE RUNNING GRAPHS

pso_hp = []
ann_hp = []
plot_string = []

#Set Sub plots parameters
nx = 1
ny = i_range
dxs = 8
dys = 6
fig, axs = plt.subplots(ny, nx, sharey = True, figsize=(dxs*nx, dys*ny))
fig.suptitle('QUALITIES',fontsize='x-large')

for ij in range(i_range):
    best_ind = np.argmin(data_err_box[ij])
    pso_hp.append(pso_list[ij][best_ind].getPSO_Hyperparameters())
    ann_hp.append(pso_list[ij][best_ind].ann.getANN_Hyperparameters())
    
    temp_string = 'Function:{}\nANN Hyperparameters: Act func- {}, Layer Arch {}\n'.format(ann_hp[ij][0],ann_hp[ij][1],ann_hp[ij][2])
    temp_string += 'PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(pso_hp[ij][0],pso_hp[ij][1],pso_hp[ij][2],pso_hp[ij][3],pso_hp[ij][4])
    plot_string.append(temp_string)

    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][3], 'b', label='SwarmBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][4],'c', label='CurrentBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][5],'r', label='CurrentWorstQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][6],'y', label='CurrentAverageQuality')
    
    axs[ij].legend(loc='center right', shadow=False, fontsize='medium')
    axs[ij].set_title(plot_string[ij],fontsize='small')

plt.savefig('varying_no_of_neurons_graphs.png')

#--------------------------------------------------------------------------------------#
#SAVING REPORT TO TXT
msg=''
for ii in range(i_range):
    for jj in range(k_repeats):
        msg += data_graph[ii][jj][1]
        msg += '/n'    
        
with open("varying_no_of_neurons_report.txt", "w") as text_file:
    text_file.write(msg)

# %% [markdown]
# ***Investigation 2.5: Varying weights in PSO***

# %%
i_range = 6 #hyperparameters variant
k_repeats = 15 #repeat each configuration sicne PSO is stocastic process

#Select Function:
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)

#Select ANN Hyperparameters
hidden_layer_neurons = [7,7]
activation = 'Sigmoid' # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)
X,Y = read_data(func)

#Select PSO Hyperparameters
swarm_size = 5
pso_alpha = [0.2, 0.6, 0.9, 1.2, 1.4, 1.6] #0.729
pso_beta = 1.6 #1.49
pso_delta = 1.6 #1.49
max_epochs = 50
bound =50
bound_max = bound
bound_min = -bound


# initiate list of ann and pso objects
ann_list = []
pso_list= []

data_graph =[]
data_err_box =[]
for i in range(i_range):
    ann_list.append(NeuralNetwork(func, hidden_layer_neurons, activation, X,Y))
    
    box_temp = []
    graph_temp = []
    pso_list_temp = []
    for k in range(k_repeats):
        pso_list_temp.append(ParticleSwarmOptimizer(swarm_size,pso_alpha[i],pso_beta,pso_delta,max_epochs, bound_max, bound_min, ann_list[i]))
            
        best_swarm_err, report, epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average = pso_list_temp[k].forward()
            
        box_temp.append(best_swarm_err)
        #data_graph.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])
        graph_temp.append([best_swarm_err,report,epoch_count, data_Swarm_best, data_Particle_current_best,data_Particle_current_worst,data_particle_current_average])

    data_err_box.append(box_temp)
    data_graph.append(graph_temp)
    pso_list.append(pso_list_temp)

#--------------------------------------------------------------------------------------#
#CREATE BOX PLOTS

fig,ax=plt.subplots()
ax.boxplot(data_err_box)
plt.savefig('varying_swarm_size_box.png')

#--------------------------------------------------------------------------------------#
#CREATE RUNNING GRAPHS

pso_hp = []
ann_hp = []
plot_string = []

#Set Sub plots parameters
nx = 1
ny = i_range
dxs = 8
dys = 6
fig, axs = plt.subplots(ny, nx, sharey = True, figsize=(dxs*nx, dys*ny))
fig.suptitle('QUALITIES',fontsize='x-large')


for ij in range(i_range):
    best_ind = np.argmin(data_err_box[ij])
    pso_hp.append(pso_list[ij][best_ind].getPSO_Hyperparameters())
    ann_hp.append(pso_list[ij][best_ind].ann.getANN_Hyperparameters())
    
    temp_string = 'Function:{}\nANN Hyperparameters: Act func- {}, Layer Arch {}\n'.format(ann_hp[ij][0],ann_hp[ij][1],ann_hp[ij][2])
    temp_string += 'PSO Hyperparameters: swarm size{}, inertia weight{}, cognitive weight{}, social weight{}, epochs{}'.format(pso_hp[ij][0],pso_hp[ij][1],pso_hp[ij][2],pso_hp[ij][3],pso_hp[ij][4])
    plot_string.append(temp_string)

    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][3], 'b', label='SwarmBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][4],'c', label='CurrentBestQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][5],'r', label='CurrentWorstQuality')
    axs[ij].plot(data_graph[ij][best_ind][2], data_graph[ij][best_ind][6],'y', label='CurrentAverageQuality')
    
    axs[ij].legend(loc='center right', shadow=False, fontsize='medium')
    axs[ij].set_title(plot_string[ij],fontsize='small')
    

plt.savefig('varying_swarm_size_graphs.png')

#--------------------------------------------------------------------------------------#
#SAVING REPORT TO TXT
msg=''
for ii in range(i_range):
    for jj in range(k_repeats):
        msg += data_graph[ii][jj][1]
        msg += '/n'    
        
with open("varying_swarm_size_report.txt", "w") as text_file:
    text_file.write(msg)
# Out:
# C:\Users\arda0364\AppData\Local\Continuum\anaconda3\envs\BIC\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(len(pso_list))
print(len(pso_list[0]))
print(len(ann_list))

# %%
print(len(data_graph))
print(len(data_graph[0]))
print(len(data_graph[0][0]))

len(data_err_box)
len(data_err_box[0])

# %%
#data_graph[0][0][1]
type(data_graph[0][0][1])
# Out:
# str

# %%
data_graph[0][0][3]

# %%
print(data_err_box[0])
print(np.argmin(data_err_box[0]))

# %%
plt.figure(figsize = (10,10))
plt.plot(epoch_count,data_Swarm_best,'b', label='SwarmBestQuality')
plt.plot(epoch_count,data_Particle_current_best,'c', label='CurrentBestQuality')
plt.plot(epoch_count,data_Particle_current_worst,'r', label='CurrentWorstQuality')
plt.plot(epoch_count,data_particle_current_average,'y', label='CurrentAverageQuality')
plt.ylabel('Error')
plt.xlabel('Epoch')

#plt.legend(title='Parameter where:')
plt.legend(loc='center right', shadow=False, fontsize='medium')
plt.title('QUALITIES',fontsize='x-large')


plt.text(0.95, 0.01, plot_string,
        verticalalignment='top', horizontalalignment='left',
        color='green', fontsize=10)

plt.savefig('foo.png')

# %%
data_err_box = [[0.08482979983091354, 0.08392835408449173, 0.08371108770370483, 0.08370077610015869, 0.08356551080942154, 0.0835561528801918, 0.08199528604745865, 0.07882919907569885, 0.07862982153892517, 0.0786231979727745], [0.07758678495883942, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019, 0.07756020873785019]]

# %%
print(data_err_box[1])

# %%
fig,ax=plt.subplots()
ax.boxplot(data_err_box)

# %%
plt.boxplot(data_err_box[0])

# %%
plt.boxplot(data_err_box[1],1)
