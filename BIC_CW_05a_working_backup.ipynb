# %% [markdown]
# ## Function Approximation
# ### Using the PSO algorithm to optimise the ANN's parameters

# %% [markdown]
# **Import Resources**

# %%
# import resources

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#import ipywidgets as widgets
#from ipywidgets import interact, interact_manual

# %% [markdown]
# **1. Create Neural Network Class**

# %%
class NeuralNetwork:    
    def __init__(self, func, hiddenLayerNeurons, activation, inputList, outputList):
        self.func = func # name of the function to be optimized
        self.layerArch = list.copy(hiddenLayerNeurons) #list of neurons in the hidden layers
        self.activation = activation # name of the activation fuction
          
        self.inputArray = inputList # array of given input dataset
        self.outputArray = outputList # array of the desired output dataset
        #print(self.inputArray,self.outputArray)
        
        # adding input and output layers to the hidden neurons list
        self.inputOutputNeurons()
        
        # calculate number of weights
        self.nWeights = self.numWeights()
        
        # set activation function
        self.actFunc = self.functionSelection()
        
        # set indices at which weight matrix to be split for matrix multiplication
        self.splitIndices = self.splitIndices()
        
    def getANN_Hyperparameters(self):
        return [self.func, self.actFunc, self.layerArch]
        
    def getnWeights(self): # getter methonds for number of weights
        return self.nWeights
        
    def inputOutputNeurons(self): # a private method to neuralNetwork class
        # Set number neurons in the Input layer
        if self.func in ('XOR','Complex'):
            self.layerArch.insert(0,2) # XOR & Complex functions are based on two input variables
        else:
            self.layerArch.insert(0,1) # Linear, Cubic, Sine, Tanh functions are based on single input variable
       
        # Set number of neurons in the Output layer
        self.layerArch.append(1) # only single output value is expected from the fuction
        
    def numWeights(self):# a private method to neuralNetwork class
        n_weights = sum(self.layerArch[i]*self.layerArch[i+1] for i in range(len(self.layerArch)-1))
        return n_weights
    
    def functionSelection(self):# a private method to neuralNetwork class
        return activation_funcs[self.activation]
    
    def splitIndices(self):
        indices = []
        for i in range(len(self.layerArch)-1):
            indices.append(self.layerArch[i]*self.layerArch[i+1])

        splitIndices = []
        splitIndices.append(indices[0])
        for j in range(1,len(indices)-1):
            splitIndices.append(splitIndices[j-1] + indices[j])

        return splitIndices
    
    def forward(self, weights):
        
        # to do: check the length of list of weigths matches the number weights
        
        wArray = np.split(weights,self.splitIndices)
        #print("splitIndices",self.splitIndices)
        #print("wArray",wArray)
        #print("layerArch", self.layerArch)
        
        wMatrix=[]
        for i in range(0,len(self.layerArch)-1):
            wMatrix.append(wArray[i].reshape(self.layerArch[i+1],self.layerArch[i]))
        #print("wArray after reshape", wMatrix)
    
        desiredArray = np.copy(self.outputArray)
        predictArray = []
        
        for i in range(len(self.inputArray)):
            ih = self.inputArray[i].reshape(-1,1)
            for j in range(0,len(self.layerArch)-1):
                #print("wMatrix = ", wMatrix[j], "ih = ", ih)
                ih = np.matmul(wMatrix[j],ih)
            
                if j != (len(self.layerArch)-1):
                    ih = self.actFunc(ih)
            predictArray.append(ih)
            
        #print(len(desiredArray), len(predictArray))

        squeezePredict = np.squeeze(predictArray)

        mse = ((desiredArray - squeezePredict)**2).mean(axis = None)
       
        return mse

# %% [markdown]
# **2. Create PSO Class**<br>
# swarmsize - desired swarm size i.e. weight array<br>
# $ \alpha \gets$ inertia weight i.e. proportion of velocity to be retained<br>
# $ \beta \gets$ cognitive weight i.e. proportion of personal best to be retained<br>
# $ \delta \gets$ social weight i.e. proportion of global best to be retained<br>
# $ \epsilon \gets$ jump size of a particle<br><br>
# **Enforcing Boundaries**: enforced boundaries by Reinitialising the position of out of bounds particles<br>

# %%
class ParticleSwarmOptimizer:    
    def __init__(self, swarm_size,pso_alpha, pso_beta, pso_delta, max_epochs, bound_max, bound_min):
        # PSO parameters
        self.swarmSize = swarm_size # number of particles in swarm
        self.psoAlpha = pso_alpha # inertia weight
        self.psoBeta = pso_beta # cognitive weight 
        self.psoDelta = pso_delta # social weight
        self.maxEpochs = max_epochs # maximum number of iterations

        self.bound_max = bound_max
        self.bound_min = bound_min
        
        self.data =[] # list to record data

    def getSwarmSize(self):
        return self.swarmSize # no of particles in swarm
    
    def getRunData(self):
        return self.data
    
    def getPSO_Hyperparameters(self):
        return [self.swarmSize, self.psoAlpha, self.psoBeta, self.psoDelta, self.maxEpochs, self.bound_max, self.bound_min]
   
    def forward(self,swarm):
        
        # initialise global best position and fittness/error
        best_swarm_pos = np.ones((swarm[0].getDim()))
        best_swarm_err = 500
        
        data=[]
        epoch = 0
        while epoch < self.maxEpochs: # run until fixed number of iterations
            
            #Update global best
            for ii in range(self.swarmSize): # for each particle in swarm/population
                
                position_ii = swarm[ii].getPosition()
                err_ii = (swarm[ii].getError())
  
                # update Global/swarm best error and position if found comparing fitness/error
                if err_ii < best_swarm_err:
                    best_swarm_err = err_ii
                    best_swarm_pos = position_ii
                

            for i in range(self.swarmSize): # for each particle in swarm/population
                
                # Gather information            
                dim_i = swarm[i].getDim()
                position_i = swarm[i].getPosition()
                velocity_i = swarm[i].getVelocity()
                best_part_error_i = swarm[i].getBestPartErr()
                best_part_position_i = swarm[i].getBestPartPos()
                err_i = swarm[i].getError()
                
                print('epoch:{:03d} ,particle:{:02d}, par err:{:0.5f}, best part err:{:0.5f}, best swarm err:{:0.2f}'.
                      format(epoch+1, i+1, err_i, best_part_error_i ,best_swarm_err))
                
                #self.data.append([('epoch',epoch+1),('particle',i+1),('Particle Current Quality',err_i),('Particle Best Quality',best_part_error_i), ('Global Best Quality',best_swarm_err)])
                self.data.append([epoch+1,i+1,err_i,best_part_error_i,best_swarm_err])
                  
                
                # compute particle new velocity
                for k in range(dim_i): # for each dimension/weight in particle i
                    a = self.psoAlpha*velocity_i[k]
                    b = self.psoBeta*(best_part_position_i[k] - position_i[k])
                    c = self.psoDelta*(best_swarm_pos[k] - position_i[k])
                    velocity_i[k] = a+b+c

                    
                # compute particle new position
                position_f = np.add(position_i,velocity_i)
                
                
                # enforcing boundaries by Reinitialising the position of out of bounds particles
                kk=0
                while kk < dim_i:
                    if position_f[kk] >= self.bound_max or position_f[kk] <= self.bound_min:
                        position_f = (np.random.rand((dim_i)).astype(np.float32)-0.5)/2
                        velocity_i = (np.random.rand((dim_i)).astype(np.float32)-0.5)/2
                        print('weights breached at weights#',kk)
                        break
                    kk +=1
                
                              
                # compute new fitness
                new_err = swarm[i].ann.forward(position_f)
                
                # update particle best error and position if found comparing fitness/error
                if new_err < best_part_error_i:
                    swarm[i].setBestPartErr(new_err)
                    swarm[i].setBestPartPos(position_f)
                
                # update particle class parameters              
                swarm[i].setPosition(position_f) # update particle position
                swarm[i].setVelocity(velocity_i) #update particle velocity
                swarm[i].setError(new_err) #update particle current error
                
                #print('epoch:{:03d} ,particle:{:02d}, par err:{:0.5f}, best part err:{:0.5f}, best swarm err:{:0.2f}'.
                      #format(epoch+1, i+1, new_err, swarm[i].getBestPartErr() ,best_swarm_err))
            
            
            print('\n--------------------------------------------------------------------------------------\n')
            epoch += 1
        return best_swarm_pos

# %% [markdown]
# **3. Create Particles Class**

# %%
class Particles:
    def __init__(self, ann):
        self.ann = ann # neural network
        self.dim = self.ann.getnWeights() # no. of weights in nurol network = dimension of particle
        
        # initialise particle best position and velocity with random values 
        self.position = (np.random.rand((self.dim)).astype(np.float64)-0.5)/2 #current position; initialized with random
        self.velocity = (np.random.rand((self.dim)).astype(np.float64)-0.5)/2 #current velocity; initialized with random
        
        self.err = self.ann.forward(self.position)  #compute error for initial position
        
        self.best_part_pos = np.copy(self.position) # intialize particle best position as intial position
        self.best_part_err = self.err  #intialized particle best error as self error from intial position
        
    # getter methods    
    def getDim(self): return self.dim
    def getPosition(self):return self.position
    def getVelocity(self):return self.velocity
    def getError(self):return self.err
    def getBestPartErr(self):return self.best_part_err
    def getBestPartPos(self):return self.best_part_pos

    
    # setter methods    
    def setPosition(self,pos):self.position = np.copy(pos)
    def setVelocity(self,vel):self.velocity = np.copy(vel)
    def setError(self,err): self.err = np.copy(err)
    def setBestPartErr(self,best_err): self.best_part_err = np.copy(best_err)
    def setBestPartPos(self,best_pos): self.best_part_pos = np.copy(best_pos)

# %%
'''
a = np.random.rand(3,3).astype(np.float32)-0.5
print(a)

a = np.random.rand(3,3).astype(np.float32)-0.5
print(a)
'''
# Out:
# '\na = np.random.rand(3,3).astype(np.float32)-0.5\nprint(a)\n\na = np.random.rand(3,3).astype(np.float32)-0.5\nprint(a)\n'

# %% [markdown]
# **Select function from User input**

# %%
'''
# Set function from User input
func = input('Choose the function name \n(Options: Linear, Cubic, Sine, TanH, XOR, Complex) = ')
'''
# Out:
# "\n# Set function from User input\nfunc = input('Choose the function name \n(Options: Linear, Cubic, Sine, TanH, XOR, Complex) = ')\n"

# %% [markdown]
# **Set Hyperparameters from User input**

# %%
'''
# Set Hyperparameters from User input

# set number of hidden layers
hidden_layers = int(input('Enter number of hidden layers = '))


# set number of neurons in the hidden layers
if(hidden_layers > 0):
    hidden_layer_neurons = []
    for layer in range(hidden_layers):
        hidden_layer_neurons.append(int(input('Enter number of nodes in hidden layer {}= '.format(layer+1))))
  
# set activation function
activation = input('Enter the activation function \n(Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian) = ')
'''
# Out:
# "\n# Set Hyperparameters from User input\n\n# set number of hidden layers\nhidden_layers = int(input('Enter number of hidden layers = '))\n\n\n# set number of neurons in the hidden layers\nif(hidden_layers > 0):\n    hidden_layer_neurons = []\n    for layer in range(hidden_layers):\n        hidden_layer_neurons.append(int(input('Enter number of nodes in hidden layer {}= '.format(layer+1))))\n  \n# set activation function\nactivation = input('Enter the activation function \n(Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian) = ')\n"

# %% [markdown]
# **Setting ANN Hyperparameters**

# %%
func = 'Cubic' #(Options: Linear, Cubic, Sine, TanH, XOR, Complex)
hidden_layer_neurons = [5,5]
activation = 'Sigmoid' # (Options: Null, Sigmoid, Hyperbolic Tangent, Cosine, Gaussian)

# %%
# to do: handling errors & exceptions

# %%
'''
#check only
for i in range(len(hidden_layer_neurons)):
    print("number of neurons in hidden layer {} is {}".format(i+1,hidden_layer_neurons[i]))
'''
# Out:
# '\n#check only\nfor i in range(len(hidden_layer_neurons)):\n    print("number of neurons in hidden layer {} is {}".format(i+1,hidden_layer_neurons[i]))\n'

# %%
activation_funcs = {
    'Null': lambda x: 0,
    'Sigmoid': lambda x: 1/(1 + np.exp(-x)),
    'Hyperbolic Tangent': lambda x: np.tanh(x),
    'Cosine': lambda x: np.cos(x),
    'Gaussian': lambda x: np.exp(-x**2/2),
        }

# %%
'''
#check only
activate = activation_funcs[activation]
print ('Output: Selected activation -',activate(.5))

print('Output: Null -',0)
print('Output: Sigmoid -',1/(1 + np.exp(-.5)))
print('Output: Hyperbolic Tangent -',np.tanh(.5))
print('Output: Cosine -',np.cos(.5))
print('Output: Gaussian -',np.exp(-.5**2/2))
'''
# Out:
# "\n#check only\nactivate = activation_funcs[activation]\nprint ('Output: Selected activation -',activate(.5))\n\nprint('Output: Null -',0)\nprint('Output: Sigmoid -',1/(1 + np.exp(-.5)))\nprint('Output: Hyperbolic Tangent -',np.tanh(.5))\nprint('Output: Cosine -',np.cos(.5))\nprint('Output: Gaussian -',np.exp(-.5**2/2))\n"

# %% [markdown]
# **Reading data from the .txt file**

# %%
# load the training data from .txt file into a list
txt_address = {'Linear':'Data/1in_linear.txt',
               'Cubic':'Data/1in_cubic.txt',
               'Sine':'Data/1in_sine.txt',
               'TanH':'Data/1in_tanh.txt',
               'XOR':'Data/2in_xor.txt',
               'Complex':'Data/2in_complex.txt'}

train_data_file = open(txt_address[func],'r')
line_data = train_data_file.readlines()
train_data_file.close()

train_list = []
for line in line_data:
    line = line.strip().split()
    for d in line:
        train_list.append(float(d))
        
#check     
#print(train_list)

if func in ('XOR','Complex'):
    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,3)
    X,Y = train_array[:,0:2], train_array[:,-1]

elif func in ('Linear', 'Cubic', 'Sine', 'TanH'):
    train_array = np.asarray(train_list, dtype=np.float32).reshape(-1,2)
    X,Y = train_array[:,0], train_array[:,-1]
else:
    "error reading data"
    
#print(train_array)
#print(X)
#print(Y)

# %%
#create instance of neural network
ann1 = NeuralNetwork(func, hidden_layer_neurons, activation, X,Y)

# %% [markdown]
# **Setting PSO Hyperparameters**

# %%
swarm_size = 20
pso_alpha = 0.7 #0.729
pso_beta = 1.8 #1.49
pso_delta = 1.8 #1.49

max_epochs = 100
bound =50

bound_max = bound
bound_min = -bound


pso1 = ParticleSwarmOptimizer(swarm_size,pso_alpha,pso_beta,pso_delta,max_epochs, bound_max, bound_min)

# %%
#create swarm with swarm_size particles
swarm = [Particles(ann1) for i in range(pso1.getSwarmSize())]

# %%
final_weights = pso1.forward(swarm)
# Out:
# epoch:001 ,particle:01, par err:0.42266, best part err:0.42266, best swarm err:0.34
# epoch:001 ,particle:02, par err:0.37688, best part err:0.37688, best swarm err:0.34
# epoch:001 ,particle:03, par err:0.41012, best part err:0.41012, best swarm err:0.34
# epoch:001 ,particle:04, par err:0.40538, best part err:0.40538, best swarm err:0.34
# epoch:001 ,particle:05, par err:0.49120, best part err:0.49120, best swarm err:0.34
# epoch:001 ,particle:06, par err:0.44609, best part err:0.44609, best swarm err:0.34
# epoch:001 ,particle:07, par err:0.37864, best part err:0.37864, best swarm err:0.34
# epoch:001 ,particle:08, par err:0.44515, best part err:0.44515, best swarm err:0.34
# epoch:001 ,particle:09, par err:0.41329, best part err:0.41329, best swarm err:0.34
# epoch:001 ,particle:10, par err:0.40333, best part err:0.40333, best swarm err:0.34
# epoch:001 ,particle:11, par err:0.33831, best part err:0.33831, best swarm err:0.34
# epoch:001 ,particle:12, par err:0.42272, best part err:0.42272, best swarm err:0.34
# epoch:001 ,particle:13, par err:0.51597, best part err:0.51597, best swarm err:0.34
# epoch:001 ,particle:14, par err:0.36618, best part err:0.36618, best swarm err:0.34
# epoch:001 ,particle:15, par err:0.35425, best part err:0.35425, best swarm err:0.34
# epoch:001 ,particle:16, par err:0.41900, best part err:0.41900, best swarm err:0.34
# epoch:001 ,particle:17, par err:0.38737, best part err:0.38737, best swarm err:0.34
# epoch:001 ,particle:18, par err:0.44646, best part err:0.44646, best swarm err:0.34
# epoch:001 ,particle:19, par err:0.41391, best part err:0.41391, best swarm err:0.34
# epoch:001 ,particle:20, par err:0.39258, best part err:0.39258, best swarm err:0.34
#
# --------------------------------------------------------------------------------------
#
# epoch:002 ,particle:01, par err:0.27745, best part err:0.27745, best swarm err:0.23
# epoch:002 ,particle:02, par err:0.32004, best part err:0.32004, best swarm err:0.23
# epoch:002 ,particle:03, par err:0.27441, best part err:0.27441, best swarm err:0.23
# epoch:002 ,particle:04, par err:0.28630, best part err:0.28630, best swarm err:0.23
# epoch:002 ,particle:05, par err:0.25158, best part err:0.25158, best swarm err:0.23
# epoch:002 ,particle:06, par err:0.25900, best part err:0.25900, best swarm err:0.23
# epoch:002 ,particle:07, par err:0.31022, best part err:0.31022, best swarm err:0.23
# epoch:002 ,particle:08, par err:0.25825, best part err:0.25825, best swarm err:0.23
# epoch:002 ,particle:09, par err:0.28479, best part err:0.28479, best swarm err:0.23
# epoch:002 ,particle:10, par err:0.27835, best part err:0.27835, best swarm err:0.23
# epoch:002 ,particle:11, par err:0.33706, best part err:0.33706, best swarm err:0.23
# epoch:002 ,particle:12, par err:0.29272, best part err:0.29272, best swarm err:0.23
# epoch:002 ,particle:13, par err:0.22525, best part err:0.22525, best swarm err:0.23
# epoch:002 ,particle:14, par err:0.28630, best part err:0.28630, best swarm err:0.23
# epoch:002 ,particle:15, par err:0.34954, best part err:0.34954, best swarm err:0.23
# epoch:002 ,particle:16, par err:0.27220, best part err:0.27220, best swarm err:0.23
# epoch:002 ,particle:17, par err:0.27202, best part err:0.27202, best swarm err:0.23
# epoch:002 ,particle:18, par err:0.24817, best part err:0.24817, best swarm err:0.23
# epoch:002 ,particle:19, par err:0.27057, best part err:0.27057, best swarm err:0.23
# epoch:002 ,particle:20, par err:0.28103, best part err:0.28103, best swarm err:0.23
#
# --------------------------------------------------------------------------------------
#
# epoch:003 ,particle:01, par err:0.17506, best part err:0.17506, best swarm err:0.17
# epoch:003 ,particle:02, par err:0.17870, best part err:0.17870, best swarm err:0.17
# epoch:003 ,particle:03, par err:0.17658, best part err:0.17658, best swarm err:0.17
# epoch:003 ,particle:04, par err:0.17361, best part err:0.17361, best swarm err:0.17
# epoch:003 ,particle:05, par err:0.16856, best part err:0.16856, best swarm err:0.17
# epoch:003 ,particle:06, par err:0.17126, best part err:0.17126, best swarm err:0.17
# epoch:003 ,particle:07, par err:0.17986, best part err:0.17986, best swarm err:0.17
# epoch:003 ,particle:08, par err:0.17122, best part err:0.17122, best swarm err:0.17
# epoch:003 ,particle:09, par err:0.17401, best part err:0.17401, best swarm err:0.17
# epoch:003 ,particle:10, par err:0.17376, best part err:0.17376, best swarm err:0.17
# epoch:003 ,particle:11, par err:0.18169, best part err:0.18169, best swarm err:0.17
# epoch:003 ,particle:12, par err:0.17306, best part err:0.17306, best swarm err:0.17
# epoch:003 ,particle:13, par err:0.16652, best part err:0.16652, best swarm err:0.17
# epoch:003 ,particle:14, par err:0.17664, best part err:0.17664, best swarm err:0.17
# epoch:003 ,particle:15, par err:0.17834, best part err:0.17834, best swarm err:0.17
# epoch:003 ,particle:16, par err:0.17381, best part err:0.17381, best swarm err:0.17
# epoch:003 ,particle:17, par err:0.17461, best part err:0.17461, best swarm err:0.17
# epoch:003 ,particle:18, par err:0.17059, best part err:0.17059, best swarm err:0.17
# epoch:003 ,particle:19, par err:0.17373, best part err:0.17373, best swarm err:0.17
# epoch:003 ,particle:20, par err:0.17647, best part err:0.17647, best swarm err:0.17
#
# --------------------------------------------------------------------------------------
#
# epoch:004 ,particle:01, par err:0.15645, best part err:0.15645, best swarm err:0.15
# epoch:004 ,particle:02, par err:0.15538, best part err:0.15538, best swarm err:0.15
# epoch:004 ,particle:03, par err:0.15510, best part err:0.15510, best swarm err:0.15
# epoch:004 ,particle:04, par err:0.15608, best part err:0.15608, best swarm err:0.15
# epoch:004 ,particle:05, par err:0.15647, best part err:0.15647, best swarm err:0.15
# epoch:004 ,particle:06, par err:0.15724, best part err:0.15724, best swarm err:0.15
# epoch:004 ,particle:07, par err:0.15458, best part err:0.15458, best swarm err:0.15
# epoch:004 ,particle:08, par err:0.15686, best part err:0.15686, best swarm err:0.15
# epoch:004 ,particle:09, par err:0.15562, best part err:0.15562, best swarm err:0.15
# epoch:004 ,particle:10, par err:0.15615, best part err:0.15615, best swarm err:0.15
# epoch:004 ,particle:11, par err:0.15514, best part err:0.15514, best swarm err:0.15
# epoch:004 ,particle:12, par err:0.15572, best part err:0.15572, best swarm err:0.15
# epoch:004 ,particle:13, par err:0.15750, best part err:0.15750, best swarm err:0.15
# epoch:004 ,particle:14, par err:0.15607, best part err:0.15607, best swarm err:0.15
# epoch:004 ,particle:15, par err:0.15465, best part err:0.15465, best swarm err:0.15
# epoch:004 ,particle:16, par err:0.15543, best part err:0.15543, best swarm err:0.15
# epoch:004 ,particle:17, par err:0.15684, best part err:0.15684, best swarm err:0.15
# epoch:004 ,particle:18, par err:0.15640, best part err:0.15640, best swarm err:0.15
# epoch:004 ,particle:19, par err:0.15565, best part err:0.15565, best swarm err:0.15
# epoch:004 ,particle:20, par err:0.15597, best part err:0.15597, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:005 ,particle:01, par err:0.15262, best part err:0.15262, best swarm err:0.15
# epoch:005 ,particle:02, par err:0.15248, best part err:0.15248, best swarm err:0.15
# epoch:005 ,particle:03, par err:0.15248, best part err:0.15248, best swarm err:0.15
# epoch:005 ,particle:04, par err:0.15246, best part err:0.15246, best swarm err:0.15
# epoch:005 ,particle:05, par err:0.15273, best part err:0.15273, best swarm err:0.15
# epoch:005 ,particle:06, par err:0.15265, best part err:0.15265, best swarm err:0.15
# epoch:005 ,particle:07, par err:0.15236, best part err:0.15236, best swarm err:0.15
# epoch:005 ,particle:08, par err:0.15261, best part err:0.15261, best swarm err:0.15
# epoch:005 ,particle:09, par err:0.15246, best part err:0.15246, best swarm err:0.15
# epoch:005 ,particle:10, par err:0.15251, best part err:0.15251, best swarm err:0.15
# epoch:005 ,particle:11, par err:0.15250, best part err:0.15250, best swarm err:0.15
# epoch:005 ,particle:12, par err:0.15257, best part err:0.15257, best swarm err:0.15
# epoch:005 ,particle:13, par err:0.15269, best part err:0.15269, best swarm err:0.15
# epoch:005 ,particle:14, par err:0.15247, best part err:0.15247, best swarm err:0.15
# epoch:005 ,particle:15, par err:0.15250, best part err:0.15250, best swarm err:0.15
# epoch:005 ,particle:16, par err:0.15248, best part err:0.15248, best swarm err:0.15
# epoch:005 ,particle:17, par err:0.15252, best part err:0.15252, best swarm err:0.15
# epoch:005 ,particle:18, par err:0.15270, best part err:0.15270, best swarm err:0.15
# epoch:005 ,particle:19, par err:0.15259, best part err:0.15259, best swarm err:0.15
# epoch:005 ,particle:20, par err:0.15251, best part err:0.15251, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:006 ,particle:01, par err:0.15170, best part err:0.15170, best swarm err:0.15
# epoch:006 ,particle:02, par err:0.15175, best part err:0.15175, best swarm err:0.15
# epoch:006 ,particle:03, par err:0.15172, best part err:0.15172, best swarm err:0.15
# epoch:006 ,particle:04, par err:0.15174, best part err:0.15174, best swarm err:0.15
# epoch:006 ,particle:05, par err:0.15172, best part err:0.15172, best swarm err:0.15
# epoch:006 ,particle:06, par err:0.15166, best part err:0.15166, best swarm err:0.15
# epoch:006 ,particle:07, par err:0.15183, best part err:0.15183, best swarm err:0.15
# epoch:006 ,particle:08, par err:0.15171, best part err:0.15171, best swarm err:0.15
# epoch:006 ,particle:09, par err:0.15174, best part err:0.15174, best swarm err:0.15
# epoch:006 ,particle:10, par err:0.15172, best part err:0.15172, best swarm err:0.15
# epoch:006 ,particle:11, par err:0.15175, best part err:0.15175, best swarm err:0.15
# epoch:006 ,particle:12, par err:0.15171, best part err:0.15171, best swarm err:0.15
# epoch:006 ,particle:13, par err:0.15168, best part err:0.15168, best swarm err:0.15
# epoch:006 ,particle:14, par err:0.15173, best part err:0.15173, best swarm err:0.15
# epoch:006 ,particle:15, par err:0.15180, best part err:0.15180, best swarm err:0.15
# epoch:006 ,particle:16, par err:0.15175, best part err:0.15175, best swarm err:0.15
# epoch:006 ,particle:17, par err:0.15169, best part err:0.15169, best swarm err:0.15
# epoch:006 ,particle:18, par err:0.15170, best part err:0.15170, best swarm err:0.15
# epoch:006 ,particle:19, par err:0.15175, best part err:0.15175, best swarm err:0.15
# epoch:006 ,particle:20, par err:0.15174, best part err:0.15174, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:007 ,particle:01, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:02, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:03, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:04, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:05, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:06, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:07, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:08, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:09, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:10, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:11, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:12, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:13, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:14, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:15, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:16, par err:0.15155, best part err:0.15155, best swarm err:0.15
# epoch:007 ,particle:17, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:18, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:19, par err:0.15154, best part err:0.15154, best swarm err:0.15
# epoch:007 ,particle:20, par err:0.15155, best part err:0.15155, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:008 ,particle:01, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:02, par err:0.15153, best part err:0.15153, best swarm err:0.15
# epoch:008 ,particle:03, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:04, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:05, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:06, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:07, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:08, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:09, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:10, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:11, par err:0.15153, best part err:0.15153, best swarm err:0.15
# epoch:008 ,particle:12, par err:0.15153, best part err:0.15153, best swarm err:0.15
# epoch:008 ,particle:13, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:14, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:15, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:16, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:17, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:18, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:19, par err:0.15152, best part err:0.15152, best swarm err:0.15
# epoch:008 ,particle:20, par err:0.15152, best part err:0.15152, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:009 ,particle:01, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:02, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:03, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:04, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:05, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:06, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:07, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:08, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:09, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:10, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:11, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:12, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:13, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:14, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:15, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:16, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:17, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:18, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:19, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:009 ,particle:20, par err:0.15151, best part err:0.15151, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:010 ,particle:01, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:02, par err:0.15149, best part err:0.15149, best swarm err:0.15
# epoch:010 ,particle:03, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:04, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:05, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:06, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:07, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:08, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:09, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:10, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:11, par err:0.15149, best part err:0.15149, best swarm err:0.15
# epoch:010 ,particle:12, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:13, par err:0.15151, best part err:0.15151, best swarm err:0.15
# epoch:010 ,particle:14, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:15, par err:0.15149, best part err:0.15149, best swarm err:0.15
# epoch:010 ,particle:16, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:17, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:18, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:19, par err:0.15150, best part err:0.15150, best swarm err:0.15
# epoch:010 ,particle:20, par err:0.15150, best part err:0.15150, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:011 ,particle:01, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:02, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:03, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:04, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:05, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:06, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:07, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:08, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:09, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:10, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:11, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:12, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:13, par err:0.15148, best part err:0.15148, best swarm err:0.15
# epoch:011 ,particle:14, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:15, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:16, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:17, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:18, par err:0.15148, best part err:0.15148, best swarm err:0.15
# epoch:011 ,particle:19, par err:0.15147, best part err:0.15147, best swarm err:0.15
# epoch:011 ,particle:20, par err:0.15147, best part err:0.15147, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:012 ,particle:01, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:02, par err:0.15145, best part err:0.15145, best swarm err:0.15
# epoch:012 ,particle:03, par err:0.15145, best part err:0.15145, best swarm err:0.15
# epoch:012 ,particle:04, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:05, par err:0.15143, best part err:0.15143, best swarm err:0.15
# epoch:012 ,particle:06, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:07, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:08, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:09, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:10, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:11, par err:0.15145, best part err:0.15145, best swarm err:0.15
# epoch:012 ,particle:12, par err:0.15145, best part err:0.15145, best swarm err:0.15
# epoch:012 ,particle:13, par err:0.15143, best part err:0.15143, best swarm err:0.15
# epoch:012 ,particle:14, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:15, par err:0.15145, best part err:0.15145, best swarm err:0.15
# epoch:012 ,particle:16, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:17, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:18, par err:0.15143, best part err:0.15143, best swarm err:0.15
# epoch:012 ,particle:19, par err:0.15144, best part err:0.15144, best swarm err:0.15
# epoch:012 ,particle:20, par err:0.15144, best part err:0.15144, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:013 ,particle:01, par err:0.15138, best part err:0.15138, best swarm err:0.15
# epoch:013 ,particle:02, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:03, par err:0.15138, best part err:0.15138, best swarm err:0.15
# epoch:013 ,particle:04, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:05, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:06, par err:0.15138, best part err:0.15138, best swarm err:0.15
# epoch:013 ,particle:07, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:08, par err:0.15138, best part err:0.15138, best swarm err:0.15
# epoch:013 ,particle:09, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:10, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:11, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:12, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:13, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:14, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:15, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:16, par err:0.15138, best part err:0.15138, best swarm err:0.15
# epoch:013 ,particle:17, par err:0.15138, best part err:0.15138, best swarm err:0.15
# epoch:013 ,particle:18, par err:0.15137, best part err:0.15137, best swarm err:0.15
# epoch:013 ,particle:19, par err:0.15138, best part err:0.15138, best swarm err:0.15
# epoch:013 ,particle:20, par err:0.15137, best part err:0.15137, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:014 ,particle:01, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:02, par err:0.15128, best part err:0.15128, best swarm err:0.15
# epoch:014 ,particle:03, par err:0.15129, best part err:0.15129, best swarm err:0.15
# epoch:014 ,particle:04, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:05, par err:0.15131, best part err:0.15131, best swarm err:0.15
# epoch:014 ,particle:06, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:07, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:08, par err:0.15131, best part err:0.15131, best swarm err:0.15
# epoch:014 ,particle:09, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:10, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:11, par err:0.15129, best part err:0.15129, best swarm err:0.15
# epoch:014 ,particle:12, par err:0.15129, best part err:0.15129, best swarm err:0.15
# epoch:014 ,particle:13, par err:0.15132, best part err:0.15132, best swarm err:0.15
# epoch:014 ,particle:14, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:15, par err:0.15128, best part err:0.15128, best swarm err:0.15
# epoch:014 ,particle:16, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:17, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:18, par err:0.15131, best part err:0.15131, best swarm err:0.15
# epoch:014 ,particle:19, par err:0.15130, best part err:0.15130, best swarm err:0.15
# epoch:014 ,particle:20, par err:0.15129, best part err:0.15129, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:015 ,particle:01, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:02, par err:0.15119, best part err:0.15119, best swarm err:0.15
# epoch:015 ,particle:03, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:04, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:05, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:06, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:07, par err:0.15119, best part err:0.15119, best swarm err:0.15
# epoch:015 ,particle:08, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:09, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:10, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:11, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:12, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:13, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:14, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:15, par err:0.15119, best part err:0.15119, best swarm err:0.15
# epoch:015 ,particle:16, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:17, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:18, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:19, par err:0.15118, best part err:0.15118, best swarm err:0.15
# epoch:015 ,particle:20, par err:0.15118, best part err:0.15118, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:016 ,particle:01, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:02, par err:0.15108, best part err:0.15108, best swarm err:0.15
# epoch:016 ,particle:03, par err:0.15107, best part err:0.15107, best swarm err:0.15
# epoch:016 ,particle:04, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:05, par err:0.15104, best part err:0.15104, best swarm err:0.15
# epoch:016 ,particle:06, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:07, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:08, par err:0.15105, best part err:0.15105, best swarm err:0.15
# epoch:016 ,particle:09, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:10, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:11, par err:0.15108, best part err:0.15108, best swarm err:0.15
# epoch:016 ,particle:12, par err:0.15107, best part err:0.15107, best swarm err:0.15
# epoch:016 ,particle:13, par err:0.15103, best part err:0.15103, best swarm err:0.15
# epoch:016 ,particle:14, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:15, par err:0.15108, best part err:0.15108, best swarm err:0.15
# epoch:016 ,particle:16, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:17, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:18, par err:0.15104, best part err:0.15104, best swarm err:0.15
# epoch:016 ,particle:19, par err:0.15106, best part err:0.15106, best swarm err:0.15
# epoch:016 ,particle:20, par err:0.15107, best part err:0.15107, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:017 ,particle:01, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:02, par err:0.15087, best part err:0.15087, best swarm err:0.15
# epoch:017 ,particle:03, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:04, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:05, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:06, par err:0.15089, best part err:0.15089, best swarm err:0.15
# epoch:017 ,particle:07, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:08, par err:0.15089, best part err:0.15089, best swarm err:0.15
# epoch:017 ,particle:09, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:10, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:11, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:12, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:13, par err:0.15089, best part err:0.15089, best swarm err:0.15
# epoch:017 ,particle:14, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:15, par err:0.15087, best part err:0.15087, best swarm err:0.15
# epoch:017 ,particle:16, par err:0.15089, best part err:0.15089, best swarm err:0.15
# epoch:017 ,particle:17, par err:0.15089, best part err:0.15089, best swarm err:0.15
# epoch:017 ,particle:18, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:19, par err:0.15088, best part err:0.15088, best swarm err:0.15
# epoch:017 ,particle:20, par err:0.15088, best part err:0.15088, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:018 ,particle:01, par err:0.15069, best part err:0.15069, best swarm err:0.15
# epoch:018 ,particle:02, par err:0.15067, best part err:0.15067, best swarm err:0.15
# epoch:018 ,particle:03, par err:0.15068, best part err:0.15068, best swarm err:0.15
# epoch:018 ,particle:04, par err:0.15069, best part err:0.15069, best swarm err:0.15
# epoch:018 ,particle:05, par err:0.15071, best part err:0.15071, best swarm err:0.15
# epoch:018 ,particle:06, par err:0.15069, best part err:0.15069, best swarm err:0.15
# epoch:018 ,particle:07, par err:0.15069, best part err:0.15069, best swarm err:0.15
# epoch:018 ,particle:08, par err:0.15070, best part err:0.15070, best swarm err:0.15
# epoch:018 ,particle:09, par err:0.15069, best part err:0.15069, best swarm err:0.15
# epoch:018 ,particle:10, par err:0.15069, best part err:0.15069, best swarm err:0.15
# epoch:018 ,particle:11, par err:0.15067, best part err:0.15067, best swarm err:0.15
# epoch:018 ,particle:12, par err:0.15068, best part err:0.15068, best swarm err:0.15
# epoch:018 ,particle:13, par err:0.15073, best part err:0.15073, best swarm err:0.15
# epoch:018 ,particle:14, par err:0.15070, best part err:0.15070, best swarm err:0.15
# epoch:018 ,particle:15, par err:0.15067, best part err:0.15067, best swarm err:0.15
# epoch:018 ,particle:16, par err:0.15070, best part err:0.15070, best swarm err:0.15
# epoch:018 ,particle:17, par err:0.15069, best part err:0.15069, best swarm err:0.15
# epoch:018 ,particle:18, par err:0.15072, best part err:0.15072, best swarm err:0.15
# epoch:018 ,particle:19, par err:0.15069, best part err:0.15069, best swarm err:0.15
# epoch:018 ,particle:20, par err:0.15069, best part err:0.15069, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:019 ,particle:01, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:02, par err:0.15049, best part err:0.15049, best swarm err:0.15
# epoch:019 ,particle:03, par err:0.15048, best part err:0.15048, best swarm err:0.15
# epoch:019 ,particle:04, par err:0.15048, best part err:0.15048, best swarm err:0.15
# epoch:019 ,particle:05, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:06, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:07, par err:0.15048, best part err:0.15048, best swarm err:0.15
# epoch:019 ,particle:08, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:09, par err:0.15048, best part err:0.15048, best swarm err:0.15
# epoch:019 ,particle:10, par err:0.15048, best part err:0.15048, best swarm err:0.15
# epoch:019 ,particle:11, par err:0.15048, best part err:0.15048, best swarm err:0.15
# epoch:019 ,particle:12, par err:0.15048, best part err:0.15048, best swarm err:0.15
# epoch:019 ,particle:13, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:14, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:15, par err:0.15049, best part err:0.15049, best swarm err:0.15
# epoch:019 ,particle:16, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:17, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:18, par err:0.15047, best part err:0.15047, best swarm err:0.15
# epoch:019 ,particle:19, par err:0.15048, best part err:0.15048, best swarm err:0.15
# epoch:019 ,particle:20, par err:0.15048, best part err:0.15048, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:020 ,particle:01, par err:0.15028, best part err:0.15028, best swarm err:0.15
# epoch:020 ,particle:02, par err:0.15030, best part err:0.15030, best swarm err:0.15
# epoch:020 ,particle:03, par err:0.15029, best part err:0.15029, best swarm err:0.15
# epoch:020 ,particle:04, par err:0.15028, best part err:0.15028, best swarm err:0.15
# epoch:020 ,particle:05, par err:0.15025, best part err:0.15025, best swarm err:0.15
# epoch:020 ,particle:06, par err:0.15028, best part err:0.15028, best swarm err:0.15
# epoch:020 ,particle:07, par err:0.15028, best part err:0.15028, best swarm err:0.15
# epoch:020 ,particle:08, par err:0.15027, best part err:0.15027, best swarm err:0.15
# epoch:020 ,particle:09, par err:0.15027, best part err:0.15027, best swarm err:0.15
# epoch:020 ,particle:10, par err:0.15028, best part err:0.15028, best swarm err:0.15
# epoch:020 ,particle:11, par err:0.15029, best part err:0.15029, best swarm err:0.15
# epoch:020 ,particle:12, par err:0.15029, best part err:0.15029, best swarm err:0.15
# epoch:020 ,particle:13, par err:0.15024, best part err:0.15024, best swarm err:0.15
# epoch:020 ,particle:14, par err:0.15027, best part err:0.15027, best swarm err:0.15
# epoch:020 ,particle:15, par err:0.15030, best part err:0.15030, best swarm err:0.15
# epoch:020 ,particle:16, par err:0.15027, best part err:0.15027, best swarm err:0.15
# epoch:020 ,particle:17, par err:0.15028, best part err:0.15028, best swarm err:0.15
# epoch:020 ,particle:18, par err:0.15025, best part err:0.15025, best swarm err:0.15
# epoch:020 ,particle:19, par err:0.15028, best part err:0.15028, best swarm err:0.15
# epoch:020 ,particle:20, par err:0.15028, best part err:0.15028, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:021 ,particle:01, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:02, par err:0.15002, best part err:0.15002, best swarm err:0.15
# epoch:021 ,particle:03, par err:0.15003, best part err:0.15003, best swarm err:0.15
# epoch:021 ,particle:04, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:05, par err:0.15005, best part err:0.15005, best swarm err:0.15
# epoch:021 ,particle:06, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:07, par err:0.15003, best part err:0.15003, best swarm err:0.15
# epoch:021 ,particle:08, par err:0.15005, best part err:0.15005, best swarm err:0.15
# epoch:021 ,particle:09, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:10, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:11, par err:0.15003, best part err:0.15003, best swarm err:0.15
# epoch:021 ,particle:12, par err:0.15003, best part err:0.15003, best swarm err:0.15
# epoch:021 ,particle:13, par err:0.15005, best part err:0.15005, best swarm err:0.15
# epoch:021 ,particle:14, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:15, par err:0.15002, best part err:0.15002, best swarm err:0.15
# epoch:021 ,particle:16, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:17, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:18, par err:0.15005, best part err:0.15005, best swarm err:0.15
# epoch:021 ,particle:19, par err:0.15004, best part err:0.15004, best swarm err:0.15
# epoch:021 ,particle:20, par err:0.15004, best part err:0.15004, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:022 ,particle:01, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:02, par err:0.14979, best part err:0.14979, best swarm err:0.15
# epoch:022 ,particle:03, par err:0.14980, best part err:0.14980, best swarm err:0.15
# epoch:022 ,particle:04, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:05, par err:0.14983, best part err:0.14983, best swarm err:0.15
# epoch:022 ,particle:06, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:07, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:08, par err:0.14982, best part err:0.14982, best swarm err:0.15
# epoch:022 ,particle:09, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:10, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:11, par err:0.14980, best part err:0.14980, best swarm err:0.15
# epoch:022 ,particle:12, par err:0.14980, best part err:0.14980, best swarm err:0.15
# epoch:022 ,particle:13, par err:0.14984, best part err:0.14984, best swarm err:0.15
# epoch:022 ,particle:14, par err:0.14982, best part err:0.14982, best swarm err:0.15
# epoch:022 ,particle:15, par err:0.14979, best part err:0.14979, best swarm err:0.15
# epoch:022 ,particle:16, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:17, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:18, par err:0.14983, best part err:0.14983, best swarm err:0.15
# epoch:022 ,particle:19, par err:0.14981, best part err:0.14981, best swarm err:0.15
# epoch:022 ,particle:20, par err:0.14981, best part err:0.14981, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:023 ,particle:01, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:02, par err:0.14961, best part err:0.14961, best swarm err:0.15
# epoch:023 ,particle:03, par err:0.14960, best part err:0.14960, best swarm err:0.15
# epoch:023 ,particle:04, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:05, par err:0.14958, best part err:0.14958, best swarm err:0.15
# epoch:023 ,particle:06, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:07, par err:0.14960, best part err:0.14960, best swarm err:0.15
# epoch:023 ,particle:08, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:09, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:10, par err:0.14960, best part err:0.14960, best swarm err:0.15
# epoch:023 ,particle:11, par err:0.14960, best part err:0.14960, best swarm err:0.15
# epoch:023 ,particle:12, par err:0.14960, best part err:0.14960, best swarm err:0.15
# epoch:023 ,particle:13, par err:0.14958, best part err:0.14958, best swarm err:0.15
# epoch:023 ,particle:14, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:15, par err:0.14961, best part err:0.14961, best swarm err:0.15
# epoch:023 ,particle:16, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:17, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:18, par err:0.14958, best part err:0.14958, best swarm err:0.15
# epoch:023 ,particle:19, par err:0.14959, best part err:0.14959, best swarm err:0.15
# epoch:023 ,particle:20, par err:0.14960, best part err:0.14960, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:024 ,particle:01, par err:0.14940, best part err:0.14940, best swarm err:0.15
# epoch:024 ,particle:02, par err:0.14941, best part err:0.14941, best swarm err:0.15
# epoch:024 ,particle:03, par err:0.14941, best part err:0.14941, best swarm err:0.15
# epoch:024 ,particle:04, par err:0.14940, best part err:0.14940, best swarm err:0.15
# epoch:024 ,particle:05, par err:0.14938, best part err:0.14938, best swarm err:0.15
# epoch:024 ,particle:06, par err:0.14940, best part err:0.14940, best swarm err:0.15
# epoch:024 ,particle:07, par err:0.14940, best part err:0.14940, best swarm err:0.15
# epoch:024 ,particle:08, par err:0.14939, best part err:0.14939, best swarm err:0.15
# epoch:024 ,particle:09, par err:0.14939, best part err:0.14939, best swarm err:0.15
# epoch:024 ,particle:10, par err:0.14939, best part err:0.14939, best swarm err:0.15
# epoch:024 ,particle:11, par err:0.14941, best part err:0.14941, best swarm err:0.15
# epoch:024 ,particle:12, par err:0.14940, best part err:0.14940, best swarm err:0.15
# epoch:024 ,particle:13, par err:0.14937, best part err:0.14937, best swarm err:0.15
# epoch:024 ,particle:14, par err:0.14939, best part err:0.14939, best swarm err:0.15
# epoch:024 ,particle:15, par err:0.14941, best part err:0.14941, best swarm err:0.15
# epoch:024 ,particle:16, par err:0.14940, best part err:0.14940, best swarm err:0.15
# epoch:024 ,particle:17, par err:0.14940, best part err:0.14940, best swarm err:0.15
# epoch:024 ,particle:18, par err:0.14938, best part err:0.14938, best swarm err:0.15
# epoch:024 ,particle:19, par err:0.14940, best part err:0.14940, best swarm err:0.15
# epoch:024 ,particle:20, par err:0.14940, best part err:0.14940, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:025 ,particle:01, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:02, par err:0.14918, best part err:0.14918, best swarm err:0.15
# epoch:025 ,particle:03, par err:0.14919, best part err:0.14919, best swarm err:0.15
# epoch:025 ,particle:04, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:05, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:06, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:07, par err:0.14919, best part err:0.14919, best swarm err:0.15
# epoch:025 ,particle:08, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:09, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:10, par err:0.14919, best part err:0.14919, best swarm err:0.15
# epoch:025 ,particle:11, par err:0.14919, best part err:0.14919, best swarm err:0.15
# epoch:025 ,particle:12, par err:0.14919, best part err:0.14919, best swarm err:0.15
# epoch:025 ,particle:13, par err:0.14921, best part err:0.14921, best swarm err:0.15
# epoch:025 ,particle:14, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:15, par err:0.14918, best part err:0.14918, best swarm err:0.15
# epoch:025 ,particle:16, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:17, par err:0.14920, best part err:0.14920, best swarm err:0.15
# epoch:025 ,particle:18, par err:0.14921, best part err:0.14921, best swarm err:0.15
# epoch:025 ,particle:19, par err:0.14919, best part err:0.14919, best swarm err:0.15
# epoch:025 ,particle:20, par err:0.14919, best part err:0.14919, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:026 ,particle:01, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:02, par err:0.14900, best part err:0.14900, best swarm err:0.15
# epoch:026 ,particle:03, par err:0.14900, best part err:0.14900, best swarm err:0.15
# epoch:026 ,particle:04, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:05, par err:0.14903, best part err:0.14903, best swarm err:0.15
# epoch:026 ,particle:06, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:07, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:08, par err:0.14902, best part err:0.14902, best swarm err:0.15
# epoch:026 ,particle:09, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:10, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:11, par err:0.14900, best part err:0.14900, best swarm err:0.15
# epoch:026 ,particle:12, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:13, par err:0.14903, best part err:0.14903, best swarm err:0.15
# epoch:026 ,particle:14, par err:0.14902, best part err:0.14902, best swarm err:0.15
# epoch:026 ,particle:15, par err:0.14900, best part err:0.14900, best swarm err:0.15
# epoch:026 ,particle:16, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:17, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:18, par err:0.14903, best part err:0.14903, best swarm err:0.15
# epoch:026 ,particle:19, par err:0.14901, best part err:0.14901, best swarm err:0.15
# epoch:026 ,particle:20, par err:0.14901, best part err:0.14901, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:027 ,particle:01, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:02, par err:0.14887, best part err:0.14887, best swarm err:0.15
# epoch:027 ,particle:03, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:04, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:05, par err:0.14885, best part err:0.14885, best swarm err:0.15
# epoch:027 ,particle:06, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:07, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:08, par err:0.14885, best part err:0.14885, best swarm err:0.15
# epoch:027 ,particle:09, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:10, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:11, par err:0.14887, best part err:0.14887, best swarm err:0.15
# epoch:027 ,particle:12, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:13, par err:0.14884, best part err:0.14884, best swarm err:0.15
# epoch:027 ,particle:14, par err:0.14885, best part err:0.14885, best swarm err:0.15
# epoch:027 ,particle:15, par err:0.14887, best part err:0.14887, best swarm err:0.15
# epoch:027 ,particle:16, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:17, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:18, par err:0.14885, best part err:0.14885, best swarm err:0.15
# epoch:027 ,particle:19, par err:0.14886, best part err:0.14886, best swarm err:0.15
# epoch:027 ,particle:20, par err:0.14886, best part err:0.14886, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:028 ,particle:01, par err:0.14872, best part err:0.14872, best swarm err:0.15
# epoch:028 ,particle:02, par err:0.14872, best part err:0.14872, best swarm err:0.15
# ...
#
# epoch:092 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:092 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:093 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:093 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:094 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:094 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:095 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:095 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:096 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:096 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:097 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:097 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:098 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:098 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:099 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:099 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------
#
# epoch:100 ,particle:01, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:02, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:03, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:04, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:05, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:06, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:07, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:08, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:09, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:10, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:11, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:12, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:13, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:14, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:15, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:16, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:17, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:18, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:19, par err:0.14786, best part err:0.14786, best swarm err:0.15
# epoch:100 ,particle:20, par err:0.14786, best part err:0.14786, best swarm err:0.15
#
# --------------------------------------------------------------------------------------

# %%
print(final_weights)
# Out:
# [-0.68570242 -0.84849673  1.23136373  2.74964077 -2.08575596  1.05053889
#   0.37690605 -1.06519931 -2.63245229 -0.91302692  0.4034376  -0.13792714
#   1.57301563  1.2172339  -0.88909399 -0.71584489  2.41292637  3.75321792
#   1.94767973  2.27449089  0.60697669 -0.1434684  -0.75166628  1.49091228
#   1.24973911  0.45421964 -0.54638889  0.52623311 -0.28554699  3.04300103
#  -3.27271714  0.90394196 -3.20188479 -0.89601314 -1.17807124]

# %%
np.savetxt('final_weights01.csv',final_weights,delimiter=',')

# %%
print(pso1.getRunData()[1])
#data in format: [epoch+1,i+1,err_i,best_part_error_i,best_swarm_err]

print(pso1.getPSO_Hyperparameters())
#data in format: [self.swarmSize, self.psoAlpha, self.psoBeta, self.psoDelta, self.maxEpochs, self.bound_max, self.bound_min}

print(pso1.ann.getANN_Hyperparameters())
#data in format: [self.func, self.actFunc, self.layerArch]
# Out:
# [1, 2, 0.3768786919581725, 0.3768786919581725, 0.33830522120065865]
# [20, 0.7, 1.8, 1.8, 100, 50, -50]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-6de28e4928c0> in <module>
#       5 #data in format: [self.swarmSize, self.psoAlpha, self.psoBeta, self.psoDelta, self.maxEpochs, self.bound_max, self.bound_min}
#       6
# ----> 7 print(pso1.ann.getANN_Hyperparameters())
#       8 #data in format: [self.func, self.actFunc, self.layerArch]
#
# AttributeError: 'ParticleSwarmOptimizer' object has no attribute 'ann'
